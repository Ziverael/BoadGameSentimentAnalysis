# %% [markdown]
# # Setup

# %%
import asyncio
from collections import Counter
import json
import re
from pathlib import Path

from googletrans import Translator
from langdetect import detect, LangDetectException
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import numpy as np
import polars as pl
from sklearn.preprocessing import MinMaxScaler
import spacy
from stopwordsiso import stopwords
from tqdm import tqdm
from tqdm.asyncio import tqdm_asyncio
from wordcloud import WordCloud

import utils
from utils import PATHS
# Out:
# /home/ziverael/Documents/BGG/analysis/.venv/lib/python3.12/site-packages/stopwordsiso/_core.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# # Tools

# %%
def extract_tokens(text: str) -> list[str]:
    """Firstly remove all non alphabetic characters, having in mind that
    there are Unicode characters. After tokenization we remove stopwords (ENG)
    and  remove all 1-2 chars lenghts words.

    Finally lemmatize tokens.
    """
    clean = re.sub(r"[\W]+", " ", text.lower())
    clean = re.sub(r"[\d]+", " ", clean)
    words = nltk.word_tokenize(clean)
    words = [w for w in words if w not in stopwords("en") and len(w) > 2]
    doc = nlp(" ".join(words))
    return [token.lemma_.lower() for token in doc if token.is_alpha]

# %% [markdown]
# # Load

# %%
with (PATHS.data / "games_reviews.json").open("rb") as f:
    data = json.load(f)

# %%
example_data = data[0]

# %%
example_data.keys()
# Out:
# dict_keys(['title', 'game_details', 'game_stats', 'game_reviews'])

# %%
Counter(extract_tokens(example_data["game_details"]["long_description"]))
# Out:
# Counter({'brass': 5,
#          'industry': 5,
#          'action': 5,
#          'birmingham': 4,
#          'game': 4,
#          'build': 3,
#          'network': 3,
#          'canal': 3,
#          'rail': 3,
#          'story': 2,
#          'predecessor': 2,
#          'develop': 2,
#          'establish': 2,
#          'era': 2,
#          'vps': 2,
#          'tile': 2,
#          'original': 2,
#          'sell': 2,
#          'loan': 2,
#          'card': 2,
#          'wild': 2,
#          'economic': 1,
#          'strategy': 1,
#          'sequel': 1,
#          'martin': 1,
#          'wallace': 1,
#          'masterpiece': 1,
#          'tell': 1,
#          'compete': 1,
#          'entrepreneur': 1,
#          'industrial': 1,
#          'revolution': 1,
#          'offer': 1,
#          'arc': 1,
#          'experience': 1,
#          'effort': 1,
#          'exploit': 1,
#          'market': 1,
#          'demand': 1,
#          'play': 1,
#          'halves': 1,
#          'win': 1,
#          'score': 1,
#          'count': 1,
#          'flip': 1,
#          'player': 1,
#          'track': 1,
#          'receiving': 1,
#          'perform': 1,
#          'pay': 1,
#          'require': 1,
#          'resource': 1,
#          'add': 1,
#          'link': 1,
#          'expand': 1,
#          'increase': 1,
#          'cotton': 1,
#          'manufacture': 1,
#          'pottery': 1,
#          'reduce': 1,
#          'income': 1,
#          'feature': 1,
#          'sixth': 1,
#          'scout': 1,
#          'discard': 1,
#          'location': 1,
#          'replace': 1,
#          'double': 1})

# %%
def recognize_language(text: str) -> str:
    try:
        lang = detect(text)
    except LangDetectException:
        lang = "en" #TODO: set special flag
    return lang

@utils.with_pickle_async()
async def translate_multiple(texts: list[str], lang_from: list[str], lang_to: list[str]) -> list[str]:
    async with Translator() as translator:
        async def translate_one(text, src, dest):
            t = await translator.translate(text=text, src=src, dest=dest)
            return t.text
        return await tqdm_asyncio.gather(
            *(translate_one(text, from_, to_) for text, from_, to_ in zip(texts, lang_from, lang_to, strict=True))
        )

# %%
example_game_reviews = [info["review"] for info in example_data["game_reviews"]]
from_langs =  [recognize_language(r) for r in example_game_reviews]
translactions = await translate_multiple(example_game_reviews, from_langs, ["en"] * len(from_langs), pickle_path=PATHS.pickles / "example_translations")

# %%
translactions
# Out:
# ["{'review': '2-4 [S]', 'reviewer_country': 'Italy', 'rating': 0.0, 'date': '2025-09-24 17:47:08', 'is_owner': True}",
#  "{'review': 'Great game that somehow feels simple, yet every decision you make carries weight\\n', 'reviewer_country': '', 'rating': 8.5, 'date': '2021-02-25 08:42:44', 'is_owner': False}",
#  '{\'review\': "If you can play this in 60 minutes you\'re playing too fast.  With my group a a game lasts about 45 minutes per player.\\n\\nKeep pushing up my rating..  This game continues to be my favorite and the favorite of our group.", \'reviewer_country\': \'United States\', \'rating\': 9.4, \'date\': \'2024-07-10 16:55:53\', \'is_owner\': True}',
#  "{'review': 'Tabletop', 'reviewer_country': 'United States', 'rating': 0.0, 'date': '2025-02-01 17:35:35', 'is_owner': True}",
#  "{'review': 'I only played half a real game, but I was captivated throughout. Would play again.', 'reviewer_country': 'United States', 'rating': 8.7, 'date': '2025-11-10 19:17:57', 'is_owner': False}",
#  "{'review': 'Ship', 'reviewer_country': 'Hong Kong', 'rating': 10.0, 'date': '2017-08-02 02:10:40', 'is_owner': True}",
#  '{\'review\': "The more I play, the more I realize it\'s more about playing the hand you\'re dealt, and less about strategy", \'reviewer_country\': \'United States\', \'rating\': 7.0, \'date\': \'2022-11-18 00:53:44\', \'is_owner\': False}',
#  "{'review': 'Very good game. I might not say it is the best of all times, but it is definetely great. The mechanics are simple, but I consider that it takes a little time to adapt to them. You may need several playthroughs to achieve some sort of mastering. Revise every victory point possibility to plan your strategy, otherwise, it can be easy to fall pursuing things that are not profitable in the long term.', 'reviewer_country': 'Paraguay', 'rating': 8.0, 'date': '2024-11-26 12:06:53', 'is_owner': True}",
#  '{\'review\': "+ Artwork is great\\n+ Great strategy game\\n+ Lots of interaction\\n+ Low luck factor\\n+ Many paths to victory\\n+ Brain burner \\n- Quite long\\n- Rules heavy \\n- Theme is a bit boring\\n\\nDeep strategic economic game with many ways to win the game. It is surprisingly enough very interactive. I\'ve only played it at 2 and 3 player count. ", \'reviewer_country\': \'Belgium\', \'rating\': 8.5, \'date\': \'2022-01-18 08:40:16\', \'is_owner\': True}',
#  "{'review': 'Not a Euro fan, it could be good, I wouldn't mind playing it again if necessary, but I won't suggest it myself. And yes, this is definitely not the first place on BGG.', 'reviewer_country': 'Belarus', 'rating': 6.0, 'date': '2025-09-06 08:12:40', 'is_owner': False}",
#  "{'review': 'Most of my plays have been at 2p, and I thoroughly enjoyed every single game. \\nHowever, it feels like it ends very quickly at 4p (a feeling it seems others at my table tend to have as well). \\n\\n', 'reviewer_country': 'Switzerland', 'rating': 9.5, 'date': '2024-12-17 10:40:53', 'is_owner': True}",
#  "{'review': 'Pt: 3', 'reviewer_country': '', 'rating': 0.0, 'date': '2025-11-10 00:00:59', 'is_owner': True}",
#  "{'review': 'In: October 2025', 'reviewer_country': '', 'rating': 0.0, 'date': '2024-05-23 23:31:31', 'is_owner': True}",
#  "{'review': 'ES', 'reviewer_country': '', 'rating': 9.0, 'date': '2021-01-26 00:30:31', 'is_owner': True}",
#  "{'review': 'M.Heavy Euro - Wallace, Trains', 'reviewer_country': 'United States', 'rating': 9.3, 'date': '2017-04-19 05:07:02', 'is_owner': True}",
#  '{\'review\': "Arguably the best strategic area control, resource management game.  Just make sure you use other peoples beer and don\'t let them use yours.", \'reviewer_country\': \'United States\', \'rating\': 8.5, \'date\': \'2019-02-16 16:05:39\', \'is_owner\': False}',
#  "{'review': 'Epic', 'reviewer_country': '', 'rating': 0.0, 'date': '2024-12-26 12:13:56', 'is_owner': False}",
#  '{\'review\': "haven\'t played it enough to really understand it. Heavy and thinky. need to log more plays", \'reviewer_country\': \'United States\', \'rating\': 7.0, \'date\': \'2025-02-25 14:52:24\', \'is_owner\': True}',
#  '{\'review\': "Brass is a game which owes a lot of its success to its ability to offer few criticisms (little chance, impeccable edition, mature theme, elitist game). It is an overrated game which surfs on the faults of the BGG ranking (the re-releases have excessively high scores, especially with a graphic overhaul and abundant hyper-quality material. These re-releases preach convictions who overrate their favorite games through a new entry on BGG).", \'reviewer_country\': \'France\', \'rating\': 7.0, \'date\': \'2023-06-21 04:28:52\', \'is_owner\': False}',
#  '{\'review\': \'Your first game is likely going to be rough. However no doubt you will see the appeal of building up your own niche economy that ends up frustratingly reliant on and sometimes in favor the other players. At the end of each round you will be left going "oh I wish I did that," or "things could have gone well if you didn\\\'t do that", but still be left to admire how everything resulted in the end. After that rough first game, you are most likely going to arrange for another game, all to get better at this system.\', \'reviewer_country\': \'Australia\', \'rating\': 9.0, \'date\': \'2025-07-04 05:16:12\', \'is_owner\': True}',
#  "{'review': 'B3u4, G2', 'reviewer_country': 'Germany', 'rating': 8.5, 'date': '2020-10-30 08:16:32', 'is_owner': True}",
#  "{'review': 'Regal 14', 'reviewer_country': 'Germany', 'rating': 0.0, 'date': '2021-11-01 11:06:57', 'is_owner': True}",
#  "{'review': '£67.85 https://www.amazon.co.uk/Roxley-Games-ROX402-Brass-Birmingham/dp/1988884047?crid=2I7084BPZPFR5&dib=eyJ2IjoiMSJ9.AKBvx-qCEQ1s2PviGSbDhYyDSrcdKdGtfSi_ilfJCheyjNb5lf8iB5Kr8USCrowvqXNUC7k-hRITiyTddwAp1e-vXgssxL4xuGJa3X2ETt8Np9UmhR4kjr6WpnTMDMRj_VvxWnEgN6AY7c15BtQ-aWQy9Jis6jXCz3utNAtdZ5rT2epjPFsa2S4Te8RikY2S8yEHoXlcbHAEnprGxF1cy7ivg7o24JuypogPNga_UZOPS_Psun_ySg-365rKRCq8i06CmiXpEVyVf83N0o-ViZGc70ox5rE1PqNQ2yb6k4I.VZKtGk37XxVIkuMPPcDUbbo9eBxUHUpzCjO7chxTe9k&dib_tag=se&keywords=brass%2Bbirmingham%2Bboard%2Bgame&qid=1762604991&sprefix=brass%2B%2Caps%2C123&sr=8-4&th=1', 'reviewer_country': '', 'rating': 0.0, 'date': '2025-11-08 10:05:06', 'is_owner': False}",
#  '{\'review\': "Previously 9. The more you play this game the more it shines!\\n\\nIt has a relatively simple rule set with incredible depth. No need for expansions.... It\'s a modern classic.\\n\\nIf you like strategy without the need to attack your opponents to win, this is for you.\\n\\nThe interplay of you using up the other players resources benefitting both you and them is very satisfying and keeps everyone engaged.\\n\\nGreat family strategic game! ", \'reviewer_country\': \'Ireland\', \'rating\': 10.0, \'date\': \'2024-05-09 09:36:06\', \'is_owner\': True}',
#  "{'review': 'I loathe this as much as I loathed the original Brass. And now add in hunger games for beer. \\n\\nOne and done.\\n\\nThe #1 game on BGG? Someone euthanize me.', 'reviewer_country': 'Canada', 'rating': 3.0, 'date': '2025-11-07 16:06:34', 'is_owner': False}",
#  "{'review': 'Tedious and boring VP pusher with instant railway transition. Not my cup of tea? No, I’d rather smear my genitalia with fish paste and dangle them in a pool of hungry piranha. \\n\\nDingo', 'reviewer_country': '', 'rating': 2.0, 'date': '2018-09-30 09:38:56', 'is_owner': False}",
#  "{'review': 'The first game had been somewhat difficult. Partly because of the new rules and partly because, in the random distribution of initial markets, we ended up with one of them closed and that disrupted how the game unfolds (it doesn't break it, but it's not the easiest thing to deal with the first time). Initially, I had the feeling that the addition of options and depth did not compensate for the loss of the fluid pace of the original.\\n\\nIn the last one I participated, the same thing happened with the initial markets and we said fuggit, and we shuffled them again. With the rules more polished and more open markets, the game flew with the fluidity that I remembered the original had, so I reconciled myself with this new version.\\n\\nBut you have to use the side of the board during the day, the side of the board at night, unless you use a miner's helmet with light, you can't distinguish a knob.\\n\\nI also don't know what the game will bring as money, because we always use poker chips.\\n\\nA classic that preserves the best of the Eurogames from that era: depth, options, decisions, interaction, fluidity, with an updated card.\\n\\nHighly recommended :star::star::star::star::nostar:', 'reviewer_country': 'Argentina', 'rating': 9.0, 'date': '2019-08-27 09:30:40', 'is_owner': False}",
#  "{'review': 'SpielboxRating 9-10, by. 9,20', 'reviewer_country': 'Germany', 'rating': 0.0, 'date': '2025-03-01 17:14:41', 'is_owner': False}",
#  '{\'review\': "Much more fun than the (old) original version. This took a few plays to grow on me. No in game text, has a central board and good balance between tactical and strategical play. Maybe a bit on the long side, but it\'s a really nail-biter till the end. I can see why this is rated so high as it is.", \'reviewer_country\': \'\', \'rating\': 8.5, \'date\': \'2023-05-04 17:22:16\', \'is_owner\': False}',
#  '{\'review\': "It\'s a great game, would struggle to get consistent plays.", \'reviewer_country\': \'United States\', \'rating\': 8.0, \'date\': \'2021-04-11 20:17:03\', \'is_owner\': False}',
#  "{'review': '+ 3D Printed insert\\n+ Sleeves', 'reviewer_country': 'Slovakia', 'rating': 8.5, 'date': '2024-09-11 07:11:51', 'is_owner': False}",
#  "{'review': 'I enjoy Lancashire and want to add this one to my collection at some point.', 'reviewer_country': '', 'rating': 0.0, 'date': '2024-11-08 11:08:43', 'is_owner': False}",
#  "{'review': 'Very clean average Euro.', 'reviewer_country': 'Spain', 'rating': 9.0, 'date': '2025-11-06 04:14:42', 'is_owner': True}",
#  "{'review': 'Great game!', 'reviewer_country': 'Indonesia', 'rating': 8.0, 'date': '2025-10-22 08:23:42', 'is_owner': True}",
#  "{'review': 'It's dry and the rules are hard to memorize compared to other games of the same weight. The main mechanism is classically simple, like Catan, even for a 2018 game. Replayability is also questionable if played with the same members. Conclusion Fun is simple, understanding is difficult.', 'reviewer_country': '', 'rating': 1.0, 'date': '2025-11-05 20:41:41', 'is_owner': False}",
#  "{'review': 'Great game\\n-scratches the economic itch\\n-tight gameplay, but does not feel too limiting\\n-not too long after you learn\\n-straightforward ways to score\\n-has a semi cooperative element to the game which make other players turns more interesting  \\n-can be a bit tough to learn/teach first time\\n-rules can feel contradicting when learning', 'reviewer_country': 'United States', 'rating': 9.0, 'date': '2025-11-05 18:34:23', 'is_owner': True}",
#  "{'review': 'kickstarter', 'reviewer_country': 'Czech Republic', 'rating': 9.5, 'date': '2018-08-02 10:34:01', 'is_owner': True}",
#  "{'review': '+ Engaging tactics and strategy\\n+ Agonizing decisions and tradeoffs\\n+ Tight economy\\n+ Player interaction\\n+ Climactic ending\\n- AP prone\\n- Finicky rules and fiddliness\\n- Downtime', 'reviewer_country': '', 'rating': 8.0, 'date': '2025-08-24 07:20:11', 'is_owner': False}",
#  '{\'review\': "BRASS BIRMINGHAM (2-4 players)\\n\\nDeluxe player aids: https://boardgamegeek.com/filepage/179522/deluxe-player-aids-brass-birmingham\\n\\nFanmade solo variant: \\n\\nhttp://www.mautoma.com/mautomas/brass-birmingham \\n\\nOnline app for solo variant so you don\'t have to print the cards: \\n\\nhttps://boardgamegeek.com/filepage/168370/brass-birmingham-george-solo-competitive-mode\\n\\nBrass Birmingham is better than Brass Lancashire. The Mautoma Solo variant is quite good but I prefer to play Brass as a multiplayer game. The game is a dry euro but a VERY good dry euro.", \'reviewer_country\': \'Belgium\', \'rating\': 9.0, \'date\': \'2020-04-16 14:52:47\', \'is_owner\': True}',
#  "{'review': 'Rules that are a bit obtuse, with exceptions and many details that make you have to constantly review them. The explanation must be prepared well, it is not easy to assimilate the concepts. \\n\\nI like that everyone participates on the central board and can take advantage of each other's routes and resources, there is a lot of interaction, without a doubt what I like most about the game. The editing is cool too. However, the game has too many unintuitive rules and too many details to keep an eye on (it can lead to long turns). Seeing that it is such a beloved game, I have given it several chances but it is definitely not my thing.', 'reviewer_country': 'Spain', 'rating': 5.0, 'date': '2019-09-21 03:01:46', 'is_owner': False}",
#  "{'review': 'It’s Brass with a more-is-better approach: more buildings, more locations, more connections—and then beer. Less cutthroat and leaning toward a point-salad feel. The high rail scoring makes the rail era predictable, though some might see it as a more forgiving, flexible evolution of the original. Could rate higher, but I’d always pick Lancashire over this, which brings the rating down a bit.', 'reviewer_country': 'Sweden', 'rating': 8.0, 'date': '2021-01-07 16:52:10', 'is_owner': False}",
#  "{'review': 'Boardroom, PAX, 4 2-4, 2h', 'reviewer_country': '', 'rating': 0.0, 'date': '2024-11-18 20:49:11', 'is_owner': False}",
#  '{\'review\': "That\'s the most boring and ugly game I\'ve ever played. Viscous snot is the most suitable description for it. 1000% overrated.", \'reviewer_country\': \'\', \'rating\': 1.0, \'date\': \'2025-11-04 11:20:33\', \'is_owner\': False}',
#  "{'review': 'Loved playing and would recommend playing but did take us 4 and a half hours to learn and play as a 3. Worth it though', 'reviewer_country': 'United Kingdom', 'rating': 9.0, 'date': '2025-11-04 08:46:21', 'is_owner': False}",
#  "{'review': 'Sleeved with Shield Titan Super Sleeves (Clear)\\nInsert included', 'reviewer_country': '', 'rating': 9.0, 'date': '2023-01-27 07:53:43', 'is_owner': True}",
#  '{\'review\': "Tentative rating.\\n\\nI understand how this game got its reputation. The puzzle involved is unique, which is such a rarity among the hundreds of Euros we see each year. It felt like the game is stimulating a whole new part of my brain\'s strategy center that I didn\'t know existed, and I love it.\\n\\nThe game is complex, the strategy is opaque, and it was a pain to teach with all of its minor titbits and exceptions. However, these won\'t matter after 20+ plays, and the game is solid enough to warrant that.", \'reviewer_country\': \'Hong Kong\', \'rating\': 9.0, \'date\': \'2025-11-03 20:53:07\', \'is_owner\': False}',
#  "{'review': '3.87', 'reviewer_country': 'Chile', 'rating': 0.0, 'date': '2021-07-13 22:37:56', 'is_owner': True}",
#  "{'review': 'great euro styled game.\\nflow of interaction is just a masterpiece.\\nMartin is genious.', 'reviewer_country': 'South Korea', 'rating': 8.9, 'date': '2023-05-31 10:49:56', 'is_owner': False}",
#  "{'review': 'Less fluid than the black edition.', 'reviewer_country': 'Italy', 'rating': 6.0, 'date': '2017-04-22 01:38:44', 'is_owner': True}",
#  '{\'review\': "In my opinion, Lancashire is much better.\\n\\nLancashire is more straightforward and you focus on the strategy. You don\'t get tired of the multitude of tokens, in Lancashire there is only the essential ones. \\n\\nAfter playing Birmingham I always felt exhausted, but still liked the game. However, after playing Lancashire the time just flew and I would have wanted to play again right away.", \'reviewer_country\': \'Hungary\', \'rating\': 0.0, \'date\': \'2018-10-26 17:42:27\', \'is_owner\': False}',
#  "{'review': '2-4 [S]', 'reviewer_country': 'Italy', 'rating': 0.0, 'date': '2025-09-24 17:47:08', 'is_owner': True}",
#  "{'review': 'Great game that somehow feels simple, yet every decision you make carries weight\\n', 'reviewer_country': '', 'rating': 8.5, 'date': '2021-02-25 08:42:44', 'is_owner': False}",
#  '{\'review\': "If you can play this in 60 minutes you\'re playing too fast.  With my group a a game lasts about 45 minutes per player.\\n\\nKeep pushing up my rating..  This game continues to be my favorite and the favorite of our group.", \'reviewer_country\': \'United States\', \'rating\': 9.4, \'date\': \'2024-07-10 16:55:53\', \'is_owner\': True}',
#  "{'review': 'Tabletop', 'reviewer_country': 'United States', 'rating': 0.0, 'date': '2025-02-01 17:35:35', 'is_owner': True}",
#  "{'review': 'I only played half a real game, but I was captivated throughout. Would play again.', 'reviewer_country': 'United States', 'rating': 8.7, 'date': '2025-11-10 19:17:57', 'is_owner': False}",
#  "{'review': 'Ship', 'reviewer_country': 'Hong Kong', 'rating': 10.0, 'date': '2017-08-02 02:10:40', 'is_owner': True}",
#  '{\'review\': "The more I play, the more I realize it\'s more about playing the hand you\'re dealt, and less about strategy", \'reviewer_country\': \'United States\', \'rating\': 7.0, \'date\': \'2022-11-18 00:53:44\', \'is_owner\': False}',
#  "{'review': 'Very good game. I might not say it is the best of all times, but it is definetely great. The mechanics are simple, but I consider that it takes a little time to adapt to them. You may need several playthroughs to achieve some sort of mastering. Revise every victory point possibility to plan your strategy, otherwise, it can be easy to fall pursuing things that are not profitable in the long term.', 'reviewer_country': 'Paraguay', 'rating': 8.0, 'date': '2024-11-26 12:06:53', 'is_owner': True}",
#  '{\'review\': "+ Artwork is great\\n+ Great strategy game\\n+ Lots of interaction\\n+ Low luck factor\\n+ Many paths to victory\\n+ Brain burner \\n- Quite long\\n- Rules heavy \\n- Theme is a bit boring\\n\\nDeep strategic economic game with many ways to win the game. It is surprisingly enough very interactive. I\'ve only played it at 2 and 3 player count. ", \'reviewer_country\': \'Belgium\', \'rating\': 8.5, \'date\': \'2022-01-18 08:40:16\', \'is_owner\': True}',
#  "{'review': 'Not a Euro fan, it could be good, I wouldn't mind playing it again if necessary, but I won't suggest it myself. And yes, this is definitely not the first place on BGG.', 'reviewer_country': 'Belarus', 'rating': 6.0, 'date': '2025-09-06 08:12:40', 'is_owner': False}",
#  "{'review': 'Most of my plays have been at 2p, and I thoroughly enjoyed every single game. \\nHowever, it feels like it ends very quickly at 4p (a feeling it seems others at my table tend to have as well). \\n\\n', 'reviewer_country': 'Switzerland', 'rating': 9.5, 'date': '2024-12-17 10:40:53', 'is_owner': True}",
#  "{'review': 'Pt: 3', 'reviewer_country': '', 'rating': 0.0, 'date': '2025-11-10 00:00:59', 'is_owner': True}",
#  "{'review': 'In: October 2025', 'reviewer_country': '', 'rating': 0.0, 'date': '2024-05-23 23:31:31', 'is_owner': True}",
#  "{'review': 'ES', 'reviewer_country': '', 'rating': 9.0, 'date': '2021-01-26 00:30:31', 'is_owner': True}",
#  "{'review': 'M.Heavy Euro - Wallace, Trains', 'reviewer_country': 'United States', 'rating': 9.3, 'date': '2017-04-19 05:07:02', 'is_owner': True}",
#  '{\'review\': "Arguably the best strategic area control, resource management game.  Just make sure you use other peoples beer and don\'t let them use yours.", \'reviewer_country\': \'United States\', \'rating\': 8.5, \'date\': \'2019-02-16 16:05:39\', \'is_owner\': False}',
#  "{'review': 'Epic', 'reviewer_country': '', 'rating': 0.0, 'date': '2024-12-26 12:13:56', 'is_owner': False}",
#  '{\'review\': "haven\'t played it enough to really understand it. Heavy and thinky. need to log more plays", \'reviewer_country\': \'United States\', \'rating\': 7.0, \'date\': \'2025-02-25 14:52:24\', \'is_owner\': True}',
#  '{\'review\': "Brass is a game which owes a lot of its success to its ability to offer few criticisms (little chance, impeccable edition, mature theme, elitist game). It is an overrated game which surfs on the faults of the BGG ranking (the re-releases have excessively high scores, especially with a graphic overhaul and abundant hyper-quality material. These re-releases preach convictions who overrate their favorite games through a new entry on BGG).", \'reviewer_country\': \'France\', \'rating\': 7.0, \'date\': \'2023-06-21 04:28:52\', \'is_owner\': False}',
#  '{\'review\': \'Your first game is likely going to be rough. However no doubt you will see the appeal of building up your own niche economy that ends up frustratingly reliant on and sometimes in favor the other players. At the end of each round you will be left going "oh I wish I did that," or "things could have gone well if you didn\\\'t do that", but still be left to admire how everything resulted in the end. After that rough first game, you are most likely going to arrange for another game, all to get better at this system.\', \'reviewer_country\': \'Australia\', \'rating\': 9.0, \'date\': \'2025-07-04 05:16:12\', \'is_owner\': True}',
#  "{'review': 'B3u4, G2', 'reviewer_country': 'Germany', 'rating': 8.5, 'date': '2020-10-30 08:16:32', 'is_owner': True}",
#  "{'review': 'Regal 14', 'reviewer_country': 'Germany', 'rating': 0.0, 'date': '2021-11-01 11:06:57', 'is_owner': True}",
#  "{'review': '£67.85 https://www.amazon.co.uk/Roxley-Games-ROX402-Brass-Birmingham/dp/1988884047?crid=2I7084BPZPFR5&dib=eyJ2IjoiMSJ9.AKBvx-qCEQ1s2PviGSbDhYyDSrcdKdGtfSi_ilfJCheyjNb5lf8iB5Kr8USCrowvqXNUC7k-hRITiyTddwAp1e-vXgssxL4xuGJa3X2ETt8Np9UmhR4kjr6WpnTMDMRj_VvxWnEgN6AY7c15BtQ-aWQy9Jis6jXCz3utNAtdZ5rT2epjPFsa2S4Te8RikY2S8yEHoXlcbHAEnprGxF1cy7ivg7o24JuypogPNga_UZOPS_Psun_ySg-365rKRCq8i06CmiXpEVyVf83N0o-ViZGc70ox5rE1PqNQ2yb6k4I.VZKtGk37XxVIkuMPPcDUbbo9eBxUHUpzCjO7chxTe9k&dib_tag=se&keywords=brass%2Bbirmingham%2Bboard%2Bgame&qid=1762604991&sprefix=brass%2B%2Caps%2C123&sr=8-4&th=1', 'reviewer_country': '', 'rating': 0.0, 'date': '2025-11-08 10:05:06', 'is_owner': False}",
#  '{\'review\': "Previously 9. The more you play this game the more it shines!\\n\\nIt has a relatively simple rule set with incredible depth. No need for expansions.... It\'s a modern classic.\\n\\nIf you like strategy without the need to attack your opponents to win, this is for you.\\n\\nThe interplay of you using up the other players resources benefitting both you and them is very satisfying and keeps everyone engaged.\\n\\nGreat family strategic game! ", \'reviewer_country\': \'Ireland\', \'rating\': 10.0, \'date\': \'2024-05-09 09:36:06\', \'is_owner\': True}',
#  "{'review': 'I loathe this as much as I loathed the original Brass. And now add in hunger games for beer. \\n\\nOne and done.\\n\\nThe #1 game on BGG? Someone euthanize me.', 'reviewer_country': 'Canada', 'rating': 3.0, 'date': '2025-11-07 16:06:34', 'is_owner': False}",
#  "{'review': 'Tedious and boring VP pusher with instant railway transition. Not my cup of tea? No, I’d rather smear my genitalia with fish paste and dangle them in a pool of hungry piranha. \\n\\nDingo', 'reviewer_country': '', 'rating': 2.0, 'date': '2018-09-30 09:38:56', 'is_owner': False}",
#  "{'review': 'The first game had been somewhat difficult. Partly because of the new rules and partly because, in the random distribution of initial markets, we ended up with one of them closed and that disrupted how the game unfolds (it doesn't break it, but it's not the easiest thing to deal with the first time). Initially, I had the feeling that the addition of options and depth did not compensate for the loss of the fluid pace of the original.\\n\\nIn the last one I participated, the same thing happened with the initial markets and we said fuggit, and we shuffled them again. With the rules more polished and more open markets, the game flew with the fluidity that I remembered the original had, so I reconciled myself with this new version.\\n\\nBut you have to use the side of the board during the day, the side of the board at night, unless you use a miner's helmet with light, you can't distinguish a knob.\\n\\nI also don't know what the game will bring as money, because we always use poker chips.\\n\\nA classic that preserves the best of the Eurogames from that era: depth, options, decisions, interaction, fluidity, with an updated card.\\n\\nHighly recommended :star::star::star::star::nostar:', 'reviewer_country': 'Argentina', 'rating': 9.0, 'date': '2019-08-27 09:30:40', 'is_owner': False}",
#  "{'review': 'SpielboxRating 9-10, by. 9,20', 'reviewer_country': 'Germany', 'rating': 0.0, 'date': '2025-03-01 17:14:41', 'is_owner': False}",
#  '{\'review\': "Much more fun than the (old) original version. This took a few plays to grow on me. No in game text, has a central board and good balance between tactical and strategical play. Maybe a bit on the long side, but it\'s a really nail-biter till the end. I can see why this is rated so high as it is.", \'reviewer_country\': \'\', \'rating\': 8.5, \'date\': \'2023-05-04 17:22:16\', \'is_owner\': False}',
#  '{\'review\': "It\'s a great game, would struggle to get consistent plays.", \'reviewer_country\': \'United States\', \'rating\': 8.0, \'date\': \'2021-04-11 20:17:03\', \'is_owner\': False}',
#  "{'review': '+ 3D Printed insert\\n+ Sleeves', 'reviewer_country': 'Slovakia', 'rating': 8.5, 'date': '2024-09-11 07:11:51', 'is_owner': False}",
#  "{'review': 'I enjoy Lancashire and want to add this one to my collection at some point.', 'reviewer_country': '', 'rating': 0.0, 'date': '2024-11-08 11:08:43', 'is_owner': False}",
#  "{'review': 'Very clean average Euro.', 'reviewer_country': 'Spain', 'rating': 9.0, 'date': '2025-11-06 04:14:42', 'is_owner': True}",
#  "{'review': 'Great game!', 'reviewer_country': 'Indonesia', 'rating': 8.0, 'date': '2025-10-22 08:23:42', 'is_owner': True}",
#  "{'review': 'It's dry and the rules are hard to memorize compared to other games of the same weight. The main mechanism is classically simple, like Catan, even for a 2018 game. Replayability is also questionable if played with the same members. Conclusion Fun is simple, understanding is difficult.', 'reviewer_country': '', 'rating': 1.0, 'date': '2025-11-05 20:41:41', 'is_owner': False}",
#  "{'review': 'Great game\\n-scratches the economic itch\\n-tight gameplay, but does not feel too limiting\\n-not too long after you learn\\n-straightforward ways to score\\n-has a semi cooperative element to the game which make other players turns more interesting  \\n-can be a bit tough to learn/teach first time\\n-rules can feel contradicting when learning', 'reviewer_country': 'United States', 'rating': 9.0, 'date': '2025-11-05 18:34:23', 'is_owner': True}",
#  "{'review': 'kickstarter', 'reviewer_country': 'Czech Republic', 'rating': 9.5, 'date': '2018-08-02 10:34:01', 'is_owner': True}",
#  "{'review': '+ Engaging tactics and strategy\\n+ Agonizing decisions and tradeoffs\\n+ Tight economy\\n+ Player interaction\\n+ Climactic ending\\n- AP prone\\n- Finicky rules and fiddliness\\n- Downtime', 'reviewer_country': '', 'rating': 8.0, 'date': '2025-08-24 07:20:11', 'is_owner': False}",
#  '{\'review\': "BRASS BIRMINGHAM (2-4 players)\\n\\nDeluxe player aids: https://boardgamegeek.com/filepage/179522/deluxe-player-aids-brass-birmingham\\n\\nFanmade solo variant: \\n\\nhttp://www.mautoma.com/mautomas/brass-birmingham \\n\\nOnline app for solo variant so you don\'t have to print the cards: \\n\\nhttps://boardgamegeek.com/filepage/168370/brass-birmingham-george-solo-competitive-mode\\n\\nBrass Birmingham is better than Brass Lancashire. The Mautoma Solo variant is quite good but I prefer to play Brass as a multiplayer game. The game is a dry euro but a VERY good dry euro.", \'reviewer_country\': \'Belgium\', \'rating\': 9.0, \'date\': \'2020-04-16 14:52:47\', \'is_owner\': True}',
#  "{'review': 'Rules that are a bit obtuse, with exceptions and many details that make you have to constantly review them. The explanation must be prepared well, it is not easy to assimilate the concepts. \\n\\nI like that everyone participates on the central board and can take advantage of each other's routes and resources, there is a lot of interaction, without a doubt what I like most about the game. The editing is cool too. However, the game has too many unintuitive rules and too many details to keep an eye on (it can lead to long turns). Seeing that it is such a beloved game, I have given it several chances but it is definitely not my thing.', 'reviewer_country': 'Spain', 'rating': 5.0, 'date': '2019-09-21 03:01:46', 'is_owner': False}",
#  "{'review': 'It’s Brass with a more-is-better approach: more buildings, more locations, more connections—and then beer. Less cutthroat and leaning toward a point-salad feel. The high rail scoring makes the rail era predictable, though some might see it as a more forgiving, flexible evolution of the original. Could rate higher, but I’d always pick Lancashire over this, which brings the rating down a bit.', 'reviewer_country': 'Sweden', 'rating': 8.0, 'date': '2021-01-07 16:52:10', 'is_owner': False}",
#  "{'review': 'Boardroom, PAX, 4 2-4, 2h', 'reviewer_country': '', 'rating': 0.0, 'date': '2024-11-18 20:49:11', 'is_owner': False}",
#  '{\'review\': "That\'s the most boring and ugly game I\'ve ever played. Viscous snot is the most suitable description for it. 1000% overrated.", \'reviewer_country\': \'\', \'rating\': 1.0, \'date\': \'2025-11-04 11:20:33\', \'is_owner\': False}',
#  "{'review': 'Loved playing and would recommend playing but did take us 4 and a half hours to learn and play as a 3. Worth it though', 'reviewer_country': 'United Kingdom', 'rating': 9.0, 'date': '2025-11-04 08:46:21', 'is_owner': False}",
#  "{'review': 'Sleeved with Shield Titan Super Sleeves (Clear)\\nInsert included', 'reviewer_country': '', 'rating': 9.0, 'date': '2023-01-27 07:53:43', 'is_owner': True}",
#  '{\'review\': "Tentative rating.\\n\\nI understand how this game got its reputation. The puzzle involved is unique, which is such a rarity among the hundreds of Euros we see each year. It felt like the game is stimulating a whole new part of my brain\'s strategy center that I didn\'t know existed, and I love it.\\n\\nThe game is complex, the strategy is opaque, and it was a pain to teach with all of its minor titbits and exceptions. However, these won\'t matter after 20+ plays, and the game is solid enough to warrant that.", \'reviewer_country\': \'Hong Kong\', \'rating\': 9.0, \'date\': \'2025-11-03 20:53:07\', \'is_owner\': False}',
#  "{'review': '3.87', 'reviewer_country': 'Chile', 'rating': 0.0, 'date': '2021-07-13 22:37:56', 'is_owner': True}",
#  "{'review': 'great euro styled game.\\nflow of interaction is just a masterpiece.\\nMartin is genious.', 'reviewer_country': 'South Korea', 'rating': 8.9, 'date': '2023-05-31 10:49:56', 'is_owner': False}",
#  "{'review': 'Less fluid than the black edition.', 'reviewer_country': 'Italy', 'rating': 6.0, 'date': '2017-04-22 01:38:44', 'is_owner': True}",
#  '{\'review\': "In my opinion, Lancashire is much better.\\n\\nLancashire is more straightforward and you focus on the strategy. You don\'t get tired of the multitude of tokens, in Lancashire there is only the essential ones. \\n\\nAfter playing Birmingham I always felt exhausted, but still liked the game. However, after playing Lancashire the time just flew and I would have wanted to play again right away.", \'reviewer_country\': \'Hungary\', \'rating\': 0.0, \'date\': \'2018-10-26 17:42:27\', \'is_owner\': False}',
#  "{'review': '2-4 [S]', 'reviewer_country': 'Italy', 'rating': 0.0, 'date': '2025-09-24 17:47:08', 'is_owner': True}",
#  "{'review': 'Great game that somehow feels simple, yet every decision you make carries weight\\n', 'reviewer_country': '', 'rating': 8.5, 'date': '2021-02-25 08:42:44', 'is_owner': False}",
#  '{\'review\': "If you can play this in 60 minutes you\'re playing too fast.  With my group a a game lasts about 45 minutes per player.\\n\\nKeep pushing up my rating..  This game continues to be my favorite and the favorite of our group.", \'reviewer_country\': \'United States\', \'rating\': 9.4, \'date\': \'2024-07-10 16:55:53\', \'is_owner\': True}',
#  "{'review': 'Tabletop', 'reviewer_country': 'United States', 'rating': 0.0, 'date': '2025-02-01 17:35:35', 'is_owner': True}",
#  "{'review': 'I only played half a real game, but I was captivated throughout. Would play again.', 'reviewer_country': 'United States', 'rating': 8.7, 'date': '2025-11-10 19:17:57', 'is_owner': False}",
#  "{'review': 'Ship', 'reviewer_country': 'Hong Kong', 'rating': 10.0, 'date': '2017-08-02 02:10:40', 'is_owner': True}",
#  '{\'review\': "The more I play, the more I realize it\'s more about playing the hand you\'re dealt, and less about strategy", \'reviewer_country\': \'United States\', \'rating\': 7.0, \'date\': \'2022-11-18 00:53:44\', \'is_owner\': False}',
#  "{'review': 'Very good game. I might not say it is the best of all times, but it is definetely great. The mechanics are simple, but I consider that it takes a little time to adapt to them. You may need several playthroughs to achieve some sort of mastering. Revise every victory point possibility to plan your strategy, otherwise, it can be easy to fall pursuing things that are not profitable in the long term.', 'reviewer_country': 'Paraguay', 'rating': 8.0, 'date': '2024-11-26 12:06:53', 'is_owner': True}",
#  '{\'review\': "+ Artwork is great\\n+ Great strategy game\\n+ Lots of interaction\\n+ Low luck factor\\n+ Many paths to victory\\n+ Brain burner \\n- Quite long\\n- Rules heavy \\n- Theme is a bit boring\\n\\nDeep strategic economic game with many ways to win the game. It is surprisingly enough very interactive. I\'ve only played it at 2 and 3 player count. ", \'reviewer_country\': \'Belgium\', \'rating\': 8.5, \'date\': \'2022-01-18 08:40:16\', \'is_owner\': True}',
#  "{'review': 'Not a Euro fan, it could be good, I wouldn't mind playing it again if necessary, but I won't suggest it myself. And yes, this is definitely not the first place on BGG.', 'reviewer_country': 'Belarus', 'rating': 6.0, 'date': '2025-09-06 08:12:40', 'is_owner': False}",
#  "{'review': 'Most of my plays have been at 2p, and I thoroughly enjoyed every single game. \\nHowever, it feels like it ends very quickly at 4p (a feeling it seems others at my table tend to have as well). \\n\\n', 'reviewer_country': 'Switzerland', 'rating': 9.5, 'date': '2024-12-17 10:40:53', 'is_owner': True}",
#  "{'review': 'Pt: 3', 'reviewer_country': '', 'rating': 0.0, 'date': '2025-11-10 00:00:59', 'is_owner': True}",
#  "{'review': 'In: October 2025', 'reviewer_country': '', 'rating': 0.0, 'date': '2024-05-23 23:31:31', 'is_owner': True}",
#  "{'review': 'ES', 'reviewer_country': '', 'rating': 9.0, 'date': '2021-01-26 00:30:31', 'is_owner': True}",
#  "{'review': 'M.Heavy Euro - Wallace, Trains', 'reviewer_country': 'United States', 'rating': 9.3, 'date': '2017-04-19 05:07:02', 'is_owner': True}",
#  '{\'review\': "Arguably the best strategic area control, resource management game.  Just make sure you use other peoples beer and don\'t let them use yours.", \'reviewer_country\': \'United States\', \'rating\': 8.5, \'date\': \'2019-02-16 16:05:39\', \'is_owner\': False}',
#  "{'review': 'Epic', 'reviewer_country': '', 'rating': 0.0, 'date': '2024-12-26 12:13:56', 'is_owner': False}",
#  '{\'review\': "haven\'t played it enough to really understand it. Heavy and thinky. need to log more plays", \'reviewer_country\': \'United States\', \'rating\': 7.0, \'date\': \'2025-02-25 14:52:24\', \'is_owner\': True}',
#  '{\'review\': "Brass is a game which owes a lot of its success to its ability to offer few criticisms (little chance, impeccable edition, mature theme, elitist game). It is an overrated game which surfs on the faults of the BGG ranking (the re-releases have excessively high scores, especially with a graphic overhaul and abundant hyper-quality material. These re-releases preach convictions who overrate their favorite games through a new entry on BGG).", \'reviewer_country\': \'France\', \'rating\': 7.0, \'date\': \'2023-06-21 04:28:52\', \'is_owner\': False}',
#  '{\'review\': \'Your first game is likely going to be rough. However no doubt you will see the appeal of building up your own niche economy that ends up frustratingly reliant on and sometimes in favor the other players. At the end of each round you will be left going "oh I wish I did that," or "things could have gone well if you didn\\\'t do that", but still be left to admire how everything resulted in the end. After that rough first game, you are most likely going to arrange for another game, all to get better at this system.\', \'reviewer_country\': \'Australia\', \'rating\': 9.0, \'date\': \'2025-07-04 05:16:12\', \'is_owner\': True}',
#  "{'review': 'B3u4, G2', 'reviewer_country': 'Germany', 'rating': 8.5, 'date': '2020-10-30 08:16:32', 'is_owner': True}",
#  "{'review': 'Regal 14', 'reviewer_country': 'Germany', 'rating': 0.0, 'date': '2021-11-01 11:06:57', 'is_owner': True}",
#  "{'review': '£67.85 https://www.amazon.co.uk/Roxley-Games-ROX402-Brass-Birmingham/dp/1988884047?crid=2I7084BPZPFR5&dib=eyJ2IjoiMSJ9.AKBvx-qCEQ1s2PviGSbDhYyDSrcdKdGtfSi_ilfJCheyjNb5lf8iB5Kr8USCrowvqXNUC7k-hRITiyTddwAp1e-vXgssxL4xuGJa3X2ETt8Np9UmhR4kjr6WpnTMDMRj_VvxWnEgN6AY7c15BtQ-aWQy9Jis6jXCz3utNAtdZ5rT2epjPFsa2S4Te8RikY2S8yEHoXlcbHAEnprGxF1cy7ivg7o24JuypogPNga_UZOPS_Psun_ySg-365rKRCq8i06CmiXpEVyVf83N0o-ViZGc70ox5rE1PqNQ2yb6k4I.VZKtGk37XxVIkuMPPcDUbbo9eBxUHUpzCjO7chxTe9k&dib_tag=se&keywords=brass%2Bbirmingham%2Bboard%2Bgame&qid=1762604991&sprefix=brass%2B%2Caps%2C123&sr=8-4&th=1', 'reviewer_country': '', 'rating': 0.0, 'date': '2025-11-08 10:05:06', 'is_owner': False}",
#  '{\'review\': "Previously 9. The more you play this game the more it shines!\\n\\nIt has a relatively simple rule set with incredible depth. No need for expansions.... It\'s a modern classic.\\n\\nIf you like strategy without the need to attack your opponents to win, this is for you.\\n\\nThe interplay of you using up the other players resources benefitting both you and them is very satisfying and keeps everyone engaged.\\n\\nGreat family strategic game! ", \'reviewer_country\': \'Ireland\', \'rating\': 10.0, \'date\': \'2024-05-09 09:36:06\', \'is_owner\': True}',
#  "{'review': 'I loathe this as much as I loathed the original Brass. And now add in hunger games for beer. \\n\\nOne and done.\\n\\nThe #1 game on BGG? Someone euthanize me.', 'reviewer_country': 'Canada', 'rating': 3.0, 'date': '2025-11-07 16:06:34', 'is_owner': False}",
#  "{'review': 'Tedious and boring VP pusher with instant railway transition. Not my cup of tea? No, I’d rather smear my genitalia with fish paste and dangle them in a pool of hungry piranha. \\n\\nDingo', 'reviewer_country': '', 'rating': 2.0, 'date': '2018-09-30 09:38:56', 'is_owner': False}",
#  "{'review': 'The first game had been somewhat difficult. Partly because of the new rules and partly because, in the random distribution of initial markets, we ended up with one of them closed and that disrupted how the game unfolds (it doesn't break it, but it's not the easiest thing to deal with the first time). Initially, I had the feeling that the addition of options and depth did not compensate for the loss of the fluid pace of the original.\\n\\nIn the last one I participated, the same thing happened with the initial markets and we said fuggit, and we shuffled them again. With the rules more polished and more open markets, the game flew with the fluidity that I remembered the original had, so I reconciled myself with this new version.\\n\\nBut you have to use the side of the board during the day, the side of the board at night, unless you use a miner's helmet with light, you can't distinguish a knob.\\n\\nI also don't know what the game will bring as money, because we always use poker chips.\\n\\nA classic that preserves the best of the Eurogames from that era: depth, options, decisions, interaction, fluidity, with an updated card.\\n\\nHighly recommended :star::star::star::star::nostar:', 'reviewer_country': 'Argentina', 'rating': 9.0, 'date': '2019-08-27 09:30:40', 'is_owner': False}",
#  "{'review': 'SpielboxRating 9-10, by. 9,20', 'reviewer_country': 'Germany', 'rating': 0.0, 'date': '2025-03-01 17:14:41', 'is_owner': False}",
#  '{\'review\': "Much more fun than the (old) original version. This took a few plays to grow on me. No in game text, has a central board and good balance between tactical and strategical play. Maybe a bit on the long side, but it\'s a really nail-biter till the end. I can see why this is rated so high as it is.", \'reviewer_country\': \'\', \'rating\': 8.5, \'date\': \'2023-05-04 17:22:16\', \'is_owner\': False}',
#  '{\'review\': "It\'s a great game, would struggle to get consistent plays.", \'reviewer_country\': \'United States\', \'rating\': 8.0, \'date\': \'2021-04-11 20:17:03\', \'is_owner\': False}',
#  "{'review': '+ 3D Printed insert\\n+ Sleeves', 'reviewer_country': 'Slovakia', 'rating': 8.5, 'date': '2024-09-11 07:11:51', 'is_owner': False}",
#  "{'review': 'I enjoy Lancashire and want to add this one to my collection at some point.', 'reviewer_country': '', 'rating': 0.0, 'date': '2024-11-08 11:08:43', 'is_owner': False}",
#  "{'review': 'Very clean average Euro.', 'reviewer_country': 'Spain', 'rating': 9.0, 'date': '2025-11-06 04:14:42', 'is_owner': True}",
#  "{'review': 'Great game!', 'reviewer_country': 'Indonesia', 'rating': 8.0, 'date': '2025-10-22 08:23:42', 'is_owner': True}",
#  "{'review': 'It's dry and the rules are hard to memorize compared to other games of the same weight. The main mechanism is classically simple, like Catan, even for a 2018 game. Replayability is also questionable if played with the same members. Conclusion Fun is simple, understanding is difficult.', 'reviewer_country': '', 'rating': 1.0, 'date': '2025-11-05 20:41:41', 'is_owner': False}",
#  "{'review': 'Great game\\n-scratches the economic itch\\n-tight gameplay, but does not feel too limiting\\n-not too long after you learn\\n-straightforward ways to score\\n-has a semi cooperative element to the game which make other players turns more interesting  \\n-can be a bit tough to learn/teach first time\\n-rules can feel contradicting when learning', 'reviewer_country': 'United States', 'rating': 9.0, 'date': '2025-11-05 18:34:23', 'is_owner': True}",
#  "{'review': 'kickstarter', 'reviewer_country': 'Czech Republic', 'rating': 9.5, 'date': '2018-08-02 10:34:01', 'is_owner': True}",
#  "{'review': '+ Engaging tactics and strategy\\n+ Agonizing decisions and tradeoffs\\n+ Tight economy\\n+ Player interaction\\n+ Climactic ending\\n- AP prone\\n- Finicky rules and fiddliness\\n- Downtime', 'reviewer_country': '', 'rating': 8.0, 'date': '2025-08-24 07:20:11', 'is_owner': False}",
#  '{\'review\': "BRASS BIRMINGHAM (2-4 players)\\n\\nDeluxe player aids: https://boardgamegeek.com/filepage/179522/deluxe-player-aids-brass-birmingham\\n\\nFanmade solo variant: \\n\\nhttp://www.mautoma.com/mautomas/brass-birmingham \\n\\nOnline app for solo variant so you don\'t have to print the cards: \\n\\nhttps://boardgamegeek.com/filepage/168370/brass-birmingham-george-solo-competitive-mode\\n\\nBrass Birmingham is better than Brass Lancashire. The Mautoma Solo variant is quite good but I prefer to play Brass as a multiplayer game. The game is a dry euro but a VERY good dry euro.", \'reviewer_country\': \'Belgium\', \'rating\': 9.0, \'date\': \'2020-04-16 14:52:47\', \'is_owner\': True}',
#  "{'review': 'Rules that are a bit obtuse, with exceptions and many details that make you have to constantly review them. The explanation must be prepared well, it is not easy to assimilate the concepts. \\n\\nI like that everyone participates on the central board and can take advantage of each other's routes and resources, there is a lot of interaction, without a doubt what I like most about the game. The editing is cool too. However, the game has too many unintuitive rules and too many details to keep an eye on (it can lead to long turns). Seeing that it is such a beloved game, I have given it several chances but it is definitely not my thing.', 'reviewer_country': 'Spain', 'rating': 5.0, 'date': '2019-09-21 03:01:46', 'is_owner': False}",
#  "{'review': 'It’s Brass with a more-is-better approach: more buildings, more locations, more connections—and then beer. Less cutthroat and leaning toward a point-salad feel. The high rail scoring makes the rail era predictable, though some might see it as a more forgiving, flexible evolution of the original. Could rate higher, but I’d always pick Lancashire over this, which brings the rating down a bit.', 'reviewer_country': 'Sweden', 'rating': 8.0, 'date': '2021-01-07 16:52:10', 'is_owner': False}",
#  "{'review': 'Boardroom, PAX, 4 2-4, 2h', 'reviewer_country': '', 'rating': 0.0, 'date': '2024-11-18 20:49:11', 'is_owner': False}",
#  '{\'review\': "That\'s the most boring and ugly game I\'ve ever played. Viscous snot is the most suitable description for it. 1000% overrated.", \'reviewer_country\': \'\', \'rating\': 1.0, \'date\': \'2025-11-04 11:20:33\', \'is_owner\': False}',
#  "{'review': 'Loved playing and would recommend playing but did take us 4 and a half hours to learn and play as a 3. Worth it though', 'reviewer_country': 'United Kingdom', 'rating': 9.0, 'date': '2025-11-04 08:46:21', 'is_owner': False}",
#  "{'review': 'Sleeved with Shield Titan Super Sleeves (Clear)\\nInsert included', 'reviewer_country': '', 'rating': 9.0, 'date': '2023-01-27 07:53:43', 'is_owner': True}",
#  '{\'review\': "Tentative rating.\\n\\nI understand how this game got its reputation. The puzzle involved is unique, which is such a rarity among the hundreds of Euros we see each year. It felt like the game is stimulating a whole new part of my brain\'s strategy center that I didn\'t know existed, and I love it.\\n\\nThe game is complex, the strategy is opaque, and it was a pain to teach with all of its minor titbits and exceptions. However, these won\'t matter after 20+ plays, and the game is solid enough to warrant that.", \'reviewer_country\': \'Hong Kong\', \'rating\': 9.0, \'date\': \'2025-11-03 20:53:07\', \'is_owner\': False}',
#  "{'review': '3.87', 'reviewer_country': 'Chile', 'rating': 0.0, 'date': '2021-07-13 22:37:56', 'is_owner': True}",
#  "{'review': 'great euro styled game.\\nflow of interaction is just a masterpiece.\\nMartin is genious.', 'reviewer_country': 'South Korea', 'rating': 8.9, 'date': '2023-05-31 10:49:56', 'is_owner': False}",
#  "{'review': 'Less fluid than the black edition.', 'reviewer_country': 'Italy', 'rating': 6.0, 'date': '2017-04-22 01:38:44', 'is_owner': True}",
#  '{\'review\': "In my opinion, Lancashire is much better.\\n\\nLancashire is more straightforward and you focus on the strategy. You don\'t get tired of the multitude of tokens, in Lancashire there is only the essential ones. \\n\\nAfter playing Birmingham I always felt exhausted, but still liked the game. However, after playing Lancashire the time just flew and I would have wanted to play again right away.", \'reviewer_country\': \'Hungary\', \'rating\': 0.0, \'date\': \'2018-10-26 17:42:27\', \'is_owner\': False}',
#  '{\'review\': "Too many little nit-picky rules.  It\'s fine, but I always get frustrated when I play it.  Wish it was a little more intuitive and elegant in its design.  I can see why people like it - my group loves it - just not my favorite.", \'reviewer_country\': \'\', \'rating\': 6.0, \'date\': \'2024-11-30 06:42:49\', \'is_owner\': False}',
#  "{'review': '25\\n50€', 'reviewer_country': 'Netherlands', 'rating': 9.0, 'date': '2025-03-02 07:49:01', 'is_owner': False}",
# ...
#  "{'review': 'Dinged corner,', 'reviewer_country': 'United States', 'rating': 9.0, 'date': '2020-12-01 04:34:11', 'is_owner': True}",
#  "{'review': '[76] 65x90 boardm sleeve', 'reviewer_country': 'South Korea', 'rating': 0.0, 'date': '2019-01-18 07:55:36', 'is_owner': True}",
#  '{\'review\': "Great network building and resource management game. \\n\\nInterestingly, this game has many actions where the action you\'re taking benefits yourself, but also another player. For example, you can take other players\' resources on building they\'ve built, but they want their buildings to be emptied so that their building tiles can be flipped and score them points and income.\\n\\nThere is a soft reset of the board in the middle of the game as well, which is definitely something to consider. If you manage to get out one of your buildings that don\'t get removed by this soft reset after the first era, they will score twice.\\n\\nI have heard countless times that this game was very cutthroat, but honestly, I didn\'t find it so compared to other network building games. Yes, you can cut someone\'s network short with your own, but that means you\'re likely cutting your own network too. Other players can use each other\'s networks anyway in many cases. I guess you can steal other players\' building spots, but that is not enough to call a game cutthroat for me. i don\'t generally like cutthroat games, but I did like this.", \'reviewer_country\': \'Canada\', \'rating\': 9.5, \'date\': \'2021-10-21 20:52:53\', \'is_owner\': True}',
#  '{\'review\': "Friend\'s game", \'reviewer_country\': \'United Kingdom\', \'rating\': 5.0, \'date\': \'2024-01-26 10:06:02\', \'is_owner\': False}',
#  "{'review': '280', 'reviewer_country': 'Romania', 'rating': 0.0, 'date': '2025-04-22 06:23:39', 'is_owner': True}",
#  "{'review': 'Challenging One.', 'reviewer_country': 'South Korea', 'rating': 9.0, 'date': '2020-10-30 02:18:31', 'is_owner': False}",
#  '{\'review\': "A very, very good game. I\'ll come back with pleasure", \'reviewer_country\': \'France\', \'rating\': 8.0, \'date\': \'2025-04-21 03:36:11\', \'is_owner\': False}',
#  "{'review': 'Olga 3\\nOmar 1', 'reviewer_country': '', 'rating': 9.1, 'date': '2021-04-18 02:18:37', 'is_owner': True}",
#  "{'review': 'A truly remarkable game.', 'reviewer_country': 'Serbia', 'rating': 10.0, 'date': '2021-03-29 08:51:28', 'is_owner': True}",
#  "{'review': 'Easy to get into but really hard on the brain to progress. Always in debt too.\\nPlays brilliantly', 'reviewer_country': 'United Kingdom', 'rating': 10.0, 'date': '2019-06-10 11:05:36', 'is_owner': True}",
#  "{'review': 'The game itself is very neat and fun, but when I started thinking about just earning points through the network, the illusion disappeared a bit.', 'reviewer_country': '', 'rating': 8.9, 'date': '2021-11-04 09:41:54', 'is_owner': True}",
#  '{\'review\': "I think the more I play this the higher it will go. I played two-handed, but I can\'t stop thinking about it...", \'reviewer_country\': \'United States\', \'rating\': 7.5, \'date\': \'2018-08-29 16:20:06\', \'is_owner\': True}',
#  "{'review': 'In UK', 'reviewer_country': 'United Kingdom', 'rating': 0.0, 'date': '2025-04-19 16:53:14', 'is_owner': True}",
#  "{'review': 'Awesome game! (Very hard to play after a longer break.) 2nd phase is more fun than 1st phase.\\nBrain-burner. Feels really good to pull off a strategy.', 'reviewer_country': '', 'rating': 8.5, 'date': '2021-05-25 04:49:34', 'is_owner': True}",
#  "{'review': 'Derrick, Jessica, Jack?', 'reviewer_country': 'United States', 'rating': 8.75, 'date': '2023-05-09 19:28:40', 'is_owner': False}",
#  "{'review': '3-4 players', 'reviewer_country': 'France', 'rating': 0.0, 'date': '2025-04-19 03:31:41', 'is_owner': True}",
#  "{'review': 'i had a lot of fun playing this game with friends', 'reviewer_country': 'United States', 'rating': 10.0, 'date': '2025-04-18 21:28:27', 'is_owner': True}",
#  "{'review': 'Amazing game at every player count.', 'reviewer_country': 'Germany', 'rating': 10.0, 'date': '2022-11-26 14:20:04', 'is_owner': True}",
#  "{'review': '#1 on BGG for a long time - would like to play!', 'reviewer_country': 'United States', 'rating': 0.0, 'date': '2022-10-19 16:29:44', 'is_owner': False}",
#  '{\'review\': "The more I play the more I am converted. What I thought was a smart but hollow experience is now one of my most excited games to table. The balance of tactical plays, strategic planning, and player interaction, all wrapped in (what I think) is a beautiful package and theme, makes it clear why this is the King. It\'s not my favourite game, but damnit if it\'s not a brilliant one.", \'reviewer_country\': \'Singapore\', \'rating\': 9.0, \'date\': \'2023-07-09 02:34:02\', \'is_owner\': False}',
#  "{'review': 'Original', 'reviewer_country': 'Serbia', 'rating': 0.0, 'date': '2025-04-18 05:20:03', 'is_owner': True}",
#  "{'review': 'Been in the cupboard for years.  Finally got to play with 2 great teachers and none of us are AP prone.\\n\\nBrilliant, loved every second.  I think it does depend on the people at the table like most games.  Any AP prone people at the table would kill this for me.\\n\\nWorthy of being top 10 game, not sure about number 1 though ;-)', 'reviewer_country': '', 'rating': 9.0, 'date': '2020-05-07 05:45:31', 'is_owner': True}",
#  '{\'review\': "One of the most responsive strategy games. And one of the best Euro\'s out there. More flexible than Brass: Lancashire. Very very good game. could be a bit stuffy. \\n", \'reviewer_country\': \'United States\', \'rating\': 0.0, \'date\': \'2025-04-17 17:23:07\', \'is_owner\': False}',
#  '{\'review\': "Only one game at 4. If it wasn\'t 1st in the bgg rankings I wouldn\'t even consider playing again.", \'reviewer_country\': \'\', \'rating\': 0.0, \'date\': \'2022-06-07 10:50:02\', \'is_owner\': False}',
#  '{\'review\': "- first couple of games you will simply try to understand the rules and flip a few tiles across a few industries, then you move on and start developing level I buildings and focus on two or three industries, maybe you even start messing around with the wild cards, at some point you then realize it is really important to flip tiles before the end of the first era and that you should to flip multiple tiles in one move, build multiple connections in one move, buy coal/iron when it\'s cheap and so on. It is all about the action efficiency, stupid! :)\\n- you are working towards your own goals but along the way other players will most likely also benefit from your activities - and vice versa. Whether it is building a connection or supplying resources. Sometimes it makes me wonder: so this is how capitalism works - everyone works for their own advantage but it somehow all falls into place and everyone is better off?!? On average at least…\\n- yet you can also hurt other players by occupying spaces they have had their eyes on or forcing them to connect your network to dealers \\n- beautiful map and art although a bit too much the dark side ", \'reviewer_country\': \'Germany\', \'rating\': 9.0, \'date\': \'2021-02-22 17:35:26\', \'is_owner\': True}',
#  "{'review': 'Just great!', 'reviewer_country': '', 'rating': 9.0, 'date': '2025-04-17 07:12:48', 'is_owner': True}",
#  "{'review': '+ insert reDrewno, iron clays 200', 'reviewer_country': 'Poland', 'rating': 9.0, 'date': '2020-10-21 17:19:47', 'is_owner': True}",
#  "{'review': 'David S. has it (March 2025)', 'reviewer_country': 'Spain', 'rating': 9.0, 'date': '2019-01-26 12:42:26', 'is_owner': True}",
#  "{'review': 'Owner: Katie', 'reviewer_country': 'United Kingdom', 'rating': 9.3, 'date': '2023-12-20 06:11:58', 'is_owner': True}",
#  '{\'review\': "Introduced this game by my mate and I can\'t stop thinking about it afterwards. Got myself a deluxe copy and played with my SO and she loves it too. My first 10 rating euro game in my collection, is almost flawless, would really like to try Lancashire next and hopefully more Brass games will come out in the future.", \'reviewer_country\': \'Australia\', \'rating\': 9.0, \'date\': \'2019-11-29 05:58:12\', \'is_owner\': True}',
#  '{\'review\': "Beautiful in it\'s design, and elegant.\\n\\nI can\'t believe how much I enjoyed this game, and it\'s worth all of the praise it gets. It scales uniquely from 2-4 players, and even has a fairly accessible \'Short\' version.\\n\\nA little finnicky, and hard to grapple with on the first go through, but you\'ll catch yourself wanting to push harder and harder for more efficiency on the next play.", \'reviewer_country\': \'\', \'rating\': 10.0, \'date\': \'2024-10-23 11:28:46\', \'is_owner\': True}',
#  "{'review': 'No necessary in-game text', 'reviewer_country': '', 'rating': 0.0, 'date': '2025-03-31 17:01:03', 'is_owner': True}",
#  "{'review': '2-4p', 'reviewer_country': 'Canada', 'rating': 0.0, 'date': '2024-07-16 03:04:19', 'is_owner': True}",
#  '{\'review\': "Incredible game. The rules are surprisingly not intimidating, it\'s strange. There\'s really only a few actions you\'re taking and you\'re limited to the cards in your hand, but there\'s an astonishing amount to consider. The nature of the rules and actions also result in new players feeling completely lost for the first half of the game. Thankfully there is an option to just only play one half. You lose out on a lot of the meaty planning ahead strategy, but new players can\'t comprehend that anyway. Allows you to still play through a teaching game in a couple of hours. The only bummer for me is so far I have mostly only played teaching/half games. \\n\\nStill my favorite economic game out there, it\'s a lot to sit down, setup and teach, but it\'s worth it every time. ", \'reviewer_country\': \'United States\', \'rating\': 8.5, \'date\': \'2018-07-06 10:37:42\', \'is_owner\': True}',
#  "{'review': 'Not my cup of tea, but I can see why people love it.\\nVery euro, but also very interactive. First plays can be very punishing for new players.\\nIt is easy to teach, but there are many nuances difficult to remember and spot when playing. It can cause AP very easily. I would not seek it but I can play it again', 'reviewer_country': 'Canada', 'rating': 6.0, 'date': '2024-05-02 07:59:08', 'is_owner': False}",
#  "{'review': 'Played at ampthill on board. Complex but worth a second play.', 'reviewer_country': 'United Kingdom', 'rating': 0.0, 'date': '2025-03-09 12:42:54', 'is_owner': False}",
#  "{'review': 'I like Lancashire a bit better but these games are good enough to warrant owning and playing two slightly different versions.', 'reviewer_country': 'United States', 'rating': 8.0, 'date': '2021-11-22 13:10:03', 'is_owner': True}",
#  "{'review': '8.5', 'reviewer_country': 'Germany', 'rating': 8.0, 'date': '2020-01-30 10:56:32', 'is_owner': False}",
#  '{\'review\': "Step back in time - entrenched in the theme - working 29hours a day at mill… young folk just wouldn\'t believe you. Fantastic! ", \'reviewer_country\': \'\', \'rating\': 9.0, \'date\': \'2021-08-08 17:40:31\', \'is_owner\': True}',
#  '{\'review\': "One of, if not, my favorite board games. Lots of different strategies but you can\'t stick to one thing and have to adapt to what other players are doing. \\n\\nLove its blend of pvp + pve. Love the quality, design, everything.", \'reviewer_country\': \'Indonesia\', \'rating\': 10.0, \'date\': \'2025-04-14 00:19:41\', \'is_owner\': True}',
#  "{'review': 'Best 3-4\\n(Sleeved)\\nKR+', 'reviewer_country': 'United Kingdom', 'rating': 10.0, 'date': '2025-04-12 20:05:59', 'is_owner': True}",
#  "{'review': 'Birthday present Sept. 2024', 'reviewer_country': 'United Kingdom', 'rating': 0.0, 'date': '2025-04-12 17:30:54', 'is_owner': True}",
#  '{\'review\': \'Description in Spanish: Euro-rated "route/network construction" game based on the Industrial Revolution\', \'reviewer_country\': \'Chile\', \'rating\': 7.5, \'date\': \'2024-10-22 17:07:26\', \'is_owner\': True}',
#  '{\'review\': "Sleeved (FFG Grey)\\nTinkertown 25 iron and 30 \'coal\' cubes", \'reviewer_country\': \'United Kingdom\', \'rating\': 9.0, \'date\': \'2019-03-06 15:04:55\', \'is_owner\': True}',
#  "{'review': 'Cegieł', 'reviewer_country': 'Poland', 'rating': 0.0, 'date': '2021-07-07 17:38:08', 'is_owner': False}",
#  "{'review': '2-4', 'reviewer_country': '', 'rating': 0.0, 'date': '2025-04-12 07:48:24', 'is_owner': True}",
#  "{'review': 'La Obra maestra del tito wallace❤️', 'reviewer_country': 'Spain', 'rating': 10.0, 'date': '2025-04-12 00:38:28', 'is_owner': True}",
#  '{\'review\': "I\'m still a novice with less than 10 plays under my belt, but this could be a top 5 game for me. I find the interaction between the players as the resource network grows to be so fascinating and unique. I\'ll revisit my rating once I have more plays under my belt", \'reviewer_country\': \'Australia\', \'rating\': 9.5, \'date\': \'2019-08-03 02:08:04\', \'is_owner\': True}',
#  "{'review': 'The setup is fiddly and the rules are overly complex.\\n* Sold by Timeless Board Games for me *', 'reviewer_country': 'South Africa', 'rating': 0.0, 'date': '2018-08-12 11:30:47', 'is_owner': False}",
#  '{\'review\': "I have the kickstarter Deluxe edition. It looks sooooo pretty that I don\'t want to play it. There is no game in my possession with a better build quality", \'reviewer_country\': \'United States\', \'rating\': 9.0, \'date\': \'2017-04-26 10:43:20\', \'is_owner\': True}',
#  '{\'review\': "A good game. I personaly prefer Lancashire because it\'s a more streamlined version.In my opinion the game already was good enough. But this is still a good one.", \'reviewer_country\': \'Ukraine\', \'rating\': 7.0, \'date\': \'2025-04-11 05:13:34\', \'is_owner\': False}',
#  '{\'review\': "Upgraded it to 9 and potentially to 10 moving forward. It does take a few plays to get around the ridiculous way goods transport around the map but once you accept that it\'s a great game.\\n\\nUpgraded to 6 after two plays. Still think it\'s fiddly as hell but it\'s definitely an interesting game.\\n\\nGiving it a reluctant 3 after one first play.\\nSuper fiddly unintuitive rules:\\n- Different ways the resources travel\\n- The fact that lvl 1 buildings get cleared from the main board but not your personal board\\n- 1 action for the 1st turn only for some reason\\n- Can use bonus beer to ship goods but not to build tracks during phase 2\\n\\nReally hated the fact that you play canal part and then reset the game and count scores to play the rail phase with some useless buildings on the board you can\'t reuse. I took effort to develop and place lvl 2 buildings on the board and I can\'t reflip them for extra income, beer, etc? \\n\\nAlso the fact that you see the scores at the end of the canal phase, if you\'re quite far behind doesn\'t make you want to play the second phase anymore.\\n\\nEtc, etc.\\n\\nI basically liked nothing about the game after this first play.", \'reviewer_country\': \'Portugal\', \'rating\': 9.0, \'date\': \'2022-02-23 07:39:42\', \'is_owner\': False}',
#  '{\'review\': "In friends\' collection: I usually wait until I played games a few times before I do a first rating, but this game is an exception. The first time I played this game was already amazing and I can\'t stop thinking about new strategies I want to try. I\'m looking forward to my next play of the game. This is exactly the type of game I love. It does all the things I want in a game and it does them right. ", \'reviewer_country\': \'\', \'rating\': 10.0, \'date\': \'2025-04-11 02:00:49\', \'is_owner\': False}',
#  "{'review': 'Martin Wallace economic game masterpiece.', 'reviewer_country': 'United States', 'rating': 10.0, 'date': '2025-03-17 22:43:40', 'is_owner': False}",
#  "{'review': 'Critical Thinking\\nEconomics\\nManagement\\nMath and Numeracy\\nProblem Solving', 'reviewer_country': '', 'rating': 0.0, 'date': '2025-04-07 15:16:44', 'is_owner': True}",
#  "{'review': 'Great game', 'reviewer_country': 'United States', 'rating': 10.0, 'date': '2025-04-10 07:13:31', 'is_owner': True}",
#  ...]

# %%
data[0]["game_reviews"]
# Out:
# [{'review': '2-4 [S]',
#   'reviewer_country': 'Italy',
#   'rating': 0.0,
#   'date': '2025-09-24 17:47:08',
#   'is_owner': True},
#  {'review': 'Great game that somehow feels simple, yet every decision you make carries weight\n',
#   'reviewer_country': '',
#   'rating': 8.5,
#   'date': '2021-02-25 08:42:44',
#   'is_owner': False},
#  {'review': "If you can play this in 60 minutes you're playing too fast.  With my group a a game lasts about 45 minutes per player.\n\nKeep pushing up my rating..  This game continues to be my favorite and the favorite of our group.",
#   'reviewer_country': 'United States',
#   'rating': 9.4,
#   'date': '2024-07-10 16:55:53',
#   'is_owner': True},
#  {'review': 'Tabletop',
#   'reviewer_country': 'United States',
#   'rating': 0.0,
#   'date': '2025-02-01 17:35:35',
#   'is_owner': True},
#  {'review': 'I only played half a real game, but I was captivated throughout. Would play again.',
#   'reviewer_country': 'United States',
#   'rating': 8.7,
#   'date': '2025-11-10 19:17:57',
#   'is_owner': False},
#  {'review': 'Ship',
#   'reviewer_country': 'Hong Kong',
#   'rating': 10.0,
#   'date': '2017-08-02 02:10:40',
#   'is_owner': True},
#  {'review': "The more I play, the more I realize it's more about playing the hand you're dealt, and less about strategy",
#   'reviewer_country': 'United States',
#   'rating': 7.0,
#   'date': '2022-11-18 00:53:44',
#   'is_owner': False},
#  {'review': 'Very good game. I might not say it is the best of all times, but it is definetely great. The mechanics are simple, but I consider that it takes a little time to adapt to them. You may need several playthroughs to achieve some sort of mastering. Revise every victory point possibility to plan your strategy, otherwise, it can be easy to fall pursuing things that are not profitable in the long term.',
#   'reviewer_country': 'Paraguay',
#   'rating': 8.0,
#   'date': '2024-11-26 12:06:53',
#   'is_owner': True},
#  {'review': "+ Artwork is great\n+ Great strategy game\n+ Lots of interaction\n+ Low luck factor\n+ Many paths to victory\n+ Brain burner \n- Quite long\n- Rules heavy \n- Theme is a bit boring\n\nDeep strategic economic game with many ways to win the game. It is surprisingly enough very interactive. I've only played it at 2 and 3 player count. ",
#   'reviewer_country': 'Belgium',
#   'rating': 8.5,
#   'date': '2022-01-18 08:40:16',
#   'is_owner': True},
#  {'review': 'Не фанат евро, это могло быть неплохо, не против сыграть в нее снова, если что, но сам предлагать ее не буду. И да, это точно не первое место BGG.',
#   'reviewer_country': 'Belarus',
#   'rating': 6.0,
#   'date': '2025-09-06 08:12:40',
#   'is_owner': False},
#  {'review': 'Most of my plays have been at 2p, and I thoroughly enjoyed every single game. \nHowever, it feels like it ends very quickly at 4p (a feeling it seems others at my table tend to have as well). \n\n',
#   'reviewer_country': 'Switzerland',
#   'rating': 9.5,
#   'date': '2024-12-17 10:40:53',
#   'is_owner': True},
#  {'review': 'Pt: 3',
#   'reviewer_country': '',
#   'rating': 0.0,
#   'date': '2025-11-10 00:00:59',
#   'is_owner': True},
#  {'review': 'In: October 2025',
#   'reviewer_country': '',
#   'rating': 0.0,
#   'date': '2024-05-23 23:31:31',
#   'is_owner': True},
#  {'review': 'ES',
#   'reviewer_country': '',
#   'rating': 9.0,
#   'date': '2021-01-26 00:30:31',
#   'is_owner': True},
#  {'review': 'M.Heavy Euro - Wallace, Trains',
#   'reviewer_country': 'United States',
#   'rating': 9.3,
#   'date': '2017-04-19 05:07:02',
#   'is_owner': True},
#  {'review': "Arguably the best strategic area control, resource management game.  Just make sure you use other peoples beer and don't let them use yours.",
#   'reviewer_country': 'United States',
#   'rating': 8.5,
#   'date': '2019-02-16 16:05:39',
#   'is_owner': False},
#  {'review': 'Epic',
#   'reviewer_country': '',
#   'rating': 0.0,
#   'date': '2024-12-26 12:13:56',
#   'is_owner': False},
#  {'review': "haven't played it enough to really understand it. Heavy and thinky. need to log more plays",
#   'reviewer_country': 'United States',
#   'rating': 7.0,
#   'date': '2025-02-25 14:52:24',
#   'is_owner': True},
#  {'review': "Brass est un jeu qui doit beaucoup de son succès à sa capacité à offrir peu de prises à la critique (hasard peu présent, édition irréprochable, thème mature, jeu élitiste). C'est un jeu surestimé qui surfe sur les défauts du classement BGG (les rééditions ont des notes excessivement hautes, surtout avec une refonte graphique et un matériel abondant hyper qualitatif. Ces rééditions prêchent des convaincus qui surnotent leurs jeux favoris au travers d'une nouvelle entrée sur BGG).",
#   'reviewer_country': 'France',
#   'rating': 7.0,
#   'date': '2023-06-21 04:28:52',
#   'is_owner': False},
#  {'review': 'Your first game is likely going to be rough. However no doubt you will see the appeal of building up your own niche economy that ends up frustratingly reliant on and sometimes in favor the other players. At the end of each round you will be left going "oh I wish I did that," or "things could have gone well if you didn\'t do that", but still be left to admire how everything resulted in the end. After that rough first game, you are most likely going to arrange for another game, all to get better at this system.',
#   'reviewer_country': 'Australia',
#   'rating': 9.0,
#   'date': '2025-07-04 05:16:12',
#   'is_owner': True},
#  {'review': 'B3u4, G2',
#   'reviewer_country': 'Germany',
#   'rating': 8.5,
#   'date': '2020-10-30 08:16:32',
#   'is_owner': True},
#  {'review': 'Regal 14',
#   'reviewer_country': 'Germany',
#   'rating': 0.0,
#   'date': '2021-11-01 11:06:57',
#   'is_owner': True},
#  {'review': '£67.85 https://www.amazon.co.uk/Roxley-Games-ROX402-Brass-Birmingham/dp/1988884047?crid=2I7084BPZPFR5&dib=eyJ2IjoiMSJ9.AKBvx-qCEQ1s2PviGSbDhYyDSrcdKdGtfSi_ilfJCheyjNb5lf8iB5Kr8USCrowvqXNUC7k-hRITiyTddwAp1e-vXgssxL4xuGJa3X2ETt8Np9UmhR4kjr6WpnTMDMRj_VvxWnEgN6AY7c15BtQ-aWQy9Jis6jXCz3utNAtdZ5rT2epjPFsa2S4Te8RikY2S8yEHoXlcbHAEnprGxF1cy7ivg7o24JuypogPNga_UZOPS_Psun_ySg-365rKRCq8i06CmiXpEVyVf83N0o-ViZGc70ox5rE1PqNQ2yb6k4I.VZKtGk37XxVIkuMPPcDUbbo9eBxUHUpzCjO7chxTe9k&dib_tag=se&keywords=brass%2Bbirmingham%2Bboard%2Bgame&qid=1762604991&sprefix=brass%2B%2Caps%2C123&sr=8-4&th=1',
#   'reviewer_country': '',
#   'rating': 0.0,
#   'date': '2025-11-08 10:05:06',
#   'is_owner': False},
#  {'review': "Previously 9. The more you play this game the more it shines!\n\nIt has a relatively simple rule set with incredible depth. No need for expansions.... It's a modern classic.\n\nIf you like strategy without the need to attack your opponents to win, this is for you.\n\nThe interplay of you using up the other players resources benefitting both you and them is very satisfying and keeps everyone engaged.\n\nGreat family strategic game! ",
#   'reviewer_country': 'Ireland',
#   'rating': 10.0,
#   'date': '2024-05-09 09:36:06',
#   'is_owner': True},
#  {'review': 'I loathe this as much as I loathed the original Brass. And now add in hunger games for beer. \n\nOne and done.\n\nThe #1 game on BGG? Someone euthanize me.',
#   'reviewer_country': 'Canada',
#   'rating': 3.0,
#   'date': '2025-11-07 16:06:34',
#   'is_owner': False},
#  {'review': 'Tedious and boring VP pusher with instant railway transition. Not my cup of tea? No, I’d rather smear my genitalia with fish paste and dangle them in a pool of hungry piranha. \n\nDingo',
#   'reviewer_country': '',
#   'rating': 2.0,
#   'date': '2018-09-30 09:38:56',
#   'is_owner': False},
#  {'review': 'La primera partida había sido media trabada. En parte por las nuevas reglas y en parte porque, en el azar de la distribución de mercados iniciales, terminamos con uno de ellos cerrado y eso trastocó cómo se desenvuelve la partida (no lo rompe, pero no es lo más fácil de encarar la primera vez). En principio, me había dejado la sensación de que el agregado de opciones y profundidad no compensaba la pérdida del paso fluido del original.\n\nEn la última que participé, pasó lo mismo con los mercados iniciales y dijimos fuggit, y los shuffleamos de nuevo. Con las reglas más aceitadas y más mercados abiertos, la partida voló con la fluidez que recordaba que tenía el original, así que me reconcilié con esta nueva versión.\n\nPero hay que usar el lado del tablero de día, el lado del tablero de noche, salvo que uses un casco de minero con luz, no se distingue un pomo.\n\nTampoco sé qué traerá el juego como dinero, porque siempre usamos fichas de póker.\n\nUn clásico que conserva lo mejor de los eurojuegos de esa época: profundidad, opciones, decisiones, interacción, fluidez, con un cromo actualizado.\n\nMuy recomendable :star::star::star::star::nostar:',
#   'reviewer_country': 'Argentina',
#   'rating': 9.0,
#   'date': '2019-08-27 09:30:40',
#   'is_owner': False},
#  {'review': 'SpielboxRating 9-10, av. 9,20',
#   'reviewer_country': 'Germany',
#   'rating': 0.0,
#   'date': '2025-03-01 17:14:41',
#   'is_owner': False},
#  {'review': "Much more fun than the (old) original version. This took a few plays to grow on me. No in game text, has a central board and good balance between tactical and strategical play. Maybe a bit on the long side, but it's a really nail-biter till the end. I can see why this is rated so high as it is.",
#   'reviewer_country': '',
#   'rating': 8.5,
#   'date': '2023-05-04 17:22:16',
#   'is_owner': False},
#  {'review': "It's a great game, would struggle to get consistent plays.",
#   'reviewer_country': 'United States',
#   'rating': 8.0,
#   'date': '2021-04-11 20:17:03',
#   'is_owner': False},
#  {'review': '+ 3D Printed insert\n+ Sleeves',
#   'reviewer_country': 'Slovakia',
#   'rating': 8.5,
#   'date': '2024-09-11 07:11:51',
#   'is_owner': False},
#  {'review': 'I enjoy Lancashire and want to add this one to my collection at some point.',
#   'reviewer_country': '',
#   'rating': 0.0,
#   'date': '2024-11-08 11:08:43',
#   'is_owner': False},
#  {'review': 'Euro medio muy limpio.',
#   'reviewer_country': 'Spain',
#   'rating': 9.0,
#   'date': '2025-11-06 04:14:42',
#   'is_owner': True},
#  {'review': 'Great game!',
#   'reviewer_country': 'Indonesia',
#   'rating': 8.0,
#   'date': '2025-10-22 08:23:42',
#   'is_owner': True},
#  {'review': '건조하고 같은 웨이트 대 게임들과 비교 했을 때 룰이 잘 안 외워지는 편. 메인 메커니즘은 2018년 게임치곤 카탄처럼 고전 특유의 단순함. 같은 멤버로 할 경우 리플레이성도 의문임. 결론 재미는 단순하고 이해는 어려움.',
#   'reviewer_country': '',
#   'rating': 1.0,
#   'date': '2025-11-05 20:41:41',
#   'is_owner': False},
#  {'review': 'Great game\n-scratches the economic itch\n-tight gameplay, but does not feel too limiting\n-not too long after you learn\n-straightforward ways to score\n-has a semi cooperative element to the game which make other players turns more interesting  \n-can be a bit tough to learn/teach first time\n-rules can feel contradicting when learning',
#   'reviewer_country': 'United States',
#   'rating': 9.0,
#   'date': '2025-11-05 18:34:23',
#   'is_owner': True},
#  {'review': 'kickstarter',
#   'reviewer_country': 'Czech Republic',
#   'rating': 9.5,
#   'date': '2018-08-02 10:34:01',
#   'is_owner': True},
#  {'review': '+ Engaging tactics and strategy\n+ Agonizing decisions and tradeoffs\n+ Tight economy\n+ Player interaction\n+ Climactic ending\n- AP prone\n- Finicky rules and fiddliness\n- Downtime',
#   'reviewer_country': '',
#   'rating': 8.0,
#   'date': '2025-08-24 07:20:11',
#   'is_owner': False},
#  {'review': "BRASS BIRMINGHAM (2-4 players)\n\nDeluxe player aids: https://boardgamegeek.com/filepage/179522/deluxe-player-aids-brass-birmingham\n\nFanmade solo variant: \n\nhttp://www.mautoma.com/mautomas/brass-birmingham \n\nOnline app for solo variant so you don't have to print the cards: \n\nhttps://boardgamegeek.com/filepage/168370/brass-birmingham-george-solo-competitive-mode\n\nBrass Birmingham is better than Brass Lancashire. The Mautoma Solo variant is quite good but I prefer to play Brass as a multiplayer game. The game is a dry euro but a VERY good dry euro.",
#   'reviewer_country': 'Belgium',
#   'rating': 9.0,
#   'date': '2020-04-16 14:52:47',
#   'is_owner': True},
#  {'review': 'Reglas un poco obtusas, con excepciones y muchos detalles que hacen que tengas que estar revisándolas constantemente. La explicación hay que preparársela bien, no es sencillo asimilar los conceptos. \n\nMe gusta que todo el mundo participe en el tablero central y que pueda aprovecharse de las rutas y recursos de los demás, hay mucha interacción, sin duda lo que más me gusta del juego. La edición, una chulada también. Sin embargo, el juego tiene demasiadas reglas poco intuitivas y demasiados detalles por los que hay que estar pendiente (puede provocar entreturnos largos). Viendo que es un juego tan querido le he dado varias oportunidades pero definitivamente no es lo mío.',
#   'reviewer_country': 'Spain',
#   'rating': 5.0,
#   'date': '2019-09-21 03:01:46',
#   'is_owner': False},
#  {'review': 'It’s Brass with a more-is-better approach: more buildings, more locations, more connections—and then beer. Less cutthroat and leaning toward a point-salad feel. The high rail scoring makes the rail era predictable, though some might see it as a more forgiving, flexible evolution of the original. Could rate higher, but I’d always pick Lancashire over this, which brings the rating down a bit.',
#   'reviewer_country': 'Sweden',
#   'rating': 8.0,
#   'date': '2021-01-07 16:52:10',
#   'is_owner': False},
#  {'review': 'Boardroom, PAX, 4 2-4, 2h',
#   'reviewer_country': '',
#   'rating': 0.0,
#   'date': '2024-11-18 20:49:11',
#   'is_owner': False},
#  {'review': "That's the most boring and ugly game I've ever played. Viscous snot is the most suitable description for it. 1000% overrated.",
#   'reviewer_country': '',
#   'rating': 1.0,
#   'date': '2025-11-04 11:20:33',
#   'is_owner': False},
#  {'review': 'Loved playing and would recommend playing but did take us 4 and a half hours to learn and play as a 3. Worth it though',
#   'reviewer_country': 'United Kingdom',
#   'rating': 9.0,
#   'date': '2025-11-04 08:46:21',
#   'is_owner': False},
#  {'review': 'Sleeved with Shield Titan Super Sleeves (Clear)\nInsert included',
#   'reviewer_country': '',
#   'rating': 9.0,
#   'date': '2023-01-27 07:53:43',
#   'is_owner': True},
#  {'review': "Tentative rating.\n\nI understand how this game got its reputation. The puzzle involved is unique, which is such a rarity among the hundreds of Euros we see each year. It felt like the game is stimulating a whole new part of my brain's strategy center that I didn't know existed, and I love it.\n\nThe game is complex, the strategy is opaque, and it was a pain to teach with all of its minor titbits and exceptions. However, these won't matter after 20+ plays, and the game is solid enough to warrant that.",
#   'reviewer_country': 'Hong Kong',
#   'rating': 9.0,
#   'date': '2025-11-03 20:53:07',
#   'is_owner': False},
#  {'review': '3.87',
#   'reviewer_country': 'Chile',
#   'rating': 0.0,
#   'date': '2021-07-13 22:37:56',
#   'is_owner': True},
#  {'review': 'great euro styled game.\nflow of interaction is just a masterpiece.\nMartin is genious.',
#   'reviewer_country': 'South Korea',
#   'rating': 8.9,
#   'date': '2023-05-31 10:49:56',
#   'is_owner': False},
#  {'review': 'Less fluid than the black edition.',
#   'reviewer_country': 'Italy',
#   'rating': 6.0,
#   'date': '2017-04-22 01:38:44',
#   'is_owner': True},
#  {'review': "In my opinion, Lancashire is much better.\n\nLancashire is more straightforward and you focus on the strategy. You don't get tired of the multitude of tokens, in Lancashire there is only the essential ones. \n\nAfter playing Birmingham I always felt exhausted, but still liked the game. However, after playing Lancashire the time just flew and I would have wanted to play again right away.",
#   'reviewer_country': 'Hungary',
#   'rating': 0.0,
#   'date': '2018-10-26 17:42:27',
#   'is_owner': False},
#  {'review': '2-4 [S]',
#   'reviewer_country': 'Italy',
#   'rating': 0.0,
#   'date': '2025-09-24 17:47:08',
#   'is_owner': True},
#  {'review': 'Great game that somehow feels simple, yet every decision you make carries weight\n',
#   'reviewer_country': '',
#   'rating': 8.5,
#   'date': '2021-02-25 08:42:44',
#   'is_owner': False},
#  {'review': "If you can play this in 60 minutes you're playing too fast.  With my group a a game lasts about 45 minutes per player.\n\nKeep pushing up my rating..  This game continues to be my favorite and the favorite of our group.",
#   'reviewer_country': 'United States',
#   'rating': 9.4,
#   'date': '2024-07-10 16:55:53',
#   'is_owner': True},
#  {'review': 'Tabletop',
#   'reviewer_country': 'United States',
#   'rating': 0.0,
#   'date': '2025-02-01 17:35:35',
#   'is_owner': True},
#  {'review': 'I only played half a real game, but I was captivated throughout. Would play again.',
#   'reviewer_country': 'United States',
#   'rating': 8.7,
#   'date': '2025-11-10 19:17:57',
#   'is_owner': False},
#  {'review': 'Ship',
#   'reviewer_country': 'Hong Kong',
#   'rating': 10.0,
#   'date': '2017-08-02 02:10:40',
#   'is_owner': True},
#  {'review': "The more I play, the more I realize it's more about playing the hand you're dealt, and less about strategy",
#   'reviewer_country': 'United States',
#   'rating': 7.0,
#   'date': '2022-11-18 00:53:44',
#   'is_owner': False},
#  {'review': 'Very good game. I might not say it is the best of all times, but it is definetely great. The mechanics are simple, but I consider that it takes a little time to adapt to them. You may need several playthroughs to achieve some sort of mastering. Revise every victory point possibility to plan your strategy, otherwise, it can be easy to fall pursuing things that are not profitable in the long term.',
#   'reviewer_country': 'Paraguay',
#   'rating': 8.0,
#   'date': '2024-11-26 12:06:53',
#   'is_owner': True},
#  {'review': "+ Artwork is great\n+ Great strategy game\n+ Lots of interaction\n+ Low luck factor\n+ Many paths to victory\n+ Brain burner \n- Quite long\n- Rules heavy \n- Theme is a bit boring\n\nDeep strategic economic game with many ways to win the game. It is surprisingly enough very interactive. I've only played it at 2 and 3 player count. ",
#   'reviewer_country': 'Belgium',
#   'rating': 8.5,
#   'date': '2022-01-18 08:40:16',
#   'is_owner': True},
#  {'review': 'Не фанат евро, это могло быть неплохо, не против сыграть в нее снова, если что, но сам предлагать ее не буду. И да, это точно не первое место BGG.',
#   'reviewer_country': 'Belarus',
#   'rating': 6.0,
#   'date': '2025-09-06 08:12:40',
#   'is_owner': False},
#  {'review': 'Most of my plays have been at 2p, and I thoroughly enjoyed every single game. \nHowever, it feels like it ends very quickly at 4p (a feeling it seems others at my table tend to have as well). \n\n',
#   'reviewer_country': 'Switzerland',
#   'rating': 9.5,
#   'date': '2024-12-17 10:40:53',
#   'is_owner': True},
#  {'review': 'Pt: 3',
#   'reviewer_country': '',
#   'rating': 0.0,
#   'date': '2025-11-10 00:00:59',
#   'is_owner': True},
#  {'review': 'In: October 2025',
#   'reviewer_country': '',
#   'rating': 0.0,
#   'date': '2024-05-23 23:31:31',
#   'is_owner': True},
#  {'review': 'ES',
#   'reviewer_country': '',
#   'rating': 9.0,
#   'date': '2021-01-26 00:30:31',
#   'is_owner': True},
#  {'review': 'M.Heavy Euro - Wallace, Trains',
#   'reviewer_country': 'United States',
#   'rating': 9.3,
#   'date': '2017-04-19 05:07:02',
#   'is_owner': True},
#  {'review': "Arguably the best strategic area control, resource management game.  Just make sure you use other peoples beer and don't let them use yours.",
#   'reviewer_country': 'United States',
#   'rating': 8.5,
#   'date': '2019-02-16 16:05:39',
#   'is_owner': False},
#  {'review': 'Epic',
#   'reviewer_country': '',
#   'rating': 0.0,
#   'date': '2024-12-26 12:13:56',
#   'is_owner': False},
#  {'review': "haven't played it enough to really understand it. Heavy and thinky. need to log more plays",
#   'reviewer_country': 'United States',
#   'rating': 7.0,
#   'date': '2025-02-25 14:52:24',
#   'is_owner': True},
#  {'review': "Brass est un jeu qui doit beaucoup de son succès à sa capacité à offrir peu de prises à la critique (hasard peu présent, édition irréprochable, thème mature, jeu élitiste). C'est un jeu surestimé qui surfe sur les défauts du classement BGG (les rééditions ont des notes excessivement hautes, surtout avec une refonte graphique et un matériel abondant hyper qualitatif. Ces rééditions prêchent des convaincus qui surnotent leurs jeux favoris au travers d'une nouvelle entrée sur BGG).",
#   'reviewer_country': 'France',
#   'rating': 7.0,
#   'date': '2023-06-21 04:28:52',
#   'is_owner': False},
#  {'review': 'Your first game is likely going to be rough. However no doubt you will see the appeal of building up your own niche economy that ends up frustratingly reliant on and sometimes in favor the other players. At the end of each round you will be left going "oh I wish I did that," or "things could have gone well if you didn\'t do that", but still be left to admire how everything resulted in the end. After that rough first game, you are most likely going to arrange for another game, all to get better at this system.',
#   'reviewer_country': 'Australia',
#   'rating': 9.0,
#   'date': '2025-07-04 05:16:12',
#   'is_owner': True},
#  {'review': 'B3u4, G2',
#   'reviewer_country': 'Germany',
#   'rating': 8.5,
#   'date': '2020-10-30 08:16:32',
#   'is_owner': True},
#  {'review': 'Regal 14',
#   'reviewer_country': 'Germany',
#   'rating': 0.0,
#   'date': '2021-11-01 11:06:57',
#   'is_owner': True},
#  {'review': '£67.85 https://www.amazon.co.uk/Roxley-Games-ROX402-Brass-Birmingham/dp/1988884047?crid=2I7084BPZPFR5&dib=eyJ2IjoiMSJ9.AKBvx-qCEQ1s2PviGSbDhYyDSrcdKdGtfSi_ilfJCheyjNb5lf8iB5Kr8USCrowvqXNUC7k-hRITiyTddwAp1e-vXgssxL4xuGJa3X2ETt8Np9UmhR4kjr6WpnTMDMRj_VvxWnEgN6AY7c15BtQ-aWQy9Jis6jXCz3utNAtdZ5rT2epjPFsa2S4Te8RikY2S8yEHoXlcbHAEnprGxF1cy7ivg7o24JuypogPNga_UZOPS_Psun_ySg-365rKRCq8i06CmiXpEVyVf83N0o-ViZGc70ox5rE1PqNQ2yb6k4I.VZKtGk37XxVIkuMPPcDUbbo9eBxUHUpzCjO7chxTe9k&dib_tag=se&keywords=brass%2Bbirmingham%2Bboard%2Bgame&qid=1762604991&sprefix=brass%2B%2Caps%2C123&sr=8-4&th=1',
#   'reviewer_country': '',
#   'rating': 0.0,
#   'date': '2025-11-08 10:05:06',
#   'is_owner': False},
#  {'review': "Previously 9. The more you play this game the more it shines!\n\nIt has a relatively simple rule set with incredible depth. No need for expansions.... It's a modern classic.\n\nIf you like strategy without the need to attack your opponents to win, this is for you.\n\nThe interplay of you using up the other players resources benefitting both you and them is very satisfying and keeps everyone engaged.\n\nGreat family strategic game! ",
#   'reviewer_country': 'Ireland',
#   'rating': 10.0,
#   'date': '2024-05-09 09:36:06',
#   'is_owner': True},
#  {'review': 'I loathe this as much as I loathed the original Brass. And now add in hunger games for beer. \n\nOne and done.\n\nThe #1 game on BGG? Someone euthanize me.',
#   'reviewer_country': 'Canada',
#   'rating': 3.0,
#   'date': '2025-11-07 16:06:34',
#   'is_owner': False},
#  {'review': 'Tedious and boring VP pusher with instant railway transition. Not my cup of tea? No, I’d rather smear my genitalia with fish paste and dangle them in a pool of hungry piranha. \n\nDingo',
#   'reviewer_country': '',
#   'rating': 2.0,
#   'date': '2018-09-30 09:38:56',
#   'is_owner': False},
#  {'review': 'La primera partida había sido media trabada. En parte por las nuevas reglas y en parte porque, en el azar de la distribución de mercados iniciales, terminamos con uno de ellos cerrado y eso trastocó cómo se desenvuelve la partida (no lo rompe, pero no es lo más fácil de encarar la primera vez). En principio, me había dejado la sensación de que el agregado de opciones y profundidad no compensaba la pérdida del paso fluido del original.\n\nEn la última que participé, pasó lo mismo con los mercados iniciales y dijimos fuggit, y los shuffleamos de nuevo. Con las reglas más aceitadas y más mercados abiertos, la partida voló con la fluidez que recordaba que tenía el original, así que me reconcilié con esta nueva versión.\n\nPero hay que usar el lado del tablero de día, el lado del tablero de noche, salvo que uses un casco de minero con luz, no se distingue un pomo.\n\nTampoco sé qué traerá el juego como dinero, porque siempre usamos fichas de póker.\n\nUn clásico que conserva lo mejor de los eurojuegos de esa época: profundidad, opciones, decisiones, interacción, fluidez, con un cromo actualizado.\n\nMuy recomendable :star::star::star::star::nostar:',
#   'reviewer_country': 'Argentina',
#   'rating': 9.0,
#   'date': '2019-08-27 09:30:40',
#   'is_owner': False},
#  {'review': 'SpielboxRating 9-10, av. 9,20',
#   'reviewer_country': 'Germany',
#   'rating': 0.0,
#   'date': '2025-03-01 17:14:41',
#   'is_owner': False},
#  {'review': "Much more fun than the (old) original version. This took a few plays to grow on me. No in game text, has a central board and good balance between tactical and strategical play. Maybe a bit on the long side, but it's a really nail-biter till the end. I can see why this is rated so high as it is.",
#   'reviewer_country': '',
#   'rating': 8.5,
#   'date': '2023-05-04 17:22:16',
#   'is_owner': False},
#  {'review': "It's a great game, would struggle to get consistent plays.",
#   'reviewer_country': 'United States',
#   'rating': 8.0,
#   'date': '2021-04-11 20:17:03',
#   'is_owner': False},
#  {'review': '+ 3D Printed insert\n+ Sleeves',
#   'reviewer_country': 'Slovakia',
#   'rating': 8.5,
#   'date': '2024-09-11 07:11:51',
#   'is_owner': False},
#  {'review': 'I enjoy Lancashire and want to add this one to my collection at some point.',
#   'reviewer_country': '',
#   'rating': 0.0,
#   'date': '2024-11-08 11:08:43',
#   'is_owner': False},
#  {'review': 'Euro medio muy limpio.',
#   'reviewer_country': 'Spain',
#   'rating': 9.0,
#   'date': '2025-11-06 04:14:42',
#   'is_owner': True},
#  {'review': 'Great game!',
#   'reviewer_country': 'Indonesia',
#   'rating': 8.0,
#   'date': '2025-10-22 08:23:42',
#   'is_owner': True},
#  {'review': '건조하고 같은 웨이트 대 게임들과 비교 했을 때 룰이 잘 안 외워지는 편. 메인 메커니즘은 2018년 게임치곤 카탄처럼 고전 특유의 단순함. 같은 멤버로 할 경우 리플레이성도 의문임. 결론 재미는 단순하고 이해는 어려움.',
#   'reviewer_country': '',
#   'rating': 1.0,
#   'date': '2025-11-05 20:41:41',
#   'is_owner': False},
#  {'review': 'Great game\n-scratches the economic itch\n-tight gameplay, but does not feel too limiting\n-not too long after you learn\n-straightforward ways to score\n-has a semi cooperative element to the game which make other players turns more interesting  \n-can be a bit tough to learn/teach first time\n-rules can feel contradicting when learning',
#   'reviewer_country': 'United States',
#   'rating': 9.0,
#   'date': '2025-11-05 18:34:23',
#   'is_owner': True},
#  {'review': 'kickstarter',
#   'reviewer_country': 'Czech Republic',
#   'rating': 9.5,
#   'date': '2018-08-02 10:34:01',
#   'is_owner': True},
#  {'review': '+ Engaging tactics and strategy\n+ Agonizing decisions and tradeoffs\n+ Tight economy\n+ Player interaction\n+ Climactic ending\n- AP prone\n- Finicky rules and fiddliness\n- Downtime',
#   'reviewer_country': '',
#   'rating': 8.0,
#   'date': '2025-08-24 07:20:11',
#   'is_owner': False},
#  {'review': "BRASS BIRMINGHAM (2-4 players)\n\nDeluxe player aids: https://boardgamegeek.com/filepage/179522/deluxe-player-aids-brass-birmingham\n\nFanmade solo variant: \n\nhttp://www.mautoma.com/mautomas/brass-birmingham \n\nOnline app for solo variant so you don't have to print the cards: \n\nhttps://boardgamegeek.com/filepage/168370/brass-birmingham-george-solo-competitive-mode\n\nBrass Birmingham is better than Brass Lancashire. The Mautoma Solo variant is quite good but I prefer to play Brass as a multiplayer game. The game is a dry euro but a VERY good dry euro.",
#   'reviewer_country': 'Belgium',
#   'rating': 9.0,
#   'date': '2020-04-16 14:52:47',
#   'is_owner': True},
#  {'review': 'Reglas un poco obtusas, con excepciones y muchos detalles que hacen que tengas que estar revisándolas constantemente. La explicación hay que preparársela bien, no es sencillo asimilar los conceptos. \n\nMe gusta que todo el mundo participe en el tablero central y que pueda aprovecharse de las rutas y recursos de los demás, hay mucha interacción, sin duda lo que más me gusta del juego. La edición, una chulada también. Sin embargo, el juego tiene demasiadas reglas poco intuitivas y demasiados detalles por los que hay que estar pendiente (puede provocar entreturnos largos). Viendo que es un juego tan querido le he dado varias oportunidades pero definitivamente no es lo mío.',
#   'reviewer_country': 'Spain',
#   'rating': 5.0,
#   'date': '2019-09-21 03:01:46',
#   'is_owner': False},
#  {'review': 'It’s Brass with a more-is-better approach: more buildings, more locations, more connections—and then beer. Less cutthroat and leaning toward a point-salad feel. The high rail scoring makes the rail era predictable, though some might see it as a more forgiving, flexible evolution of the original. Could rate higher, but I’d always pick Lancashire over this, which brings the rating down a bit.',
#   'reviewer_country': 'Sweden',
#   'rating': 8.0,
#   'date': '2021-01-07 16:52:10',
#   'is_owner': False},
#  {'review': 'Boardroom, PAX, 4 2-4, 2h',
#   'reviewer_country': '',
#   'rating': 0.0,
#   'date': '2024-11-18 20:49:11',
#   'is_owner': False},
#  {'review': "That's the most boring and ugly game I've ever played. Viscous snot is the most suitable description for it. 1000% overrated.",
#   'reviewer_country': '',
#   'rating': 1.0,
#   'date': '2025-11-04 11:20:33',
#   'is_owner': False},
#  {'review': 'Loved playing and would recommend playing but did take us 4 and a half hours to learn and play as a 3. Worth it though',
#   'reviewer_country': 'United Kingdom',
#   'rating': 9.0,
#   'date': '2025-11-04 08:46:21',
#   'is_owner': False},
#  {'review': 'Sleeved with Shield Titan Super Sleeves (Clear)\nInsert included',
#   'reviewer_country': '',
#   'rating': 9.0,
#   'date': '2023-01-27 07:53:43',
#   'is_owner': True},
#  {'review': "Tentative rating.\n\nI understand how this game got its reputation. The puzzle involved is unique, which is such a rarity among the hundreds of Euros we see each year. It felt like the game is stimulating a whole new part of my brain's strategy center that I didn't know existed, and I love it.\n\nThe game is complex, the strategy is opaque, and it was a pain to teach with all of its minor titbits and exceptions. However, these won't matter after 20+ plays, and the game is solid enough to warrant that.",
#   'reviewer_country': 'Hong Kong',
#   'rating': 9.0,
#   'date': '2025-11-03 20:53:07',
#   'is_owner': False},
#  {'review': '3.87',
#   'reviewer_country': 'Chile',
#   'rating': 0.0,
#   'date': '2021-07-13 22:37:56',
#   'is_owner': True},
#  {'review': 'great euro styled game.\nflow of interaction is just a masterpiece.\nMartin is genious.',
#   'reviewer_country': 'South Korea',
#   'rating': 8.9,
#   'date': '2023-05-31 10:49:56',
#   'is_owner': False},
#  {'review': 'Less fluid than the black edition.',
#   'reviewer_country': 'Italy',
#   'rating': 6.0,
#   'date': '2017-04-22 01:38:44',
#   'is_owner': True},
#  {'review': "In my opinion, Lancashire is much better.\n\nLancashire is more straightforward and you focus on the strategy. You don't get tired of the multitude of tokens, in Lancashire there is only the essential ones. \n\nAfter playing Birmingham I always felt exhausted, but still liked the game. However, after playing Lancashire the time just flew and I would have wanted to play again right away.",
#   'reviewer_country': 'Hungary',
#   'rating': 0.0,
#   'date': '2018-10-26 17:42:27',
#   'is_owner': False},
#  {'review': '2-4 [S]',
#   'reviewer_country': 'Italy',
#   'rating': 0.0,
#   'date': '2025-09-24 17:47:08',
#   'is_owner': True},
#  {'review': 'Great game that somehow feels simple, yet every decision you make carries weight\n',
#   'reviewer_country': '',
#   'rating': 8.5,
#   'date': '2021-02-25 08:42:44',
#   'is_owner': False},
#  {'review': "If you can play this in 60 minutes you're playing too fast.  With my group a a game lasts about 45 minutes per player.\n\nKeep pushing up my rating..  This game continues to be my favorite and the favorite of our group.",
#   'reviewer_country': 'United States',
#   'rating': 9.4,
#   'date': '2024-07-10 16:55:53',
#   'is_owner': True},
#  {'review': 'Tabletop',
#   'reviewer_country': 'United States',
#   'rating': 0.0,
#   'date': '2025-02-01 17:35:35',
#   'is_owner': True},
#  {'review': 'I only played half a real game, but I was captivated throughout. Would play again.',
#   'reviewer_country': 'United States',
#   'rating': 8.7,
#   'date': '2025-11-10 19:17:57',
#   'is_owner': False},
#  {'review': 'Ship',
#   'reviewer_country': 'Hong Kong',
#   'rating': 10.0,
#   'date': '2017-08-02 02:10:40',
#   'is_owner': True},
#  {'review': "The more I play, the more I realize it's more about playing the hand you're dealt, and less about strategy",
#   'reviewer_country': 'United States',
#   'rating': 7.0,
#   'date': '2022-11-18 00:53:44',
#   'is_owner': False},
#  {'review': 'Very good game. I might not say it is the best of all times, but it is definetely great. The mechanics are simple, but I consider that it takes a little time to adapt to them. You may need several playthroughs to achieve some sort of mastering. Revise every victory point possibility to plan your strategy, otherwise, it can be easy to fall pursuing things that are not profitable in the long term.',
#   'reviewer_country': 'Paraguay',
#   'rating': 8.0,
#   'date': '2024-11-26 12:06:53',
#   'is_owner': True},
#  {'review': "+ Artwork is great\n+ Great strategy game\n+ Lots of interaction\n+ Low luck factor\n+ Many paths to victory\n+ Brain burner \n- Quite long\n- Rules heavy \n- Theme is a bit boring\n\nDeep strategic economic game with many ways to win the game. It is surprisingly enough very interactive. I've only played it at 2 and 3 player count. ",
#   'reviewer_country': 'Belgium',
#   'rating': 8.5,
#   'date': '2022-01-18 08:40:16',
#   'is_owner': True},
#  {'review': 'Не фанат евро, это могло быть неплохо, не против сыграть в нее снова, если что, но сам предлагать ее не буду. И да, это точно не первое место BGG.',
#   'reviewer_country': 'Belarus',
#   'rating': 6.0,
#   'date': '2025-09-06 08:12:40',
#   'is_owner': False},
#  {'review': 'Most of my plays have been at 2p, and I thoroughly enjoyed every single game. \nHowever, it feels like it ends very quickly at 4p (a feeling it seems others at my table tend to have as well). \n\n',
#   'reviewer_country': 'Switzerland',
#   'rating': 9.5,
#   'date': '2024-12-17 10:40:53',
#   'is_owner': True},
#  {'review': 'Pt: 3',
#   'reviewer_country': '',
#   'rating': 0.0,
#   'date': '2025-11-10 00:00:59',
#   'is_owner': True},
#  {'review': 'In: October 2025',
#   'reviewer_country': '',
#   'rating': 0.0,
#   'date': '2024-05-23 23:31:31',
#   'is_owner': True},
#  {'review': 'ES',
#   'reviewer_country': '',
#   'rating': 9.0,
#   'date': '2021-01-26 00:30:31',
#   'is_owner': True},
#  {'review': 'M.Heavy Euro - Wallace, Trains',
#   'reviewer_country': 'United States',
#   'rating': 9.3,
#   'date': '2017-04-19 05:07:02',
#   'is_owner': True},
#  {'review': "Arguably the best strategic area control, resource management game.  Just make sure you use other peoples beer and don't let them use yours.",
#   'reviewer_country': 'United States',
#   'rating': 8.5,
#   'date': '2019-02-16 16:05:39',
#   'is_owner': False},
#  {'review': 'Epic',
#   'reviewer_country': '',
#   'rating': 0.0,
#   'date': '2024-12-26 12:13:56',
#   'is_owner': False},
#  {'review': "haven't played it enough to really understand it. Heavy and thinky. need to log more plays",
#   'reviewer_country': 'United States',
#   'rating': 7.0,
#   'date': '2025-02-25 14:52:24',
#   'is_owner': True},
#  {'review': "Brass est un jeu qui doit beaucoup de son succès à sa capacité à offrir peu de prises à la critique (hasard peu présent, édition irréprochable, thème mature, jeu élitiste). C'est un jeu surestimé qui surfe sur les défauts du classement BGG (les rééditions ont des notes excessivement hautes, surtout avec une refonte graphique et un matériel abondant hyper qualitatif. Ces rééditions prêchent des convaincus qui surnotent leurs jeux favoris au travers d'une nouvelle entrée sur BGG).",
#   'reviewer_country': 'France',
#   'rating': 7.0,
#   'date': '2023-06-21 04:28:52',
#   'is_owner': False},
#  {'review': 'Your first game is likely going to be rough. However no doubt you will see the appeal of building up your own niche economy that ends up frustratingly reliant on and sometimes in favor the other players. At the end of each round you will be left going "oh I wish I did that," or "things could have gone well if you didn\'t do that", but still be left to admire how everything resulted in the end. After that rough first game, you are most likely going to arrange for another game, all to get better at this system.',
#   'reviewer_country': 'Australia',
#   'rating': 9.0,
#   'date': '2025-07-04 05:16:12',
#   'is_owner': True},
#  {'review': 'B3u4, G2',
#   'reviewer_country': 'Germany',
#   'rating': 8.5,
#   'date': '2020-10-30 08:16:32',
#   'is_owner': True},
#  {'review': 'Regal 14',
#   'reviewer_country': 'Germany',
#   'rating': 0.0,
#   'date': '2021-11-01 11:06:57',
#   'is_owner': True},
#  {'review': '£67.85 https://www.amazon.co.uk/Roxley-Games-ROX402-Brass-Birmingham/dp/1988884047?crid=2I7084BPZPFR5&dib=eyJ2IjoiMSJ9.AKBvx-qCEQ1s2PviGSbDhYyDSrcdKdGtfSi_ilfJCheyjNb5lf8iB5Kr8USCrowvqXNUC7k-hRITiyTddwAp1e-vXgssxL4xuGJa3X2ETt8Np9UmhR4kjr6WpnTMDMRj_VvxWnEgN6AY7c15BtQ-aWQy9Jis6jXCz3utNAtdZ5rT2epjPFsa2S4Te8RikY2S8yEHoXlcbHAEnprGxF1cy7ivg7o24JuypogPNga_UZOPS_Psun_ySg-365rKRCq8i06CmiXpEVyVf83N0o-ViZGc70ox5rE1PqNQ2yb6k4I.VZKtGk37XxVIkuMPPcDUbbo9eBxUHUpzCjO7chxTe9k&dib_tag=se&keywords=brass%2Bbirmingham%2Bboard%2Bgame&qid=1762604991&sprefix=brass%2B%2Caps%2C123&sr=8-4&th=1',
#   'reviewer_country': '',
#   'rating': 0.0,
#   'date': '2025-11-08 10:05:06',
#   'is_owner': False},
#  {'review': "Previously 9. The more you play this game the more it shines!\n\nIt has a relatively simple rule set with incredible depth. No need for expansions.... It's a modern classic.\n\nIf you like strategy without the need to attack your opponents to win, this is for you.\n\nThe interplay of you using up the other players resources benefitting both you and them is very satisfying and keeps everyone engaged.\n\nGreat family strategic game! ",
#   'reviewer_country': 'Ireland',
#   'rating': 10.0,
#   'date': '2024-05-09 09:36:06',
#   'is_owner': True},
#  {'review': 'I loathe this as much as I loathed the original Brass. And now add in hunger games for beer. \n\nOne and done.\n\nThe #1 game on BGG? Someone euthanize me.',
#   'reviewer_country': 'Canada',
#   'rating': 3.0,
#   'date': '2025-11-07 16:06:34',
#   'is_owner': False},
#  {'review': 'Tedious and boring VP pusher with instant railway transition. Not my cup of tea? No, I’d rather smear my genitalia with fish paste and dangle them in a pool of hungry piranha. \n\nDingo',
#   'reviewer_country': '',
#   'rating': 2.0,
#   'date': '2018-09-30 09:38:56',
#   'is_owner': False},
#  {'review': 'La primera partida había sido media trabada. En parte por las nuevas reglas y en parte porque, en el azar de la distribución de mercados iniciales, terminamos con uno de ellos cerrado y eso trastocó cómo se desenvuelve la partida (no lo rompe, pero no es lo más fácil de encarar la primera vez). En principio, me había dejado la sensación de que el agregado de opciones y profundidad no compensaba la pérdida del paso fluido del original.\n\nEn la última que participé, pasó lo mismo con los mercados iniciales y dijimos fuggit, y los shuffleamos de nuevo. Con las reglas más aceitadas y más mercados abiertos, la partida voló con la fluidez que recordaba que tenía el original, así que me reconcilié con esta nueva versión.\n\nPero hay que usar el lado del tablero de día, el lado del tablero de noche, salvo que uses un casco de minero con luz, no se distingue un pomo.\n\nTampoco sé qué traerá el juego como dinero, porque siempre usamos fichas de póker.\n\nUn clásico que conserva lo mejor de los eurojuegos de esa época: profundidad, opciones, decisiones, interacción, fluidez, con un cromo actualizado.\n\nMuy recomendable :star::star::star::star::nostar:',
#   'reviewer_country': 'Argentina',
#   'rating': 9.0,
#   'date': '2019-08-27 09:30:40',
#   'is_owner': False},
#  {'review': 'SpielboxRating 9-10, av. 9,20',
#   'reviewer_country': 'Germany',
#   'rating': 0.0,
#   'date': '2025-03-01 17:14:41',
#   'is_owner': False},
#  {'review': "Much more fun than the (old) original version. This took a few plays to grow on me. No in game text, has a central board and good balance between tactical and strategical play. Maybe a bit on the long side, but it's a really nail-biter till the end. I can see why this is rated so high as it is.",
#   'reviewer_country': '',
#   'rating': 8.5,
#   'date': '2023-05-04 17:22:16',
#   'is_owner': False},
#  {'review': "It's a great game, would struggle to get consistent plays.",
#   'reviewer_country': 'United States',
#   'rating': 8.0,
#   'date': '2021-04-11 20:17:03',
#   'is_owner': False},
#  {'review': '+ 3D Printed insert\n+ Sleeves',
#   'reviewer_country': 'Slovakia',
#   'rating': 8.5,
#   'date': '2024-09-11 07:11:51',
#   'is_owner': False},
#  {'review': 'I enjoy Lancashire and want to add this one to my collection at some point.',
#   'reviewer_country': '',
#   'rating': 0.0,
#   'date': '2024-11-08 11:08:43',
#   'is_owner': False},
#  {'review': 'Euro medio muy limpio.',
#   'reviewer_country': 'Spain',
#   'rating': 9.0,
#   'date': '2025-11-06 04:14:42',
#   'is_owner': True},
#  {'review': 'Great game!',
#   'reviewer_country': 'Indonesia',
#   'rating': 8.0,
#   'date': '2025-10-22 08:23:42',
#   'is_owner': True},
#  {'review': '건조하고 같은 웨이트 대 게임들과 비교 했을 때 룰이 잘 안 외워지는 편. 메인 메커니즘은 2018년 게임치곤 카탄처럼 고전 특유의 단순함. 같은 멤버로 할 경우 리플레이성도 의문임. 결론 재미는 단순하고 이해는 어려움.',
#   'reviewer_country': '',
#   'rating': 1.0,
#   'date': '2025-11-05 20:41:41',
#   'is_owner': False},
#  {'review': 'Great game\n-scratches the economic itch\n-tight gameplay, but does not feel too limiting\n-not too long after you learn\n-straightforward ways to score\n-has a semi cooperative element to the game which make other players turns more interesting  \n-can be a bit tough to learn/teach first time\n-rules can feel contradicting when learning',
#   'reviewer_country': 'United States',
#   'rating': 9.0,
#   'date': '2025-11-05 18:34:23',
#   'is_owner': True},
#  {'review': 'kickstarter',
#   'reviewer_country': 'Czech Republic',
#   'rating': 9.5,
#   'date': '2018-08-02 10:34:01',
#   'is_owner': True},
#  {'review': '+ Engaging tactics and strategy\n+ Agonizing decisions and tradeoffs\n+ Tight economy\n+ Player interaction\n+ Climactic ending\n- AP prone\n- Finicky rules and fiddliness\n- Downtime',
#   'reviewer_country': '',
#   'rating': 8.0,
#   'date': '2025-08-24 07:20:11',
#   'is_owner': False},
#  {'review': "BRASS BIRMINGHAM (2-4 players)\n\nDeluxe player aids: https://boardgamegeek.com/filepage/179522/deluxe-player-aids-brass-birmingham\n\nFanmade solo variant: \n\nhttp://www.mautoma.com/mautomas/brass-birmingham \n\nOnline app for solo variant so you don't have to print the cards: \n\nhttps://boardgamegeek.com/filepage/168370/brass-birmingham-george-solo-competitive-mode\n\nBrass Birmingham is better than Brass Lancashire. The Mautoma Solo variant is quite good but I prefer to play Brass as a multiplayer game. The game is a dry euro but a VERY good dry euro.",
#   'reviewer_country': 'Belgium',
#   'rating': 9.0,
#   'date': '2020-04-16 14:52:47',
#   'is_owner': True},
#  {'review': 'Reglas un poco obtusas, con excepciones y muchos detalles que hacen que tengas que estar revisándolas constantemente. La explicación hay que preparársela bien, no es sencillo asimilar los conceptos. \n\nMe gusta que todo el mundo participe en el tablero central y que pueda aprovecharse de las rutas y recursos de los demás, hay mucha interacción, sin duda lo que más me gusta del juego. La edición, una chulada también. Sin embargo, el juego tiene demasiadas reglas poco intuitivas y demasiados detalles por los que hay que estar pendiente (puede provocar entreturnos largos). Viendo que es un juego tan querido le he dado varias oportunidades pero definitivamente no es lo mío.',
#   'reviewer_country': 'Spain',
#   'rating': 5.0,
#   'date': '2019-09-21 03:01:46',
#   'is_owner': False},
#  {'review': 'It’s Brass with a more-is-better approach: more buildings, more locations, more connections—and then beer. Less cutthroat and leaning toward a point-salad feel. The high rail scoring makes the rail era predictable, though some might see it as a more forgiving, flexible evolution of the original. Could rate higher, but I’d always pick Lancashire over this, which brings the rating down a bit.',
#   'reviewer_country': 'Sweden',
#   'rating': 8.0,
#   'date': '2021-01-07 16:52:10',
#   'is_owner': False},
#  {'review': 'Boardroom, PAX, 4 2-4, 2h',
#   'reviewer_country': '',
#   'rating': 0.0,
#   'date': '2024-11-18 20:49:11',
#   'is_owner': False},
#  {'review': "That's the most boring and ugly game I've ever played. Viscous snot is the most suitable description for it. 1000% overrated.",
#   'reviewer_country': '',
#   'rating': 1.0,
#   'date': '2025-11-04 11:20:33',
#   'is_owner': False},
#  {'review': 'Loved playing and would recommend playing but did take us 4 and a half hours to learn and play as a 3. Worth it though',
#   'reviewer_country': 'United Kingdom',
#   'rating': 9.0,
#   'date': '2025-11-04 08:46:21',
#   'is_owner': False},
#  {'review': 'Sleeved with Shield Titan Super Sleeves (Clear)\nInsert included',
#   'reviewer_country': '',
#   'rating': 9.0,
#   'date': '2023-01-27 07:53:43',
#   'is_owner': True},
#  {'review': "Tentative rating.\n\nI understand how this game got its reputation. The puzzle involved is unique, which is such a rarity among the hundreds of Euros we see each year. It felt like the game is stimulating a whole new part of my brain's strategy center that I didn't know existed, and I love it.\n\nThe game is complex, the strategy is opaque, and it was a pain to teach with all of its minor titbits and exceptions. However, these won't matter after 20+ plays, and the game is solid enough to warrant that.",
#   'reviewer_country': 'Hong Kong',
#   'rating': 9.0,
#   'date': '2025-11-03 20:53:07',
#   'is_owner': False},
#  {'review': '3.87',
#   'reviewer_country': 'Chile',
#   'rating': 0.0,
#   'date': '2021-07-13 22:37:56',
#   'is_owner': True},
#  {'review': 'great euro styled game.\nflow of interaction is just a masterpiece.\nMartin is genious.',
#   'reviewer_country': 'South Korea',
#   'rating': 8.9,
#   'date': '2023-05-31 10:49:56',
#   'is_owner': False},
#  {'review': 'Less fluid than the black edition.',
#   'reviewer_country': 'Italy',
#   'rating': 6.0,
#   'date': '2017-04-22 01:38:44',
#   'is_owner': True},
#  {'review': "In my opinion, Lancashire is much better.\n\nLancashire is more straightforward and you focus on the strategy. You don't get tired of the multitude of tokens, in Lancashire there is only the essential ones. \n\nAfter playing Birmingham I always felt exhausted, but still liked the game. However, after playing Lancashire the time just flew and I would have wanted to play again right away.",
#   'reviewer_country': 'Hungary',
#   'rating': 0.0,
#   'date': '2018-10-26 17:42:27',
#   'is_owner': False},
#  {'review': "Too many little nit-picky rules.  It's fine, but I always get frustrated when I play it.  Wish it was a little more intuitive and elegant in its design.  I can see why people like it - my group loves it - just not my favorite.",
#   'reviewer_country': '',
#   'rating': 6.0,
#   'date': '2024-11-30 06:42:49',
#   'is_owner': False},
#  {'review': '25\n50€',
#   'reviewer_country': 'Netherlands',
#   'rating': 9.0,
#   'date': '2025-03-02 07:49:01',
#   'is_owner': False},
# ...
#  {'review': 'lang_eng cat_strategy',
#   'reviewer_country': 'Sweden',
#   'rating': 0.0,
#   'date': '2025-04-23 08:22:18',
#   'is_owner': True},
#  {'review': 'Dinged corner,',
#   'reviewer_country': 'United States',
#   'rating': 9.0,
#   'date': '2020-12-01 04:34:11',
#   'is_owner': True},
#  {'review': '[76] 65x90 boardm sleeve',
#   'reviewer_country': 'South Korea',
#   'rating': 0.0,
#   'date': '2019-01-18 07:55:36',
#   'is_owner': True},
#  {'review': "Great network building and resource management game. \n\nInterestingly, this game has many actions where the action you're taking benefits yourself, but also another player. For example, you can take other players' resources on building they've built, but they want their buildings to be emptied so that their building tiles can be flipped and score them points and income.\n\nThere is a soft reset of the board in the middle of the game as well, which is definitely something to consider. If you manage to get out one of your buildings that don't get removed by this soft reset after the first era, they will score twice.\n\nI have heard countless times that this game was very cutthroat, but honestly, I didn't find it so compared to other network building games. Yes, you can cut someone's network short with your own, but that means you're likely cutting your own network too. Other players can use each other's networks anyway in many cases. I guess you can steal other players' building spots, but that is not enough to call a game cutthroat for me. i don't generally like cutthroat games, but I did like this.",
#   'reviewer_country': 'Canada',
#   'rating': 9.5,
#   'date': '2021-10-21 20:52:53',
#   'is_owner': True},
#  {'review': "Friend's game",
#   'reviewer_country': 'United Kingdom',
#   'rating': 5.0,
#   'date': '2024-01-26 10:06:02',
#   'is_owner': False},
#  {'review': '280',
#   'reviewer_country': 'Romania',
#   'rating': 0.0,
#   'date': '2025-04-22 06:23:39',
#   'is_owner': True},
#  {'review': 'Challenging One.',
#   'reviewer_country': 'South Korea',
#   'rating': 9.0,
#   'date': '2020-10-30 02:18:31',
#   'is_owner': False},
#  {'review': "A very, very good game. I'll come back with pleasure",
#   'reviewer_country': 'France',
#   'rating': 8.0,
#   'date': '2025-04-21 03:36:11',
#   'is_owner': False},
#  {'review': 'Olga 3\nOmar 1',
#   'reviewer_country': '',
#   'rating': 9.1,
#   'date': '2021-04-18 02:18:37',
#   'is_owner': True},
#  {'review': 'A truly remarkable game.',
#   'reviewer_country': 'Serbia',
#   'rating': 10.0,
#   'date': '2021-03-29 08:51:28',
#   'is_owner': True},
#  {'review': 'Easy to get into but really hard on the brain to progress. Always in debt too.\nPlays brilliantly',
#   'reviewer_country': 'United Kingdom',
#   'rating': 10.0,
#   'date': '2019-06-10 11:05:36',
#   'is_owner': True},
#  {'review': '게임 자체는 너무 깔끔하고 재밌는데, 네트워크로 점수만 버는 생각을 하기 시작하니 환상이 좀 사라짐.',
#   'reviewer_country': '',
#   'rating': 8.9,
#   'date': '2021-11-04 09:41:54',
#   'is_owner': True},
#  {'review': "I think the more I play this the higher it will go. I played two-handed, but I can't stop thinking about it...",
#   'reviewer_country': 'United States',
#   'rating': 7.5,
#   'date': '2018-08-29 16:20:06',
#   'is_owner': True},
#  {'review': 'In UK',
#   'reviewer_country': 'United Kingdom',
#   'rating': 0.0,
#   'date': '2025-04-19 16:53:14',
#   'is_owner': True},
#  {'review': 'Awesome game! (Very hard to play after a longer break.) 2nd phase is more fun than 1st phase.\nBrain-burner. Feels really good to pull off a strategy.',
#   'reviewer_country': '',
#   'rating': 8.5,
#   'date': '2021-05-25 04:49:34',
#   'is_owner': True},
#  {'review': 'Derrick, Jessica, Jack?',
#   'reviewer_country': 'United States',
#   'rating': 8.75,
#   'date': '2023-05-09 19:28:40',
#   'is_owner': False},
#  {'review': '3-4 players',
#   'reviewer_country': 'France',
#   'rating': 0.0,
#   'date': '2025-04-19 03:31:41',
#   'is_owner': True},
#  {'review': 'i had a lot of fun playing this game with friends',
#   'reviewer_country': 'United States',
#   'rating': 10.0,
#   'date': '2025-04-18 21:28:27',
#   'is_owner': True},
#  {'review': 'Amazing game at every player count.',
#   'reviewer_country': 'Germany',
#   'rating': 10.0,
#   'date': '2022-11-26 14:20:04',
#   'is_owner': True},
#  {'review': '#1 on BGG for a long time - would like to play!',
#   'reviewer_country': 'United States',
#   'rating': 0.0,
#   'date': '2022-10-19 16:29:44',
#   'is_owner': False},
#  {'review': "The more I play the more I am converted. What I thought was a smart but hollow experience is now one of my most excited games to table. The balance of tactical plays, strategic planning, and player interaction, all wrapped in (what I think) is a beautiful package and theme, makes it clear why this is the King. It's not my favourite game, but damnit if it's not a brilliant one.",
#   'reviewer_country': 'Singapore',
#   'rating': 9.0,
#   'date': '2023-07-09 02:34:02',
#   'is_owner': False},
#  {'review': 'Original',
#   'reviewer_country': 'Serbia',
#   'rating': 0.0,
#   'date': '2025-04-18 05:20:03',
#   'is_owner': True},
#  {'review': 'Been in the cupboard for years.  Finally got to play with 2 great teachers and none of us are AP prone.\n\nBrilliant, loved every second.  I think it does depend on the people at the table like most games.  Any AP prone people at the table would kill this for me.\n\nWorthy of being top 10 game, not sure about number 1 though ;-)',
#   'reviewer_country': '',
#   'rating': 9.0,
#   'date': '2020-05-07 05:45:31',
#   'is_owner': True},
#  {'review': "One of the most responsive strategy games. And one of the best Euro's out there. More flexible than Brass: Lancashire. Very very good game. could be a bit stuffy. \n",
#   'reviewer_country': 'United States',
#   'rating': 0.0,
#   'date': '2025-04-17 17:23:07',
#   'is_owner': False},
#  {'review': "Une seule partie à 4. S'il n'était pas 1er au classement bgg je n'envisagerai même pas d'y rejouer.",
#   'reviewer_country': '',
#   'rating': 0.0,
#   'date': '2022-06-07 10:50:02',
#   'is_owner': False},
#  {'review': "- first couple of games you will simply try to understand the rules and flip a few tiles across a few industries, then you move on and start developing level I buildings and focus on two or three industries, maybe you even start messing around with the wild cards, at some point you then realize it is really important to flip tiles before the end of the first era and that you should to flip multiple tiles in one move, build multiple connections in one move, buy coal/iron when it's cheap and so on. It is all about the action efficiency, stupid! :)\n- you are working towards your own goals but along the way other players will most likely also benefit from your activities - and vice versa. Whether it is building a connection or supplying resources. Sometimes it makes me wonder: so this is how capitalism works - everyone works for their own advantage but it somehow all falls into place and everyone is better off?!? On average at least…\n- yet you can also hurt other players by occupying spaces they have had their eyes on or forcing them to connect your network to dealers \n- beautiful map and art although a bit too much the dark side ",
#   'reviewer_country': 'Germany',
#   'rating': 9.0,
#   'date': '2021-02-22 17:35:26',
#   'is_owner': True},
#  {'review': 'Just great!',
#   'reviewer_country': '',
#   'rating': 9.0,
#   'date': '2025-04-17 07:12:48',
#   'is_owner': True},
#  {'review': '+ insert reDrewno, iron clays 200',
#   'reviewer_country': 'Poland',
#   'rating': 9.0,
#   'date': '2020-10-21 17:19:47',
#   'is_owner': True},
#  {'review': 'Lo tiene David S. (marzo 2025)',
#   'reviewer_country': 'Spain',
#   'rating': 9.0,
#   'date': '2019-01-26 12:42:26',
#   'is_owner': True},
#  {'review': 'Owner: Katie',
#   'reviewer_country': 'United Kingdom',
#   'rating': 9.3,
#   'date': '2023-12-20 06:11:58',
#   'is_owner': True},
#  {'review': "Introduced this game by my mate and I can't stop thinking about it afterwards. Got myself a deluxe copy and played with my SO and she loves it too. My first 10 rating euro game in my collection, is almost flawless, would really like to try Lancashire next and hopefully more Brass games will come out in the future.",
#   'reviewer_country': 'Australia',
#   'rating': 9.0,
#   'date': '2019-11-29 05:58:12',
#   'is_owner': True},
#  {'review': "Beautiful in it's design, and elegant.\n\nI can't believe how much I enjoyed this game, and it's worth all of the praise it gets. It scales uniquely from 2-4 players, and even has a fairly accessible 'Short' version.\n\nA little finnicky, and hard to grapple with on the first go through, but you'll catch yourself wanting to push harder and harder for more efficiency on the next play.",
#   'reviewer_country': '',
#   'rating': 10.0,
#   'date': '2024-10-23 11:28:46',
#   'is_owner': True},
#  {'review': 'No necessary in-game text',
#   'reviewer_country': '',
#   'rating': 0.0,
#   'date': '2025-03-31 17:01:03',
#   'is_owner': True},
#  {'review': '2-4p',
#   'reviewer_country': 'Canada',
#   'rating': 0.0,
#   'date': '2024-07-16 03:04:19',
#   'is_owner': True},
#  {'review': "Incredible game. The rules are surprisingly not intimidating, it's strange. There's really only a few actions you're taking and you're limited to the cards in your hand, but there's an astonishing amount to consider. The nature of the rules and actions also result in new players feeling completely lost for the first half of the game. Thankfully there is an option to just only play one half. You lose out on a lot of the meaty planning ahead strategy, but new players can't comprehend that anyway. Allows you to still play through a teaching game in a couple of hours. The only bummer for me is so far I have mostly only played teaching/half games. \n\nStill my favorite economic game out there, it's a lot to sit down, setup and teach, but it's worth it every time. ",
#   'reviewer_country': 'United States',
#   'rating': 8.5,
#   'date': '2018-07-06 10:37:42',
#   'is_owner': True},
#  {'review': 'Not my cup of tea, but I can see why people love it.\nVery euro, but also very interactive. First plays can be very punishing for new players.\nIt is easy to teach, but there are many nuances difficult to remember and spot when playing. It can cause AP very easily. I would not seek it but I can play it again',
#   'reviewer_country': 'Canada',
#   'rating': 6.0,
#   'date': '2024-05-02 07:59:08',
#   'is_owner': False},
#  {'review': 'Played at ampthill on board. Complex but worth a second play.',
#   'reviewer_country': 'United Kingdom',
#   'rating': 0.0,
#   'date': '2025-03-09 12:42:54',
#   'is_owner': False},
#  {'review': 'I like Lancashire a bit better but these games are good enough to warrant owning and playing two slightly different versions.',
#   'reviewer_country': 'United States',
#   'rating': 8.0,
#   'date': '2021-11-22 13:10:03',
#   'is_owner': True},
#  {'review': '8.5',
#   'reviewer_country': 'Germany',
#   'rating': 8.0,
#   'date': '2020-01-30 10:56:32',
#   'is_owner': False},
#  {'review': "Step back in time - entrenched in the theme - working 29hours a day at mill… young folk just wouldn't believe you. Fantastic! ",
#   'reviewer_country': '',
#   'rating': 9.0,
#   'date': '2021-08-08 17:40:31',
#   'is_owner': True},
#  {'review': "One of, if not, my favorite board games. Lots of different strategies but you can't stick to one thing and have to adapt to what other players are doing. \n\nLove its blend of pvp + pve. Love the quality, design, everything.",
#   'reviewer_country': 'Indonesia',
#   'rating': 10.0,
#   'date': '2025-04-14 00:19:41',
#   'is_owner': True},
#  {'review': 'Best 3-4\n(Sleeved)\nKR+',
#   'reviewer_country': 'United Kingdom',
#   'rating': 10.0,
#   'date': '2025-04-12 20:05:59',
#   'is_owner': True},
#  {'review': 'Birthday present Sept. 2024',
#   'reviewer_country': 'United Kingdom',
#   'rating': 0.0,
#   'date': '2025-04-12 17:30:54',
#   'is_owner': True},
#  {'review': 'Descripción en español: Juego clasificado como euro de "construcción de rutas/redes" basado en la Revolución Industrial',
#   'reviewer_country': 'Chile',
#   'rating': 7.5,
#   'date': '2024-10-22 17:07:26',
#   'is_owner': True},
#  {'review': "Sleeved (FFG Grey)\nTinkertown 25 iron and 30 'coal' cubes",
#   'reviewer_country': 'United Kingdom',
#   'rating': 9.0,
#   'date': '2019-03-06 15:04:55',
#   'is_owner': True},
#  {'review': 'Cegieł',
#   'reviewer_country': 'Poland',
#   'rating': 0.0,
#   'date': '2021-07-07 17:38:08',
#   'is_owner': False},
#  {'review': '2-4',
#   'reviewer_country': '',
#   'rating': 0.0,
#   'date': '2025-04-12 07:48:24',
#   'is_owner': True},
#  {'review': 'La Obra maestra del tito wallace❤️',
#   'reviewer_country': 'Spain',
#   'rating': 10.0,
#   'date': '2025-04-12 00:38:28',
#   'is_owner': True},
#  {'review': "I'm still a novice with less than 10 plays under my belt, but this could be a top 5 game for me. I find the interaction between the players as the resource network grows to be so fascinating and unique. I'll revisit my rating once I have more plays under my belt",
#   'reviewer_country': 'Australia',
#   'rating': 9.5,
#   'date': '2019-08-03 02:08:04',
#   'is_owner': True},
#  {'review': 'The setup is fiddly and the rules are overly complex.\n* Sold by Timeless Board Games for me *',
#   'reviewer_country': 'South Africa',
#   'rating': 0.0,
#   'date': '2018-08-12 11:30:47',
#   'is_owner': False},
#  {'review': "I have the kickstarter Deluxe edition. It looks sooooo pretty that I don't want to play it. There is no game in my possession with a better build quality",
#   'reviewer_country': 'United States',
#   'rating': 9.0,
#   'date': '2017-04-26 10:43:20',
#   'is_owner': True},
#  {'review': "A good game. I personaly prefer Lancashire because it's a more streamlined version.In my opinion the game already was good enough. But this is still a good one.",
#   'reviewer_country': 'Ukraine',
#   'rating': 7.0,
#   'date': '2025-04-11 05:13:34',
#   'is_owner': False},
#  {'review': "Upgraded it to 9 and potentially to 10 moving forward. It does take a few plays to get around the ridiculous way goods transport around the map but once you accept that it's a great game.\n\nUpgraded to 6 after two plays. Still think it's fiddly as hell but it's definitely an interesting game.\n\nGiving it a reluctant 3 after one first play.\nSuper fiddly unintuitive rules:\n- Different ways the resources travel\n- The fact that lvl 1 buildings get cleared from the main board but not your personal board\n- 1 action for the 1st turn only for some reason\n- Can use bonus beer to ship goods but not to build tracks during phase 2\n\nReally hated the fact that you play canal part and then reset the game and count scores to play the rail phase with some useless buildings on the board you can't reuse. I took effort to develop and place lvl 2 buildings on the board and I can't reflip them for extra income, beer, etc? \n\nAlso the fact that you see the scores at the end of the canal phase, if you're quite far behind doesn't make you want to play the second phase anymore.\n\nEtc, etc.\n\nI basically liked nothing about the game after this first play.",
#   'reviewer_country': 'Portugal',
#   'rating': 9.0,
#   'date': '2022-02-23 07:39:42',
#   'is_owner': False},
#  {'review': "In friends' collection: I usually wait until I played games a few times before I do a first rating, but this game is an exception. The first time I played this game was already amazing and I can't stop thinking about new strategies I want to try. I'm looking forward to my next play of the game. This is exactly the type of game I love. It does all the things I want in a game and it does them right. ",
#   'reviewer_country': '',
#   'rating': 10.0,
#   'date': '2025-04-11 02:00:49',
#   'is_owner': False},
#  {'review': 'Martin Wallace economic game masterpiece.',
#   'reviewer_country': 'United States',
#   'rating': 10.0,
#   'date': '2025-03-17 22:43:40',
#   'is_owner': False},
#  {'review': 'Critical Thinking\nEconomics\nManagement\nMath and Numeracy\nProblem Solving',
#   'reviewer_country': '',
#   'rating': 0.0,
#   'date': '2025-04-07 15:16:44',
#   'is_owner': True},
#  {'review': 'Great game',
#   'reviewer_country': 'United States',
#   'rating': 10.0,
#   'date': '2025-04-10 07:13:31',
#   'is_owner': True},
#  ...]

# %%
def extract_tokens(text: str) -> list[str]:
    """Firstly remove all non alphabetic characters, having in mind that
    there are Unicode characters. After tokenization we remove stopwords (ENG+PL)
    and  remove all 1-2 chars lenghts words.

    Finally lemmatize tokens.
    """
    clean = re.sub(r"[\W]+", " ", text.lower())
    clean = re.sub(r"[\d]+", " ", clean)
    words = nltk.word_tokenize(clean)
    words = [w for w in words if w not in (word_difficulty.STOPWORDS_PL | word_difficulty.STOPWORDS_EN) and len(w) > 2]
    doc = nlp(" ".join(words))
    return [token.lemma_.lower() for token in doc if token.is_alpha]

# %% [markdown]
# # Unsupervised Text Classification

# %%
import polars as pl
from sklearn.datasets import fetch_20newsgroups

# load data
train = fetch_20newsgroups(subset='train', shuffle=False)
test = fetch_20newsgroups(subset='test', shuffle=False)

# parse data to pandas DataFrames
newsgroup_test = pd.DataFrame({'article':test.data, 'class_index':test.target})
newsgroup_train = pd.DataFrame({'article':train.data, 'class_index':train.target})

# load labels with keywords
labels = pd.read_csv('20newsgroups_keywords.csv',sep=';')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 13
#      10 newsgroup_train = pd.DataFrame({'article':train.data, 'class_index':train.target})
#      12 # load labels with keywords
# ---> 13 labels = pd.read_csv('20newsgroups_keywords.csv',sep=';')
#
# File ~/Documents/BGG/analysis/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/Documents/BGG/analysis/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/Documents/BGG/analysis/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/Documents/BGG/analysis/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/Documents/BGG/analysis/.venv/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '20newsgroups_keywords.csv'
