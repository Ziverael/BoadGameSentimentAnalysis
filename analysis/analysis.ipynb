# %% [markdown]
# # Setup

# %%
import asyncio
from collections import Counter
import json
import re
from pathlib import Path

from googletrans import Translator
from langdetect import detect, LangDetectException
import matplotlib.pyplot as plt
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import numpy as np
import polars as pl
from sklearn.preprocessing import MinMaxScaler
import spacy
from stopwordsiso import stopwords
from tqdm import tqdm
from tqdm.asyncio import tqdm_asyncio
from wordcloud import WordCloud

import utils
from utils import PATHS
# Out:
# /home/ziverael/Documents/BGG/analysis/.venv/lib/python3.12/site-packages/stopwordsiso/_core.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
# nltk.download('vader_lexicon')
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# # Tools

# %%
def extract_tokens(text: str) -> list[str]:
    """Firstly remove all non alphabetic characters, having in mind that
    there are Unicode characters. After tokenization we remove stopwords (ENG)
    and  remove all 1-2 chars lenghts words.

    Finally lemmatize tokens.
    """
    clean = re.sub(r"[\W]+", " ", text.lower())
    clean = re.sub(r"[\d]+", " ", clean)
    words = nltk.word_tokenize(clean)
    words = [w for w in words if w not in stopwords("en") and len(w) > 2]
    doc = nlp(" ".join(words))
    return [token.lemma_.lower() for token in doc if token.is_alpha]

# %% [markdown]
# # Load

# %%
with (PATHS.data / "games_reviews.json").open("rb") as f:
    data = json.load(f)

# %%
example_data = data[0]

# %%
example_data.keys()
# Out:
# dict_keys(['title', 'game_details', 'game_stats', 'game_reviews'])

# %%
Counter(extract_tokens(example_data["game_details"]["long_description"]))
# Out:
# Counter({'brass': 5,
#          'industry': 5,
#          'action': 5,
#          'birmingham': 4,
#          'game': 4,
#          'build': 3,
#          'network': 3,
#          'canal': 3,
#          'rail': 3,
#          'story': 2,
#          'predecessor': 2,
#          'develop': 2,
#          'establish': 2,
#          'era': 2,
#          'vps': 2,
#          'tile': 2,
#          'original': 2,
#          'sell': 2,
#          'loan': 2,
#          'card': 2,
#          'wild': 2,
#          'economic': 1,
#          'strategy': 1,
#          'sequel': 1,
#          'martin': 1,
#          'wallace': 1,
#          'masterpiece': 1,
#          'tell': 1,
#          'compete': 1,
#          'entrepreneur': 1,
#          'industrial': 1,
#          'revolution': 1,
#          'offer': 1,
#          'arc': 1,
#          'experience': 1,
#          'effort': 1,
#          'exploit': 1,
#          'market': 1,
#          'demand': 1,
#          'play': 1,
#          'halves': 1,
#          'win': 1,
#          'score': 1,
#          'count': 1,
#          'flip': 1,
#          'player': 1,
#          'track': 1,
#          'receiving': 1,
#          'perform': 1,
#          'pay': 1,
#          'require': 1,
#          'resource': 1,
#          'add': 1,
#          'link': 1,
#          'expand': 1,
#          'increase': 1,
#          'cotton': 1,
#          'manufacture': 1,
#          'pottery': 1,
#          'reduce': 1,
#          'income': 1,
#          'feature': 1,
#          'sixth': 1,
#          'scout': 1,
#          'discard': 1,
#          'location': 1,
#          'replace': 1,
#          'double': 1})

# %%
def recognize_language(text: str) -> str:
    try:
        lang = detect(text)
    except LangDetectException:
        lang = "en" #TODO: set special flag
    return lang

@utils.with_pickle_async()
async def translate_multiple(texts: list[str], lang_from: list[str], lang_to: list[str]) -> list[str]:
    async with Translator() as translator:
        async def translate_one(text, src, dest):
            t = await translator.translate(text=text, src=src, dest=dest)
            return t.text
        return await tqdm_asyncio.gather(
            *(translate_one(text, from_, to_) for text, from_, to_ in zip(texts, lang_from, lang_to, strict=True))
        )

# %%
example_game_reviews = [info["review"] for info in example_data["game_reviews"]]
from_langs =  [recognize_language(r) for r in example_game_reviews]
translactions = await translate_multiple(example_game_reviews, from_langs, ["en"] * len(from_langs), pickle_path=PATHS.pickles / "example_translations")
# Out:
# 100%|██████████| 3800/3800 [00:08<00:00, 423.20it/s]

# %%
example_game_reviews
# Out:
# ['2-4 [S]',
#  'Great game that somehow feels simple, yet every decision you make carries weight\n',
#  "If you can play this in 60 minutes you're playing too fast.  With my group a a game lasts about 45 minutes per player.\n\nKeep pushing up my rating..  This game continues to be my favorite and the favorite of our group.",
#  'Tabletop',
#  'I only played half a real game, but I was captivated throughout. Would play again.',
#  'Ship',
#  "The more I play, the more I realize it's more about playing the hand you're dealt, and less about strategy",
#  'Very good game. I might not say it is the best of all times, but it is definetely great. The mechanics are simple, but I consider that it takes a little time to adapt to them. You may need several playthroughs to achieve some sort of mastering. Revise every victory point possibility to plan your strategy, otherwise, it can be easy to fall pursuing things that are not profitable in the long term.',
#  "+ Artwork is great\n+ Great strategy game\n+ Lots of interaction\n+ Low luck factor\n+ Many paths to victory\n+ Brain burner \n- Quite long\n- Rules heavy \n- Theme is a bit boring\n\nDeep strategic economic game with many ways to win the game. It is surprisingly enough very interactive. I've only played it at 2 and 3 player count. ",
#  'Не фанат евро, это могло быть неплохо, не против сыграть в нее снова, если что, но сам предлагать ее не буду. И да, это точно не первое место BGG.',
#  'Most of my plays have been at 2p, and I thoroughly enjoyed every single game. \nHowever, it feels like it ends very quickly at 4p (a feeling it seems others at my table tend to have as well). \n\n',
#  'Pt: 3',
#  'In: October 2025',
#  'ES',
#  'M.Heavy Euro - Wallace, Trains',
#  "Arguably the best strategic area control, resource management game.  Just make sure you use other peoples beer and don't let them use yours.",
#  'Epic',
#  "haven't played it enough to really understand it. Heavy and thinky. need to log more plays",
#  "Brass est un jeu qui doit beaucoup de son succès à sa capacité à offrir peu de prises à la critique (hasard peu présent, édition irréprochable, thème mature, jeu élitiste). C'est un jeu surestimé qui surfe sur les défauts du classement BGG (les rééditions ont des notes excessivement hautes, surtout avec une refonte graphique et un matériel abondant hyper qualitatif. Ces rééditions prêchent des convaincus qui surnotent leurs jeux favoris au travers d'une nouvelle entrée sur BGG).",
#  'Your first game is likely going to be rough. However no doubt you will see the appeal of building up your own niche economy that ends up frustratingly reliant on and sometimes in favor the other players. At the end of each round you will be left going "oh I wish I did that," or "things could have gone well if you didn\'t do that", but still be left to admire how everything resulted in the end. After that rough first game, you are most likely going to arrange for another game, all to get better at this system.',
#  'B3u4, G2',
#  'Regal 14',
#  '£67.85 https://www.amazon.co.uk/Roxley-Games-ROX402-Brass-Birmingham/dp/1988884047?crid=2I7084BPZPFR5&dib=eyJ2IjoiMSJ9.AKBvx-qCEQ1s2PviGSbDhYyDSrcdKdGtfSi_ilfJCheyjNb5lf8iB5Kr8USCrowvqXNUC7k-hRITiyTddwAp1e-vXgssxL4xuGJa3X2ETt8Np9UmhR4kjr6WpnTMDMRj_VvxWnEgN6AY7c15BtQ-aWQy9Jis6jXCz3utNAtdZ5rT2epjPFsa2S4Te8RikY2S8yEHoXlcbHAEnprGxF1cy7ivg7o24JuypogPNga_UZOPS_Psun_ySg-365rKRCq8i06CmiXpEVyVf83N0o-ViZGc70ox5rE1PqNQ2yb6k4I.VZKtGk37XxVIkuMPPcDUbbo9eBxUHUpzCjO7chxTe9k&dib_tag=se&keywords=brass%2Bbirmingham%2Bboard%2Bgame&qid=1762604991&sprefix=brass%2B%2Caps%2C123&sr=8-4&th=1',
#  "Previously 9. The more you play this game the more it shines!\n\nIt has a relatively simple rule set with incredible depth. No need for expansions.... It's a modern classic.\n\nIf you like strategy without the need to attack your opponents to win, this is for you.\n\nThe interplay of you using up the other players resources benefitting both you and them is very satisfying and keeps everyone engaged.\n\nGreat family strategic game! ",
#  'I loathe this as much as I loathed the original Brass. And now add in hunger games for beer. \n\nOne and done.\n\nThe #1 game on BGG? Someone euthanize me.',
#  'Tedious and boring VP pusher with instant railway transition. Not my cup of tea? No, I’d rather smear my genitalia with fish paste and dangle them in a pool of hungry piranha. \n\nDingo',
#  'La primera partida había sido media trabada. En parte por las nuevas reglas y en parte porque, en el azar de la distribución de mercados iniciales, terminamos con uno de ellos cerrado y eso trastocó cómo se desenvuelve la partida (no lo rompe, pero no es lo más fácil de encarar la primera vez). En principio, me había dejado la sensación de que el agregado de opciones y profundidad no compensaba la pérdida del paso fluido del original.\n\nEn la última que participé, pasó lo mismo con los mercados iniciales y dijimos fuggit, y los shuffleamos de nuevo. Con las reglas más aceitadas y más mercados abiertos, la partida voló con la fluidez que recordaba que tenía el original, así que me reconcilié con esta nueva versión.\n\nPero hay que usar el lado del tablero de día, el lado del tablero de noche, salvo que uses un casco de minero con luz, no se distingue un pomo.\n\nTampoco sé qué traerá el juego como dinero, porque siempre usamos fichas de póker.\n\nUn clásico que conserva lo mejor de los eurojuegos de esa época: profundidad, opciones, decisiones, interacción, fluidez, con un cromo actualizado.\n\nMuy recomendable :star::star::star::star::nostar:',
#  'SpielboxRating 9-10, av. 9,20',
#  "Much more fun than the (old) original version. This took a few plays to grow on me. No in game text, has a central board and good balance between tactical and strategical play. Maybe a bit on the long side, but it's a really nail-biter till the end. I can see why this is rated so high as it is.",
#  "It's a great game, would struggle to get consistent plays.",
#  '+ 3D Printed insert\n+ Sleeves',
#  'I enjoy Lancashire and want to add this one to my collection at some point.',
#  'Euro medio muy limpio.',
#  'Great game!',
#  '건조하고 같은 웨이트 대 게임들과 비교 했을 때 룰이 잘 안 외워지는 편. 메인 메커니즘은 2018년 게임치곤 카탄처럼 고전 특유의 단순함. 같은 멤버로 할 경우 리플레이성도 의문임. 결론 재미는 단순하고 이해는 어려움.',
#  'Great game\n-scratches the economic itch\n-tight gameplay, but does not feel too limiting\n-not too long after you learn\n-straightforward ways to score\n-has a semi cooperative element to the game which make other players turns more interesting  \n-can be a bit tough to learn/teach first time\n-rules can feel contradicting when learning',
#  'kickstarter',
#  '+ Engaging tactics and strategy\n+ Agonizing decisions and tradeoffs\n+ Tight economy\n+ Player interaction\n+ Climactic ending\n- AP prone\n- Finicky rules and fiddliness\n- Downtime',
#  "BRASS BIRMINGHAM (2-4 players)\n\nDeluxe player aids: https://boardgamegeek.com/filepage/179522/deluxe-player-aids-brass-birmingham\n\nFanmade solo variant: \n\nhttp://www.mautoma.com/mautomas/brass-birmingham \n\nOnline app for solo variant so you don't have to print the cards: \n\nhttps://boardgamegeek.com/filepage/168370/brass-birmingham-george-solo-competitive-mode\n\nBrass Birmingham is better than Brass Lancashire. The Mautoma Solo variant is quite good but I prefer to play Brass as a multiplayer game. The game is a dry euro but a VERY good dry euro.",
#  'Reglas un poco obtusas, con excepciones y muchos detalles que hacen que tengas que estar revisándolas constantemente. La explicación hay que preparársela bien, no es sencillo asimilar los conceptos. \n\nMe gusta que todo el mundo participe en el tablero central y que pueda aprovecharse de las rutas y recursos de los demás, hay mucha interacción, sin duda lo que más me gusta del juego. La edición, una chulada también. Sin embargo, el juego tiene demasiadas reglas poco intuitivas y demasiados detalles por los que hay que estar pendiente (puede provocar entreturnos largos). Viendo que es un juego tan querido le he dado varias oportunidades pero definitivamente no es lo mío.',
#  'It’s Brass with a more-is-better approach: more buildings, more locations, more connections—and then beer. Less cutthroat and leaning toward a point-salad feel. The high rail scoring makes the rail era predictable, though some might see it as a more forgiving, flexible evolution of the original. Could rate higher, but I’d always pick Lancashire over this, which brings the rating down a bit.',
#  'Boardroom, PAX, 4 2-4, 2h',
#  "That's the most boring and ugly game I've ever played. Viscous snot is the most suitable description for it. 1000% overrated.",
#  'Loved playing and would recommend playing but did take us 4 and a half hours to learn and play as a 3. Worth it though',
#  'Sleeved with Shield Titan Super Sleeves (Clear)\nInsert included',
#  "Tentative rating.\n\nI understand how this game got its reputation. The puzzle involved is unique, which is such a rarity among the hundreds of Euros we see each year. It felt like the game is stimulating a whole new part of my brain's strategy center that I didn't know existed, and I love it.\n\nThe game is complex, the strategy is opaque, and it was a pain to teach with all of its minor titbits and exceptions. However, these won't matter after 20+ plays, and the game is solid enough to warrant that.",
#  '3.87',
#  'great euro styled game.\nflow of interaction is just a masterpiece.\nMartin is genious.',
#  'Less fluid than the black edition.',
#  "In my opinion, Lancashire is much better.\n\nLancashire is more straightforward and you focus on the strategy. You don't get tired of the multitude of tokens, in Lancashire there is only the essential ones. \n\nAfter playing Birmingham I always felt exhausted, but still liked the game. However, after playing Lancashire the time just flew and I would have wanted to play again right away.",
#  '2-4 [S]',
#  'Great game that somehow feels simple, yet every decision you make carries weight\n',
#  "If you can play this in 60 minutes you're playing too fast.  With my group a a game lasts about 45 minutes per player.\n\nKeep pushing up my rating..  This game continues to be my favorite and the favorite of our group.",
#  'Tabletop',
#  'I only played half a real game, but I was captivated throughout. Would play again.',
#  'Ship',
#  "The more I play, the more I realize it's more about playing the hand you're dealt, and less about strategy",
#  'Very good game. I might not say it is the best of all times, but it is definetely great. The mechanics are simple, but I consider that it takes a little time to adapt to them. You may need several playthroughs to achieve some sort of mastering. Revise every victory point possibility to plan your strategy, otherwise, it can be easy to fall pursuing things that are not profitable in the long term.',
#  "+ Artwork is great\n+ Great strategy game\n+ Lots of interaction\n+ Low luck factor\n+ Many paths to victory\n+ Brain burner \n- Quite long\n- Rules heavy \n- Theme is a bit boring\n\nDeep strategic economic game with many ways to win the game. It is surprisingly enough very interactive. I've only played it at 2 and 3 player count. ",
#  'Не фанат евро, это могло быть неплохо, не против сыграть в нее снова, если что, но сам предлагать ее не буду. И да, это точно не первое место BGG.',
#  'Most of my plays have been at 2p, and I thoroughly enjoyed every single game. \nHowever, it feels like it ends very quickly at 4p (a feeling it seems others at my table tend to have as well). \n\n',
#  'Pt: 3',
#  'In: October 2025',
#  'ES',
#  'M.Heavy Euro - Wallace, Trains',
#  "Arguably the best strategic area control, resource management game.  Just make sure you use other peoples beer and don't let them use yours.",
#  'Epic',
#  "haven't played it enough to really understand it. Heavy and thinky. need to log more plays",
#  "Brass est un jeu qui doit beaucoup de son succès à sa capacité à offrir peu de prises à la critique (hasard peu présent, édition irréprochable, thème mature, jeu élitiste). C'est un jeu surestimé qui surfe sur les défauts du classement BGG (les rééditions ont des notes excessivement hautes, surtout avec une refonte graphique et un matériel abondant hyper qualitatif. Ces rééditions prêchent des convaincus qui surnotent leurs jeux favoris au travers d'une nouvelle entrée sur BGG).",
#  'Your first game is likely going to be rough. However no doubt you will see the appeal of building up your own niche economy that ends up frustratingly reliant on and sometimes in favor the other players. At the end of each round you will be left going "oh I wish I did that," or "things could have gone well if you didn\'t do that", but still be left to admire how everything resulted in the end. After that rough first game, you are most likely going to arrange for another game, all to get better at this system.',
#  'B3u4, G2',
#  'Regal 14',
#  '£67.85 https://www.amazon.co.uk/Roxley-Games-ROX402-Brass-Birmingham/dp/1988884047?crid=2I7084BPZPFR5&dib=eyJ2IjoiMSJ9.AKBvx-qCEQ1s2PviGSbDhYyDSrcdKdGtfSi_ilfJCheyjNb5lf8iB5Kr8USCrowvqXNUC7k-hRITiyTddwAp1e-vXgssxL4xuGJa3X2ETt8Np9UmhR4kjr6WpnTMDMRj_VvxWnEgN6AY7c15BtQ-aWQy9Jis6jXCz3utNAtdZ5rT2epjPFsa2S4Te8RikY2S8yEHoXlcbHAEnprGxF1cy7ivg7o24JuypogPNga_UZOPS_Psun_ySg-365rKRCq8i06CmiXpEVyVf83N0o-ViZGc70ox5rE1PqNQ2yb6k4I.VZKtGk37XxVIkuMPPcDUbbo9eBxUHUpzCjO7chxTe9k&dib_tag=se&keywords=brass%2Bbirmingham%2Bboard%2Bgame&qid=1762604991&sprefix=brass%2B%2Caps%2C123&sr=8-4&th=1',
#  "Previously 9. The more you play this game the more it shines!\n\nIt has a relatively simple rule set with incredible depth. No need for expansions.... It's a modern classic.\n\nIf you like strategy without the need to attack your opponents to win, this is for you.\n\nThe interplay of you using up the other players resources benefitting both you and them is very satisfying and keeps everyone engaged.\n\nGreat family strategic game! ",
#  'I loathe this as much as I loathed the original Brass. And now add in hunger games for beer. \n\nOne and done.\n\nThe #1 game on BGG? Someone euthanize me.',
#  'Tedious and boring VP pusher with instant railway transition. Not my cup of tea? No, I’d rather smear my genitalia with fish paste and dangle them in a pool of hungry piranha. \n\nDingo',
#  'La primera partida había sido media trabada. En parte por las nuevas reglas y en parte porque, en el azar de la distribución de mercados iniciales, terminamos con uno de ellos cerrado y eso trastocó cómo se desenvuelve la partida (no lo rompe, pero no es lo más fácil de encarar la primera vez). En principio, me había dejado la sensación de que el agregado de opciones y profundidad no compensaba la pérdida del paso fluido del original.\n\nEn la última que participé, pasó lo mismo con los mercados iniciales y dijimos fuggit, y los shuffleamos de nuevo. Con las reglas más aceitadas y más mercados abiertos, la partida voló con la fluidez que recordaba que tenía el original, así que me reconcilié con esta nueva versión.\n\nPero hay que usar el lado del tablero de día, el lado del tablero de noche, salvo que uses un casco de minero con luz, no se distingue un pomo.\n\nTampoco sé qué traerá el juego como dinero, porque siempre usamos fichas de póker.\n\nUn clásico que conserva lo mejor de los eurojuegos de esa época: profundidad, opciones, decisiones, interacción, fluidez, con un cromo actualizado.\n\nMuy recomendable :star::star::star::star::nostar:',
#  'SpielboxRating 9-10, av. 9,20',
#  "Much more fun than the (old) original version. This took a few plays to grow on me. No in game text, has a central board and good balance between tactical and strategical play. Maybe a bit on the long side, but it's a really nail-biter till the end. I can see why this is rated so high as it is.",
#  "It's a great game, would struggle to get consistent plays.",
#  '+ 3D Printed insert\n+ Sleeves',
#  'I enjoy Lancashire and want to add this one to my collection at some point.',
#  'Euro medio muy limpio.',
#  'Great game!',
#  '건조하고 같은 웨이트 대 게임들과 비교 했을 때 룰이 잘 안 외워지는 편. 메인 메커니즘은 2018년 게임치곤 카탄처럼 고전 특유의 단순함. 같은 멤버로 할 경우 리플레이성도 의문임. 결론 재미는 단순하고 이해는 어려움.',
#  'Great game\n-scratches the economic itch\n-tight gameplay, but does not feel too limiting\n-not too long after you learn\n-straightforward ways to score\n-has a semi cooperative element to the game which make other players turns more interesting  \n-can be a bit tough to learn/teach first time\n-rules can feel contradicting when learning',
#  'kickstarter',
#  '+ Engaging tactics and strategy\n+ Agonizing decisions and tradeoffs\n+ Tight economy\n+ Player interaction\n+ Climactic ending\n- AP prone\n- Finicky rules and fiddliness\n- Downtime',
#  "BRASS BIRMINGHAM (2-4 players)\n\nDeluxe player aids: https://boardgamegeek.com/filepage/179522/deluxe-player-aids-brass-birmingham\n\nFanmade solo variant: \n\nhttp://www.mautoma.com/mautomas/brass-birmingham \n\nOnline app for solo variant so you don't have to print the cards: \n\nhttps://boardgamegeek.com/filepage/168370/brass-birmingham-george-solo-competitive-mode\n\nBrass Birmingham is better than Brass Lancashire. The Mautoma Solo variant is quite good but I prefer to play Brass as a multiplayer game. The game is a dry euro but a VERY good dry euro.",
#  'Reglas un poco obtusas, con excepciones y muchos detalles que hacen que tengas que estar revisándolas constantemente. La explicación hay que preparársela bien, no es sencillo asimilar los conceptos. \n\nMe gusta que todo el mundo participe en el tablero central y que pueda aprovecharse de las rutas y recursos de los demás, hay mucha interacción, sin duda lo que más me gusta del juego. La edición, una chulada también. Sin embargo, el juego tiene demasiadas reglas poco intuitivas y demasiados detalles por los que hay que estar pendiente (puede provocar entreturnos largos). Viendo que es un juego tan querido le he dado varias oportunidades pero definitivamente no es lo mío.',
#  'It’s Brass with a more-is-better approach: more buildings, more locations, more connections—and then beer. Less cutthroat and leaning toward a point-salad feel. The high rail scoring makes the rail era predictable, though some might see it as a more forgiving, flexible evolution of the original. Could rate higher, but I’d always pick Lancashire over this, which brings the rating down a bit.',
#  'Boardroom, PAX, 4 2-4, 2h',
#  "That's the most boring and ugly game I've ever played. Viscous snot is the most suitable description for it. 1000% overrated.",
#  'Loved playing and would recommend playing but did take us 4 and a half hours to learn and play as a 3. Worth it though',
#  'Sleeved with Shield Titan Super Sleeves (Clear)\nInsert included',
#  "Tentative rating.\n\nI understand how this game got its reputation. The puzzle involved is unique, which is such a rarity among the hundreds of Euros we see each year. It felt like the game is stimulating a whole new part of my brain's strategy center that I didn't know existed, and I love it.\n\nThe game is complex, the strategy is opaque, and it was a pain to teach with all of its minor titbits and exceptions. However, these won't matter after 20+ plays, and the game is solid enough to warrant that.",
#  '3.87',
#  'great euro styled game.\nflow of interaction is just a masterpiece.\nMartin is genious.',
#  'Less fluid than the black edition.',
#  "In my opinion, Lancashire is much better.\n\nLancashire is more straightforward and you focus on the strategy. You don't get tired of the multitude of tokens, in Lancashire there is only the essential ones. \n\nAfter playing Birmingham I always felt exhausted, but still liked the game. However, after playing Lancashire the time just flew and I would have wanted to play again right away.",
#  '2-4 [S]',
#  'Great game that somehow feels simple, yet every decision you make carries weight\n',
#  "If you can play this in 60 minutes you're playing too fast.  With my group a a game lasts about 45 minutes per player.\n\nKeep pushing up my rating..  This game continues to be my favorite and the favorite of our group.",
#  'Tabletop',
#  'I only played half a real game, but I was captivated throughout. Would play again.',
#  'Ship',
#  "The more I play, the more I realize it's more about playing the hand you're dealt, and less about strategy",
#  'Very good game. I might not say it is the best of all times, but it is definetely great. The mechanics are simple, but I consider that it takes a little time to adapt to them. You may need several playthroughs to achieve some sort of mastering. Revise every victory point possibility to plan your strategy, otherwise, it can be easy to fall pursuing things that are not profitable in the long term.',
#  "+ Artwork is great\n+ Great strategy game\n+ Lots of interaction\n+ Low luck factor\n+ Many paths to victory\n+ Brain burner \n- Quite long\n- Rules heavy \n- Theme is a bit boring\n\nDeep strategic economic game with many ways to win the game. It is surprisingly enough very interactive. I've only played it at 2 and 3 player count. ",
#  'Не фанат евро, это могло быть неплохо, не против сыграть в нее снова, если что, но сам предлагать ее не буду. И да, это точно не первое место BGG.',
#  'Most of my plays have been at 2p, and I thoroughly enjoyed every single game. \nHowever, it feels like it ends very quickly at 4p (a feeling it seems others at my table tend to have as well). \n\n',
#  'Pt: 3',
#  'In: October 2025',
#  'ES',
#  'M.Heavy Euro - Wallace, Trains',
#  "Arguably the best strategic area control, resource management game.  Just make sure you use other peoples beer and don't let them use yours.",
#  'Epic',
#  "haven't played it enough to really understand it. Heavy and thinky. need to log more plays",
#  "Brass est un jeu qui doit beaucoup de son succès à sa capacité à offrir peu de prises à la critique (hasard peu présent, édition irréprochable, thème mature, jeu élitiste). C'est un jeu surestimé qui surfe sur les défauts du classement BGG (les rééditions ont des notes excessivement hautes, surtout avec une refonte graphique et un matériel abondant hyper qualitatif. Ces rééditions prêchent des convaincus qui surnotent leurs jeux favoris au travers d'une nouvelle entrée sur BGG).",
#  'Your first game is likely going to be rough. However no doubt you will see the appeal of building up your own niche economy that ends up frustratingly reliant on and sometimes in favor the other players. At the end of each round you will be left going "oh I wish I did that," or "things could have gone well if you didn\'t do that", but still be left to admire how everything resulted in the end. After that rough first game, you are most likely going to arrange for another game, all to get better at this system.',
#  'B3u4, G2',
#  'Regal 14',
#  '£67.85 https://www.amazon.co.uk/Roxley-Games-ROX402-Brass-Birmingham/dp/1988884047?crid=2I7084BPZPFR5&dib=eyJ2IjoiMSJ9.AKBvx-qCEQ1s2PviGSbDhYyDSrcdKdGtfSi_ilfJCheyjNb5lf8iB5Kr8USCrowvqXNUC7k-hRITiyTddwAp1e-vXgssxL4xuGJa3X2ETt8Np9UmhR4kjr6WpnTMDMRj_VvxWnEgN6AY7c15BtQ-aWQy9Jis6jXCz3utNAtdZ5rT2epjPFsa2S4Te8RikY2S8yEHoXlcbHAEnprGxF1cy7ivg7o24JuypogPNga_UZOPS_Psun_ySg-365rKRCq8i06CmiXpEVyVf83N0o-ViZGc70ox5rE1PqNQ2yb6k4I.VZKtGk37XxVIkuMPPcDUbbo9eBxUHUpzCjO7chxTe9k&dib_tag=se&keywords=brass%2Bbirmingham%2Bboard%2Bgame&qid=1762604991&sprefix=brass%2B%2Caps%2C123&sr=8-4&th=1',
#  "Previously 9. The more you play this game the more it shines!\n\nIt has a relatively simple rule set with incredible depth. No need for expansions.... It's a modern classic.\n\nIf you like strategy without the need to attack your opponents to win, this is for you.\n\nThe interplay of you using up the other players resources benefitting both you and them is very satisfying and keeps everyone engaged.\n\nGreat family strategic game! ",
#  'I loathe this as much as I loathed the original Brass. And now add in hunger games for beer. \n\nOne and done.\n\nThe #1 game on BGG? Someone euthanize me.',
#  'Tedious and boring VP pusher with instant railway transition. Not my cup of tea? No, I’d rather smear my genitalia with fish paste and dangle them in a pool of hungry piranha. \n\nDingo',
#  'La primera partida había sido media trabada. En parte por las nuevas reglas y en parte porque, en el azar de la distribución de mercados iniciales, terminamos con uno de ellos cerrado y eso trastocó cómo se desenvuelve la partida (no lo rompe, pero no es lo más fácil de encarar la primera vez). En principio, me había dejado la sensación de que el agregado de opciones y profundidad no compensaba la pérdida del paso fluido del original.\n\nEn la última que participé, pasó lo mismo con los mercados iniciales y dijimos fuggit, y los shuffleamos de nuevo. Con las reglas más aceitadas y más mercados abiertos, la partida voló con la fluidez que recordaba que tenía el original, así que me reconcilié con esta nueva versión.\n\nPero hay que usar el lado del tablero de día, el lado del tablero de noche, salvo que uses un casco de minero con luz, no se distingue un pomo.\n\nTampoco sé qué traerá el juego como dinero, porque siempre usamos fichas de póker.\n\nUn clásico que conserva lo mejor de los eurojuegos de esa época: profundidad, opciones, decisiones, interacción, fluidez, con un cromo actualizado.\n\nMuy recomendable :star::star::star::star::nostar:',
#  'SpielboxRating 9-10, av. 9,20',
#  "Much more fun than the (old) original version. This took a few plays to grow on me. No in game text, has a central board and good balance between tactical and strategical play. Maybe a bit on the long side, but it's a really nail-biter till the end. I can see why this is rated so high as it is.",
#  "It's a great game, would struggle to get consistent plays.",
#  '+ 3D Printed insert\n+ Sleeves',
#  'I enjoy Lancashire and want to add this one to my collection at some point.',
#  'Euro medio muy limpio.',
#  'Great game!',
#  '건조하고 같은 웨이트 대 게임들과 비교 했을 때 룰이 잘 안 외워지는 편. 메인 메커니즘은 2018년 게임치곤 카탄처럼 고전 특유의 단순함. 같은 멤버로 할 경우 리플레이성도 의문임. 결론 재미는 단순하고 이해는 어려움.',
#  'Great game\n-scratches the economic itch\n-tight gameplay, but does not feel too limiting\n-not too long after you learn\n-straightforward ways to score\n-has a semi cooperative element to the game which make other players turns more interesting  \n-can be a bit tough to learn/teach first time\n-rules can feel contradicting when learning',
#  'kickstarter',
#  '+ Engaging tactics and strategy\n+ Agonizing decisions and tradeoffs\n+ Tight economy\n+ Player interaction\n+ Climactic ending\n- AP prone\n- Finicky rules and fiddliness\n- Downtime',
#  "BRASS BIRMINGHAM (2-4 players)\n\nDeluxe player aids: https://boardgamegeek.com/filepage/179522/deluxe-player-aids-brass-birmingham\n\nFanmade solo variant: \n\nhttp://www.mautoma.com/mautomas/brass-birmingham \n\nOnline app for solo variant so you don't have to print the cards: \n\nhttps://boardgamegeek.com/filepage/168370/brass-birmingham-george-solo-competitive-mode\n\nBrass Birmingham is better than Brass Lancashire. The Mautoma Solo variant is quite good but I prefer to play Brass as a multiplayer game. The game is a dry euro but a VERY good dry euro.",
#  'Reglas un poco obtusas, con excepciones y muchos detalles que hacen que tengas que estar revisándolas constantemente. La explicación hay que preparársela bien, no es sencillo asimilar los conceptos. \n\nMe gusta que todo el mundo participe en el tablero central y que pueda aprovecharse de las rutas y recursos de los demás, hay mucha interacción, sin duda lo que más me gusta del juego. La edición, una chulada también. Sin embargo, el juego tiene demasiadas reglas poco intuitivas y demasiados detalles por los que hay que estar pendiente (puede provocar entreturnos largos). Viendo que es un juego tan querido le he dado varias oportunidades pero definitivamente no es lo mío.',
#  'It’s Brass with a more-is-better approach: more buildings, more locations, more connections—and then beer. Less cutthroat and leaning toward a point-salad feel. The high rail scoring makes the rail era predictable, though some might see it as a more forgiving, flexible evolution of the original. Could rate higher, but I’d always pick Lancashire over this, which brings the rating down a bit.',
#  'Boardroom, PAX, 4 2-4, 2h',
#  "That's the most boring and ugly game I've ever played. Viscous snot is the most suitable description for it. 1000% overrated.",
#  'Loved playing and would recommend playing but did take us 4 and a half hours to learn and play as a 3. Worth it though',
#  'Sleeved with Shield Titan Super Sleeves (Clear)\nInsert included',
#  "Tentative rating.\n\nI understand how this game got its reputation. The puzzle involved is unique, which is such a rarity among the hundreds of Euros we see each year. It felt like the game is stimulating a whole new part of my brain's strategy center that I didn't know existed, and I love it.\n\nThe game is complex, the strategy is opaque, and it was a pain to teach with all of its minor titbits and exceptions. However, these won't matter after 20+ plays, and the game is solid enough to warrant that.",
#  '3.87',
#  'great euro styled game.\nflow of interaction is just a masterpiece.\nMartin is genious.',
#  'Less fluid than the black edition.',
#  "In my opinion, Lancashire is much better.\n\nLancashire is more straightforward and you focus on the strategy. You don't get tired of the multitude of tokens, in Lancashire there is only the essential ones. \n\nAfter playing Birmingham I always felt exhausted, but still liked the game. However, after playing Lancashire the time just flew and I would have wanted to play again right away.",
#  "Too many little nit-picky rules.  It's fine, but I always get frustrated when I play it.  Wish it was a little more intuitive and elegant in its design.  I can see why people like it - my group loves it - just not my favorite.",
#  '25\n50€',
#  "This game is not about deciding what to do. It's about figuring out what you can do by navigating the silly amount of clunky exceptions slowly but surely chipping away your decision space until only 1-2 options are remaining. Turns take a long time not because of strategy, but because of how fiddly everything is. The rules are nonsensical from a logic standpoint. Some resources follow networks, some teleport, some do both, sometimes, except x and y and z. And then, halfway through the game, the connections between the places you worked on for the last hour and a half have to be removed and redone from scratch in the second half. The graphic design is abysmal, symbols are lost in the unnecessary detail, everything becomes a blurry mess, while important information is hidden away in the corners. The player aids that come in the box are worthless, the game is genuinely unlearnable and unplayable without the user-made ones. Furthermore, the setup and the mid-game scoring/upkeep are tedious, fiddly and take way too long. This game does not deserve the praise it gets, at all.",
#  'Was my #1 game! (2022)\nI love the shared economy, board building, income, and theme of this game.',
#  'самоделка',
#  "good game , \nbrass Birmingham = wildcatters ( underrated )\nhas the same feel: \n-pick an area through cards on a map\n- play your actions , build, develop, trains ... in that area\n- use each other's  network\n....",
#  'Loaned to Connor Smith on 11/3/2023, returned 1/22/2024\nLoaned to Cade Loving on 3/16/2024, returned',
#  'not fun no matter how hard i try',
#  '+Incredible depth of strategy. Brain burning turns trying to figure out what, where and in which order to build. \n+The player economy and heavy interaction is a joy. "Helping" other players out by flipping their tiles makes everyone feel good, but can quickly swing to tense denial as someone takes your last beer. Need to always be on your toes to see how changes in the board state benefits or harms you.\n+Lots of opportunities to feel clever in short-term tactics to take advantage of board/market state, and also longer-term planning for big sales. \n\n-Easily creates AP in players, making the game drag at 4p.\n-Takes a couple plays to really see the tactics and strategies. First play is mostly just figuring out WHAT you can do with your cards.  \n\n≈The cards act as a limit to what you\'re able to do, which is not my preference for a heavy strategy game. The "do the best with what you\'ve been given" feels more tactical. Contrast this with Terra Mystica where all the actions are available to you, but it is your resources that limit your choices. \n≈Strategizing and playing well is a massive brain burn. It\'s a lot of work just figuring out what the cards allow you to do, before you can even work out an optimal strategy from the available options.\n\n8 > 7.8 > 8',
#  "Doesn't sound that interesting, but the #1 game ever, so might as well try?",
#  'Partially Played at ProCon 2024. Was the last day, we were both exhausted so I will not rate just yet until there is another chance to play it.',
#  'Overall, it’s a solid game, but I expected more from something ranked #1. If it held a lower position, I’d likely view it more favorably. Also, the theme drags everything else down.',
#  'A bit too repetitive',
#  'A superb economic game\n',
#  'Played once and enjoyed it. It took several turns before it started to click, but not until end of the game that some of the scoring really started to make sense.',
#  '2-4',
#  'We played together with my wife. We love the game, the its number 1 place on the ranking list is well deserved. The learning curve took some time, we watched tutorials as some rules were not easily understandable in the hungarian rule book (at least for us).\n\nThe game with 2 players is fun and pretty fast, with little downtime. Both eras are fun and once you figure out certain rules it can be fun. There are more detailed reviews, but what I have to say is that this is a well designed game (a bit too dark for my taste and eyes) made for us, as we like euro games with less or zero luck.',
#  'The perfect german.',
#  'A heavy boardgame classic with a short rulebook presenting relatively few and absolutely clear rules, a simple and convincing iconography, a truely atomspheric artwork and an outstanding thematic embedding.\nTons of tactical options, dilemmas and decisions just wait to be explored, interaction galore. Gameplay is very demanding, entertainment guaranteed. Sheer enthusiasm if a plan works, pure frustration if it doesn´t, \nThe board game companion to "Hard times" by Charles Dickens or "North & South" by Elizabeth Gaskell.\nBest board game ever? I don´t know, but it´s extraordinary.\n(SPIEL25 Essen 25.10.25)',
#  'Skopje Insert 3d',
#  "Pros:\nGreat theme and artwork. It looks beautiful on the table.\nUsually finishes within reasonable time\nCons:\nSome of the mechanics in this game are unnecessarily complex for complexity sake. \nTransition from canal to rail era breaks the rhythm of the game . Scraping all those old tiles off the map is fiddly and annoying.\nSetup is a drag. Having to meticulously place all the tiles on player boards feels like a chore and is annoying due to the fact that most of them don't get used.",
#  '*',
#  'M: 2-4',
#  'Nagyon okos pozitív-negatív interakció.\nSzuper a változó piac és a játékkossorend okos kezelése.\nA téma "meh", de legalább szépen van megvalósítva.\nA sör mechanikája számomra nem olyan érdekes, mint a kikötőké.\nSokkal több a lehetőség, mint a Lancashireben, emiatt veszít kicsit a feszültségből.\nMegérdemelten BGG top 1.',
#  'It it great',
#  'Brass: Birmingham (2018) https://tarsasjatekok.com/tarsasjatek/brass-lancashire-2007/kiegeszito/brass-birmingham-2018 Gavan Brown, Matt Tolman, Martin Wallace Artist: Gavan Brown, Lina Cossette, David Forest, Gui Landgraf, Damien Mammoliti, Matt Tolman Rank: Overall 1 Strategy 1 Spiel des Jahres 2018 Év játéka jelölt TEMU',
#  'fun!',
#  'A crunchy and smooth euro. Certainly a bit heavy, but the game is a blast to play. I really need to play this one more. This game is another proof that hand-management is the best mechanism in gaming. The current king of BGG, it\'s definitely one of the best euros that I\'ve ever played. The set up is a bit long, but it\'s all worth it. All the mechanics of the game shines through, and it\'s very engaging and fun to construct new "buildings" and deliver goods. And the beautiful artwork is just the cherry on top.\n\nThat being said, it does still feel a bit dry and less exciting compared to lots of other heavy euro games that I love. I personally enjoy A Feast for Odin, Kanban EV, and Great Western Trail a lot more. Maybe because the currency and numbers in those games are smaller and less math-y. ',
#  "Industrial Revolution England-Themed, Heavy Economic Euro-Game.\n2-4 Players. (Best With 3-4 Players).\n\n'Deluxe Edition Comes With Upgraded Player Mats, A Custom Insert, And Upgraded Money Chips'.\n\n“Sleeved”",
#  "This is a very interactive game: players must look for ways to interfere with their opponents’ plans by blocking access to markets and resources. While that’s going on, you must somehow implement a plan of your own while factoring in all the ways your opponents could mess it up. The result is a fascinating but often frustrating game.\n \nThe art and graphics are too dark, even on the “daylight” side of the double sided board. This is too bad because the art is excellent. The dark shading is meant to be thematic by portraying the dirty coal smoke pollution of the period. It’s as if a dark grey filter is overlaid on the board but it’s so dark it's difficult to discern the features necessary for play without bright room lighting. ",
#  'Steam version but not good',
#  'Preferred player count: 4p\nInteraction: High, while still being a Euro.',
#  'Solo',
#  "It's.... fine. Would you have told me this is the number 1 rated board game on BGG after playing it I would have never believed you. \n\nMaybe I need to try it again?",
#  '2-4 B: 3-4\nW: 3.87',
#  'The absolutely most overrated game ever. Boring and stale. Lacking a lot of variation and dynamic to be even near a good game for me.',
#  'Sleeved with:\nGGS10063ML Standard Card Game Matte (66 x 91)',
#  'Aesthetic: 1\nMechanism: 2\nInvolvement/length/fluid: 2\nReplayability: 2\nOther: 1',
#  '+ Iron Clay Upgrade\n+ Playmat',
#  'E. 60',
#  'H',
#  'To test',
#  'Played only once with friends and fell in love. Awesome game. Will try it again to get more of it.',
#  '1 play',
#  '낙보하',
#  'We played Brass as Kickstarter and Deluxe edition (which is the same quality and tokens) and as 4, 3 and 2 player games. Its incredibly flexible and game mechanics are challenging enough to keep you busy during downtime (which it has) but overall, player interaction is very good and we can truly recommend it because of its re-playability in all constellations.',
#  'Excellent. Deep strategy with clear rules that are not even that complex. The only downside is that you constantly have to do a LOT of coin exchange to have exact change.',
#  'Played (IRL & TTS)',
#  '3 4 players',
#  'Theme is so great. I was born in Dudley and am very proud of our industrial heritage. This game is the best attempt to place the player at the heart of the industrial revolution. \n\nAfter playing a few games I realised it requires a lot of time investment to play and improve but having spent that time I really appreciate the nuance of this tight design. Exclusively played at 2 players.',
#  'tiefe strategische Möglichkeiten, Wettbewerb um Platz, Mitnutzung von Ressourcen von Mitspielern...\nWiederspielwert aus meiner Sicht hoch',
#  'Best at 2',
#  '2025',
#  'N/A Expansions\n\n(Folded Space Insert)',
#  'JJ2',
#  'Roxley Games',
#  'Gave it a shot to see what all the hype was about, and I was pleasantly surprised! The economic choices are varied. Stealing resources from others, or getting your resources stolen, does not feel too cutthroat since you get hefty benefits from depleting resources, no matter who was responsible for this. This makes these "take that" choices feel less malevolent and the less obvious choice to take, because you need to think about whether it helps them more than it helps you. It\'s also surprisingly not a super long game unless you have players with bad cases of AP. The setup is a bit tedious, but I always measure games by the setup/fun ratio, and the fun in this case is worth it.',
#  '2024:I\n2025:IIII',
#  'English retail edition. Includes https://boardgamegeek.com/boardgameaccessory/306354/brass-birmingham-lancashire-folded-space-insert\n\nBox has moderate shelf wear and whitening, seen here:\nhttps://boardgamegeek.com/image/9176195/lboucheron\nhttps://boardgamegeek.com/image/9176197/lboucheron\nhttps://boardgamegeek.com/image/9176194/lboucheron\n\nThe previous owner glued together the Folded Space insert. I believe they put away the game components before the glue was fully dry, which led to a few pieces sticking and tearing when removed. All the damaged pieces I could find are shown here:\n\nhttps://boardgamegeek.com/image/9176196/lboucheron\n\nAll other components are in excellent condition. Cards are sleeved in premium sleeves.',
#  'Such an excellent design and the reprint is out of this world!',
#  "Complex game with many strategies available. Great game of it's genre",
#  'Need to Review',
#  'Kichen - Schwaarzt Regal',
#  "Find this one a little harder to get my head around than Lancashire, but probably just because I don't own it.",
#  'Kickstarter Spieleschmiede mit Iron clays ',
#  '3D Printed Insert',
#  'I mean what can I even say that anybody else hasn’t already? It’s Brass Birmingham. That’s all you need to know, and while it isn’t one of my all time favorites it’s undeniably fantastic. Brass keeps you on your toes in way that rewards both long term planning and clever decisions on the fly, making you constantly adjust to the ever fluctuations of the market. Brass can feel very frustrating at times, sure. However anyone with a love of the hobby who is willing to give it a good amount of plays will see why this is the number one game of all time. At least until camel up inevitably overtakes it as it should.',
#  'Highest Rank: 1 in 2025',
#  "Puzzle-y and thinky game. Lots of strategies to explore. Good player interaction, in terms of racing for certain spots and resources, and using other player's connections and resources (coal, iron, & beer). Very crunchy.",
#  "For two players, it isn't our household first choice.  But it's a really fun game to have in the collection and play with 3 or 4.",
#  'See other copy.',
#  'One play: Nice game, random location of selling points made half the map unused.',
#  'Check',
#  '[u]Expansions & Upgrades:[/u]\n- Iron Clays',
#  'Had a lot of fun with this, great mechanics for the most part and lots of interesting interaction.  Really enjoy the markets, loans, network building etc..  So much interaction and so many great small quick decisions.',
#  '@TX',
#  'Sleeved / Inserted',
#  "I don't like beer. ",
#  'Zmwo',
#  'played\n',
#  'Really enjoyed they game. It was challenging to set up your turns but it was fun. Played it with 2 others. ',
#  'Keep',
#  'Best: 3-4\nOwner: Adam A',
#  '* Sleeved ✓\n* Custom Insert - I want one',
#  '30% luck , 70% strategy',
#  "Took another run at Birmingham after hitting 20+ plays of Lancashire. Confirmed that for our tastes, it's worse in every way. A frustrating, lengthy, overly procedural experience that offers less interaction than the original. Lowered rating to a 6. I'm surprised more gamers new to the system don't bounce off Birmingham. \n===================================================\nFinally got this to the table after almost a dozen plays of Lancashire.\n\nBirmingham is much fiddlier. Much more difficult to put together a sequence of useful actions. The addition of beer, and the wonky benefits of manufactured goods and pottery, make for a more uneven and frustrating experience all around. That’s not sour grapes - I won handily.\n\nPresumably, Birmingham is intended to refresh the challenge for people who have played out Lancashire. Fair enough. But I won’t be coming back to it any time soon - Lancashire isn’t a lifestyle game for me, so at 6-7 plays a year I expect I have years of play before it starts to get stale. I doubt Birmingham sees the table again in that time.",
#  'Premium\n(Deluxe Edition)',
#  "What a cool game. The aesthetic is great, the strategy runs deep, and I absolutely adore the interconnectedness of the economy. Seeing this level of interaction in a Euro is so refreshing. The players have immense agency over the state of the game, and the way it all comes together is magical.\n\nThat said, some of the rules are incredibly unintuitive, bordering on arcane (iron can teleport, coal cannot, beer can for you, etc). There's enough weirdness to make it genuinely difficult to explain with a straight face. It's not particularly complex in the traditional sense; there's not that many actions you can take, but these strange caveats combined with the obtuse nature of how to actually play the game well makes for a large barrier to entry. I also find the game can veer into being slightly dry after many plays.\n\nStill, this is an amazing design. My only real critiques are in regards to the teach, and once players learn it this is a masterpiece. The fact that this game allows for this level of enmeshment between the players is a breath of fresh air, and something I must find more of. ",
#  '电厂的plus版，但是总感觉没有电厂那么简洁，刚开始玩会很容易村，多玩几把了会懂点他的设计意图',
#  'aliexpress',
#  'DS',
#  'PoS',
#  'Hard to teach but smooth as silk once everyone gets it. The game gives you that perfect desire a game should - to play it again because you think you know where you can do better next time.',
#  'Mary and I love this game.  Such a fun strategy game that does not get boring. ',
#  '1/2 off @ Barnes and Noble 2025',
#  'This is the best economic game I have. I am really proud to have the Kickstarter edition. It is a number 1 more than deserved.',
#  "[b]Thoughts:[/b] Not sure this deserves #1 on BGG, but it's an amazing game without question. Doesn't get to the table as much as we'd like so it takes a minute to get back into the rules. When we do though, it's always a joy. Every decision matters and the economic engine is unlike anything else.\n\n[b]Tag(s):[/b] Economic, Heavy Euro, Network Building\n[b]Best Player Count:[/b] 2-4, {3-4}\n[b]Rating:[/b] 9, [color=red]-0.5[/color]\n[b]Own:[/b] Physical",
#  "This is a great game. I don't know whether I'm slightly biased being from the Midlands but this is surely better than the Lancashire one! ? The number of components can be a little daunting at first but once you see past the sheer number of little tokens stacked on your player boards, underneath is quite a simple game with a couple of key mechanisms to remember. Unfortunately, my wife's not there yet, so it doesn't hit the table enough but I would probably play this game most weeks if I could. ",
#  'Premium Sleeved (Paladin - Percivals)\nPainted Barrels\nDeluxe Iron Clays\n3D Printed Player Trays\n3D Printed Insert\n\n09235/20000',
#  "It's a good game. Is it worthy of being #1? I don't think so but is definitely up there if euro is your thing. I enjoy playing but it would be rare for me to suggest out of my other games.",
#  "Played at Mini Wellycon 2024. Very smart highly interactive and interconnected economic Euro. A bit dry but really interesting. Only played once and clearly it's the sort of game you need to play a few times to really get to grips with it. I wouldn't put it #1 on my personal list, but I can see how it's such a BGG hit.",
#  "A solid game, I'm just not as excited about it as most other people seem to be. Bought at Essen Spiel '19.",
#  '참신하고 재밌음',
#  '9',
#  "Setup: Extremely hard to setup and start\nLearning: Hard to learn\nGame Design: Well designed, with multiple integrated mechanics and a lot of replayability\nArt: Very stylized, finding towns are a challenge\nSocial: Not really social, people play alone, don't even have to be here\nCompetitive: Can be competitive, but more, can create a lot of achievements as there are probably 100s of strategies that work\nScoring: Not too hard as most of the stuff is scored during game",
#  '2-4\nNoEng',
# ...
#  '(Sleeved; matte)\n\nPlaymat',
#  'Sleeved\nInsert',
#  'Just boring',
#  'game is so very elegant and dynamic every time',
#  "probably the best economic game I've ever played...",
#  "Tout simplement une merveille ludique ! Aussi bon, quoique différent, que son grand frère. Agréable à 2 ou 3 contrairement à Lancashire qui nese joue qu'à 4.",
#  'Ab 50€ kann man überlegen\nFür knapp unter 30 stonks',
#  'One of the best strategy game designs of all time.',
#  'theme: train, economic\nbest: 3-4\ntime: average (~2h)\n',
#  '1-4',
#  'WANT',
#  'Best with 4 player, as you get more interactions.',
#  '2-4 players\nHardcore\nPhilly',
#  'Printed Organizer',
#  'Amazing game but takes 2 hours to play, not everyone is up to play it but I love it!',
#  'Erklärer/Spielleiter: Thierry',
#  'Mejor juego económico que existe',
#  'Heavy-2',
#  'Sloyca Premium',
#  'Signed Copy',
#  '80€ + 56€ insert + 8€ schalen + 39,50€ token',
#  'Not sure if its the best boardgame ever, but definetly in the top 5',
#  "Played the new BRASS: BIRMINGHAM yesterday and completely blown away by it (even though I sucked at it). Strong core mechanics, very compelling and elegant gameplay and the most kick-ass production for a Euro I have ever seen (without being  over-produced like most KS games I see). This is Brass done right.  Can't wait to play again...& again!\n\nMy biggest critique of the game (if at all) is related to its major strength—aesthetics. While the art IS spectacular and looks just that on the computer screen where the light of a thousand suns from tiny pixels bring out all the details, I am afraid the printing process does not do justice to the darker palette. This severely impairs the playing of the game in sub-optimal lighting conditions (many cafes, pubs and non-game room areas in condo apartments have this problem). The location banners have similar tonal values and hence can be hard to identify (again, ONLY in sub-optimal lighting conditions) Having said that, it does look AWESOME in natural daylight and/well-lit rooms. I am only making this point because I am REALLY loving the game and wish it was as perfect as it could have been. \n\nAlso, because of the Kickstarter success, it would have been very practical and helpful if a stretch goal was player trays to go with the awesome player mats so all the tiles could be stored in the correct place and the game does not need the 5-6 min painful setup of sorting and placing tiles. Much like games such as Wasteland Express , Reckoners etc. Love the Iron Clays though...cant imagine playing without them!\n--------------------\n\nFavorite things...\n► Brass: Birmingham reinvents a classic, building upon what worked the most and improving things that did not. The depth the game offers relative to its complexity and ruleset is simply the best.\n► The player interaction is another highlight for me. The game works like a dynamic shared economy where every action affects others—networks, market prices, and resource access make Brass feel alive and competitive. This is my absolute favorite kind of player interaction.\n► There are multiple paths to victory, which serve a varied degree of challenges, allowing players to pick what seems most challenging and/or fun for them.\n\nMore, on this & other games in my ALL TIME - TOP 100  on my ⟣⧗First Pass⧗⟢ Blog:\nhttps://boardgamegeek.com/blog/9052/blogpost/172984/anim8rs-top-100-from-1000-2024-25-to-01",
#  'Very good game; one of my top euros. Very fiddly setup and some mechanics are clunky, but otherwise I love the way the game looks and plays. Slightly better than Lancashire, I think, and a major improvement over original Brass in terms of looks.\n\nKey downside in my opinion is that the card actions are hard to remember and manage, especially with new players. People need to be very diligent about spending cards for actions and drawing back up to 8 cards. Very, very common to get to the end of an era with one person having too many cards.',
#  "Matt's collection",
#  'Played once. Looong game. \nOnly for hardcore gamers',
#  'Dobio za rodjendan od Leona i Jelene',
#  'Players C2-4 B3-4\n60-120min',
#  "2 - 4 players\nCan be a bit heavy and some players are susceptible to AP'ing a bit much.",
#  "Haven't tried but my immediate circle doesn't have it and it sticks out as the top boardgame on many lists that I haven't tried and am interested in.",
#  'Insert from PrintablesByCaren (Etsy $37)',
#  'Best game of all time.\n\nMid-heavy euro with a lot of player interaction and a lot of replayability.',
#  "After a while I sold this and I bought the original. If Lancashire didn't exist, this rating would higher. The problem is, they made a worse version of a good game.\n\nIt is more convoluted than Lancashire, with more little bits and adapted to modern eurogamers. The game is more forgiving. No matter how bad the situation is, you can always do something, it is not nearly as tight as the original. Second era is just everyone placing connections and beer. The variable setup is nice, but Lancashire is superior in every other aspect.",
#  'Yes',
#  'The depth/complexity is too small for my taste. Whenever I had my turn planned, I realized that I missed another special rule (because each resource is handled differently). I guess this becomes easier over time but it still requires a lot of mental resources to just get all of the constraints right.',
#  'A really interesting game with a lot of cool mechanics. It takes a while to play though you can set an ealier stopping point (the game has obvious eras) should you not want the game to take too long. It is a bit more complicated than some so it helps to have an experienced person at the table.',
#  'Very challenging and fin game',
#  'lang_eng cat_strategy',
#  'Dinged corner,',
#  '[76] 65x90 boardm sleeve',
#  "Great network building and resource management game. \n\nInterestingly, this game has many actions where the action you're taking benefits yourself, but also another player. For example, you can take other players' resources on building they've built, but they want their buildings to be emptied so that their building tiles can be flipped and score them points and income.\n\nThere is a soft reset of the board in the middle of the game as well, which is definitely something to consider. If you manage to get out one of your buildings that don't get removed by this soft reset after the first era, they will score twice.\n\nI have heard countless times that this game was very cutthroat, but honestly, I didn't find it so compared to other network building games. Yes, you can cut someone's network short with your own, but that means you're likely cutting your own network too. Other players can use each other's networks anyway in many cases. I guess you can steal other players' building spots, but that is not enough to call a game cutthroat for me. i don't generally like cutthroat games, but I did like this.",
#  "Friend's game",
#  '280',
#  'Challenging One.',
#  "A very, very good game. I'll come back with pleasure",
#  'Olga 3\nOmar 1',
#  'A truly remarkable game.',
#  'Easy to get into but really hard on the brain to progress. Always in debt too.\nPlays brilliantly',
#  '게임 자체는 너무 깔끔하고 재밌는데, 네트워크로 점수만 버는 생각을 하기 시작하니 환상이 좀 사라짐.',
#  "I think the more I play this the higher it will go. I played two-handed, but I can't stop thinking about it...",
#  'In UK',
#  'Awesome game! (Very hard to play after a longer break.) 2nd phase is more fun than 1st phase.\nBrain-burner. Feels really good to pull off a strategy.',
#  'Derrick, Jessica, Jack?',
#  '3-4 players',
#  'i had a lot of fun playing this game with friends',
#  'Amazing game at every player count.',
#  '#1 on BGG for a long time - would like to play!',
#  "The more I play the more I am converted. What I thought was a smart but hollow experience is now one of my most excited games to table. The balance of tactical plays, strategic planning, and player interaction, all wrapped in (what I think) is a beautiful package and theme, makes it clear why this is the King. It's not my favourite game, but damnit if it's not a brilliant one.",
#  'Original',
#  'Been in the cupboard for years.  Finally got to play with 2 great teachers and none of us are AP prone.\n\nBrilliant, loved every second.  I think it does depend on the people at the table like most games.  Any AP prone people at the table would kill this for me.\n\nWorthy of being top 10 game, not sure about number 1 though ;-)',
#  "One of the most responsive strategy games. And one of the best Euro's out there. More flexible than Brass: Lancashire. Very very good game. could be a bit stuffy. \n",
#  "Une seule partie à 4. S'il n'était pas 1er au classement bgg je n'envisagerai même pas d'y rejouer.",
#  "- first couple of games you will simply try to understand the rules and flip a few tiles across a few industries, then you move on and start developing level I buildings and focus on two or three industries, maybe you even start messing around with the wild cards, at some point you then realize it is really important to flip tiles before the end of the first era and that you should to flip multiple tiles in one move, build multiple connections in one move, buy coal/iron when it's cheap and so on. It is all about the action efficiency, stupid! :)\n- you are working towards your own goals but along the way other players will most likely also benefit from your activities - and vice versa. Whether it is building a connection or supplying resources. Sometimes it makes me wonder: so this is how capitalism works - everyone works for their own advantage but it somehow all falls into place and everyone is better off?!? On average at least…\n- yet you can also hurt other players by occupying spaces they have had their eyes on or forcing them to connect your network to dealers \n- beautiful map and art although a bit too much the dark side ",
#  'Just great!',
#  '+ insert reDrewno, iron clays 200',
#  'Lo tiene David S. (marzo 2025)',
#  'Owner: Katie',
#  "Introduced this game by my mate and I can't stop thinking about it afterwards. Got myself a deluxe copy and played with my SO and she loves it too. My first 10 rating euro game in my collection, is almost flawless, would really like to try Lancashire next and hopefully more Brass games will come out in the future.",
#  "Beautiful in it's design, and elegant.\n\nI can't believe how much I enjoyed this game, and it's worth all of the praise it gets. It scales uniquely from 2-4 players, and even has a fairly accessible 'Short' version.\n\nA little finnicky, and hard to grapple with on the first go through, but you'll catch yourself wanting to push harder and harder for more efficiency on the next play.",
#  'No necessary in-game text',
#  '2-4p',
#  "Incredible game. The rules are surprisingly not intimidating, it's strange. There's really only a few actions you're taking and you're limited to the cards in your hand, but there's an astonishing amount to consider. The nature of the rules and actions also result in new players feeling completely lost for the first half of the game. Thankfully there is an option to just only play one half. You lose out on a lot of the meaty planning ahead strategy, but new players can't comprehend that anyway. Allows you to still play through a teaching game in a couple of hours. The only bummer for me is so far I have mostly only played teaching/half games. \n\nStill my favorite economic game out there, it's a lot to sit down, setup and teach, but it's worth it every time. ",
#  'Not my cup of tea, but I can see why people love it.\nVery euro, but also very interactive. First plays can be very punishing for new players.\nIt is easy to teach, but there are many nuances difficult to remember and spot when playing. It can cause AP very easily. I would not seek it but I can play it again',
#  'Played at ampthill on board. Complex but worth a second play.',
#  'I like Lancashire a bit better but these games are good enough to warrant owning and playing two slightly different versions.',
#  '8.5',
#  "Step back in time - entrenched in the theme - working 29hours a day at mill… young folk just wouldn't believe you. Fantastic! ",
#  "One of, if not, my favorite board games. Lots of different strategies but you can't stick to one thing and have to adapt to what other players are doing. \n\nLove its blend of pvp + pve. Love the quality, design, everything.",
#  'Best 3-4\n(Sleeved)\nKR+',
#  'Birthday present Sept. 2024',
#  'Descripción en español: Juego clasificado como euro de "construcción de rutas/redes" basado en la Revolución Industrial',
#  "Sleeved (FFG Grey)\nTinkertown 25 iron and 30 'coal' cubes",
#  'Cegieł',
#  '2-4',
#  'La Obra maestra del tito wallace❤️',
#  "I'm still a novice with less than 10 plays under my belt, but this could be a top 5 game for me. I find the interaction between the players as the resource network grows to be so fascinating and unique. I'll revisit my rating once I have more plays under my belt",
#  'The setup is fiddly and the rules are overly complex.\n* Sold by Timeless Board Games for me *',
#  "I have the kickstarter Deluxe edition. It looks sooooo pretty that I don't want to play it. There is no game in my possession with a better build quality",
#  "A good game. I personaly prefer Lancashire because it's a more streamlined version.In my opinion the game already was good enough. But this is still a good one.",
#  "Upgraded it to 9 and potentially to 10 moving forward. It does take a few plays to get around the ridiculous way goods transport around the map but once you accept that it's a great game.\n\nUpgraded to 6 after two plays. Still think it's fiddly as hell but it's definitely an interesting game.\n\nGiving it a reluctant 3 after one first play.\nSuper fiddly unintuitive rules:\n- Different ways the resources travel\n- The fact that lvl 1 buildings get cleared from the main board but not your personal board\n- 1 action for the 1st turn only for some reason\n- Can use bonus beer to ship goods but not to build tracks during phase 2\n\nReally hated the fact that you play canal part and then reset the game and count scores to play the rail phase with some useless buildings on the board you can't reuse. I took effort to develop and place lvl 2 buildings on the board and I can't reflip them for extra income, beer, etc? \n\nAlso the fact that you see the scores at the end of the canal phase, if you're quite far behind doesn't make you want to play the second phase anymore.\n\nEtc, etc.\n\nI basically liked nothing about the game after this first play.",
#  "In friends' collection: I usually wait until I played games a few times before I do a first rating, but this game is an exception. The first time I played this game was already amazing and I can't stop thinking about new strategies I want to try. I'm looking forward to my next play of the game. This is exactly the type of game I love. It does all the things I want in a game and it does them right. ",
#  'Martin Wallace economic game masterpiece.',
#  'Critical Thinking\nEconomics\nManagement\nMath and Numeracy\nProblem Solving',
#  'Great game',
#  ...]

# %%
translactions
# Out:
# ['2-4 [S]',
#  'Great game that somehow feels simple, yet every decision you make carries weight',
#  "If you can play this in 60 minutes you're playing too fast.  With my group a a game lasts about 45 minutes per player.\n\nKeep pushing up my rating..  This game continues to be my favorite and the favorite of our group.",
#  'Table top',
#  'I only played half a real game, but I was captivated throughout. Would play again.',
#  'SGI',
#  "The more I play, the more I realize it's more about playing the hand you're dealt, and less about strategy",
#  'Very good game. I might not say it is the best of all times, but it is definetely great. The mechanics are simple, but I consider that it takes a little time to adapt to them. You may need several playthroughs to achieve some sort of mastering. Revise every victory point possibility to plan your strategy, otherwise, it can be easy to fall pursuing things that are not profitable in the long term.',
#  "+ Artwork is great\n+ Great strategy game\n+ Lots of interaction\n+ Low luck factor\n+ Many paths to victory\n+ Brain burner \n- Quite long\n- Rules heavy \n- Theme is a bit boring\n\nDeep strategic economic game with many ways to win the game. It is surprisingly enough very interactive. I've only played it at 2 and 3 player count.",
#  'Not a Euro fan, it could be good, I wouldn’t mind playing it again if necessary, but I won’t suggest it myself. And yes, this is definitely not the first place on BGG.',
#  'Most of my plays have been at 2p, and I thoroughly enjoyed every single game. \nHowever, it feels like it ends very quickly at 4p (a feeling it seems others at my table tend to have as well).',
#  'Pt: 3',
#  'In: October 2025',
#  'IS',
#  'M.Heavy Euro - Wallace, Trains',
#  "Arguably the best strategic area control, resource management game.  Just make sure you use other peoples beer and don't let them use yours.",
#  'Epic',
#  "haven't played it enough to really understand it. Heavy and thinky. need to log more plays",
#  "Brass is a game that owes a lot of its success to its ability to offer little criticism (little chance, impeccable editing, mature theme, elitist game). It's an overrated game that rides on the flaws of the BGG ranking (the reissues have excessively high ratings, especially with a graphical overhaul and abundant hyper-quality material. These reissues preach convictions who overrate their favorite games through a new entry on BGG).",
#  'Your first game is likely going to be rough. However no doubt you will see the appeal of building up your own niche economy that ends up frustratingly reliant on and sometimes in favor the other players. At the end of each round you will be left going "oh I wish I did that," or "things could have gone well if you didn\'t do that", but still be left to admire how everything resulted in the end. After that rough first game, you are most likely going to arrange for another game, all to get better at this system.',
#  'B3u4, G2',
#  'Gift 14',
#  '£67.85 https://www.amazon.co.uk/Roxley-Games-ROX402-Brass-Birmingham/dp/1988884047?crid=2I7084BPZPFR5&dib=eyJ2IjoiMSJ9.AKBvx-qCEQ1s2PviGSbDhYyDSrcdKdGtfSi_ilfJCheyjNb5lf8iB5Kr8USCrowvqXNUC7k-hRITiyTddwAp1e-vXgssxL4xuGJa3X2ETt8Np9UmhR4kjr6WpnTMDMRj_VvxWnEgN6AY7c15BtQ-aWQy9Jis6jXCz3utNAtdZ5rT2epjPFsa2S4Te8RikY2S8yEHoXlcbHAEnprGxF1cy7ivg7o24JuypogPNga_UZOPS_Psun_ySg-365rKRCq8i06CmiXpEVyVf83N0o-ViZGc70ox5rE1PqNQ2yb6k4I.VZKtGk37XxVIkuMPPcDUbbo9eBxUHUpzCjO7chxTe9k&dib_tag=se&keywords=brass%2Bbirmingham%2Bboard%2Bgame&qid=1762604991&sprefix=brass%2B%2Caps%2C123&sr=8-4&th=1',
#  "Previously 9. The more you play this game the more it shines!\n\nIt has a relatively simple rule set with incredible depth. No need for expansions.... It's a modern classic.\n\nIf you like strategy without the need to attack your opponents to win, this is for you.\n\nThe interplay of you using up the other players resources benefitting both you and them is very satisfying and keeps everyone engaged.\n\nGreat family strategic game!",
#  'I loathe this as much as I loathed the original Brass. And now add in hunger games for beer. \n\nOne and done.\n\nThe #1 game on BGG? Someone euthanize me.',
#  'Tedious and boring VP pusher with instant railway transition. Not my cup of tea? No, I’d rather smear my genitalia with fish paste and dangle them in a pool of hungry piranha. \n\nDingo',
#  "The first game had been somewhat difficult. Partly because of the new rules and partly because, in the random distribution of initial markets, we ended up with one of them closed and that disrupted how the game unfolds (it doesn't break it, but it's not the easiest thing to deal with the first time). Initially, I was left with the feeling that the addition of options and depth did not compensate for the loss of the fluid pace of the original.\n\nIn the last one I participated in, the same thing happened with the initial markets and we said fuggit, and we shuffled them again. With the rules more polished and more markets open, the game flew with the fluidity that I remembered the original having, so I reconciled myself with this new version.\n\nBut you have to use the side of the board during the day, the side of the board at night, unless you use a miner's helmet with a light, you can't see a knob.\n\nI also don't know what the game will bring as money, because we always use poker chips.\n\nA classic that preserves the best of the Eurogames of that time: depth, options, decisions, interaction, fluidity, with an updated card.\n\nHighly recommended :star::star::star::star::nostar:",
#  'SpielboxRating 9-10, by. 9.20',
#  "Much more fun than the (old) original version. This took a few plays to grow on me. No in game text, has a central board and good balance between tactical and strategical play. Maybe a bit on the long side, but it's a really nail-biter till the end. I can see why this is rated so high as it is.",
#  "It's a great game, would struggle to get consistent plays.",
#  '+ 3D Printed insert\n+ Sleeves',
#  'I enjoy Lancashire and want to add this one to my collection at some point.',
#  'Very clean medium euro.',
#  'Great game!',
#  'Compared to dry games of the same weight, the rules are hard to memorize. The main mechanism is classically simple, like Catan, even for a 2018 game. Replayability is also questionable if played with the same members. Conclusion Fun is simple, understanding is difficult.',
#  'Great game\n-scratches the economic itch\n-tight gameplay, but does not feel too limiting\n-not too long after you learn\n-straightforward ways to score\n-has a semi cooperative element to the game which make other players turns more interesting  \n-can be a bit tough to learn/teach first time\n-rules can feel contradicting when learning',
#  'kickstarter',
#  '+ Engaging tactics and strategy\n+ Agonizing decisions and tradeoffs\n+ Tight economy\n+ Player interaction\n+ Climactic ending\n- AP prone\n- Finicky rules and fiddliness\n- Downtime',
#  "BRASS BIRMINGHAM (2-4 players)\n\nDeluxe player aids: https://boardgamegeek.com/filepage/179522/deluxe-player-aids-brass-birmingham\n\nFanmade solo variant: \n\nhttp://www.mautoma.com/mautomas/brass-birmingham \n\nOnline app for solo variant so you don't have to print the cards: \n\nhttps://boardgamegeek.com/filepage/168370/brass-birmingham-george-solo-competitive-mode\n\nBrass Birmingham is better than Brass Lancashire. The Mautoma Solo variant is quite good but I prefer to play Brass as a multiplayer game. The game is a dry euro but a VERY good dry euro.",
#  "Rules that are a bit obtuse, with exceptions and many details that make you have to constantly review them. The explanation must be prepared well, it is not easy to assimilate the concepts. \n\nI like that everyone participates on the central board and can take advantage of each other's routes and resources, there is a lot of interaction, without a doubt what I like most about the game. The editing is cool too. However, the game has too many unintuitive rules and too many details to keep an eye on (it can lead to long turns). Seeing that it is such a beloved game, I have given it several chances but it is definitely not my thing.",
#  'It’s Brass with a more-is-better approach: more buildings, more locations, more connections—and then beer. Less cutthroat and leaning toward a point-salad feel. The high rail scoring makes the rail era predictable, though some might see it as a more forgiving, flexible evolution of the original. Could rate higher, but I’d always pick Lancashire over this, which brings the rating down a bit.',
#  'Boardroom, PAX, 4 2-4, 2h',
#  "That's the most boring and ugly game I've ever played. Viscous snot is the most suitable description for it. 1000% overrated.",
#  'Loved playing and would recommend playing but did take us 4 and a half hours to learn and play as a 3. Worth it though',
#  'Sleeved with Shield Titan Super Sleeves (Clear)\nInsert included',
#  "Tentative rating.\n\nI understand how this game got its reputation. The puzzle involved is unique, which is such a rarity among the hundreds of Euros we see each year. It felt like the game is stimulating a whole new part of my brain's strategy center that I didn't know existed, and I love it.\n\nThe game is complex, the strategy is opaque, and it was a pain to teach with all of its minor titbits and exceptions. However, these won't matter after 20+ plays, and the game is solid enough to warrant that.",
#  '3.87',
#  'great euro styled game.\nflow of interaction is just a masterpiece.\nMartin is genious.',
#  'Less fluid than the black edition.',
#  "In my opinion, Lancashire is much better.\n\nLancashire is more straightforward and you focus on the strategy. You don't get tired of the multitude of tokens, in Lancashire there is only the essential ones. \n\nAfter playing Birmingham I always felt exhausted, but still liked the game. However, after playing Lancashire the time just flew and I would have wanted to play again right away.",
#  '2-4 [S]',
#  'Great game that somehow feels simple, yet every decision you make carries weight',
#  "If you can play this in 60 minutes you're playing too fast.  With my group a a game lasts about 45 minutes per player.\n\nKeep pushing up my rating..  This game continues to be my favorite and the favorite of our group.",
#  'Table top',
#  'I only played half a real game, but I was captivated throughout. Would play again.',
#  'SGI',
#  "The more I play, the more I realize it's more about playing the hand you're dealt, and less about strategy",
#  'Very good game. I might not say it is the best of all times, but it is definetely great. The mechanics are simple, but I consider that it takes a little time to adapt to them. You may need several playthroughs to achieve some sort of mastering. Revise every victory point possibility to plan your strategy, otherwise, it can be easy to fall pursuing things that are not profitable in the long term.',
#  "+ Artwork is great\n+ Great strategy game\n+ Lots of interaction\n+ Low luck factor\n+ Many paths to victory\n+ Brain burner \n- Quite long\n- Rules heavy \n- Theme is a bit boring\n\nDeep strategic economic game with many ways to win the game. It is surprisingly enough very interactive. I've only played it at 2 and 3 player count.",
#  'Not a Euro fan, it could be good, I wouldn’t mind playing it again if necessary, but I won’t suggest it myself. And yes, this is definitely not the first place on BGG.',
#  'Most of my plays have been at 2p, and I thoroughly enjoyed every single game. \nHowever, it feels like it ends very quickly at 4p (a feeling it seems others at my table tend to have as well).',
#  'Pt: 3',
#  'In: October 2025',
#  'IS',
#  'M.Heavy Euro - Wallace, Trains',
#  "Arguably the best strategic area control, resource management game.  Just make sure you use other peoples beer and don't let them use yours.",
#  'Epic',
#  "haven't played it enough to really understand it. Heavy and thinky. need to log more plays",
#  "Brass is a game that owes a lot of its success to its ability to offer little criticism (little chance, impeccable editing, mature theme, elitist game). It's an overrated game that rides on the flaws of the BGG ranking (the reissues have excessively high ratings, especially with a graphical overhaul and abundant hyper-quality material. These reissues preach convictions who overrate their favorite games through a new entry on BGG).",
#  'Your first game is likely going to be rough. However no doubt you will see the appeal of building up your own niche economy that ends up frustratingly reliant on and sometimes in favor the other players. At the end of each round you will be left going "oh I wish I did that," or "things could have gone well if you didn\'t do that", but still be left to admire how everything resulted in the end. After that rough first game, you are most likely going to arrange for another game, all to get better at this system.',
#  'B3u4, G2',
#  'Gift 14',
#  '£67.85 https://www.amazon.co.uk/Roxley-Games-ROX402-Brass-Birmingham/dp/1988884047?crid=2I7084BPZPFR5&dib=eyJ2IjoiMSJ9.AKBvx-qCEQ1s2PviGSbDhYyDSrcdKdGtfSi_ilfJCheyjNb5lf8iB5Kr8USCrowvqXNUC7k-hRITiyTddwAp1e-vXgssxL4xuGJa3X2ETt8Np9UmhR4kjr6WpnTMDMRj_VvxWnEgN6AY7c15BtQ-aWQy9Jis6jXCz3utNAtdZ5rT2epjPFsa2S4Te8RikY2S8yEHoXlcbHAEnprGxF1cy7ivg7o24JuypogPNga_UZOPS_Psun_ySg-365rKRCq8i06CmiXpEVyVf83N0o-ViZGc70ox5rE1PqNQ2yb6k4I.VZKtGk37XxVIkuMPPcDUbbo9eBxUHUpzCjO7chxTe9k&dib_tag=se&keywords=brass%2Bbirmingham%2Bboard%2Bgame&qid=1762604991&sprefix=brass%2B%2Caps%2C123&sr=8-4&th=1',
#  "Previously 9. The more you play this game the more it shines!\n\nIt has a relatively simple rule set with incredible depth. No need for expansions.... It's a modern classic.\n\nIf you like strategy without the need to attack your opponents to win, this is for you.\n\nThe interplay of you using up the other players resources benefitting both you and them is very satisfying and keeps everyone engaged.\n\nGreat family strategic game!",
#  'I loathe this as much as I loathed the original Brass. And now add in hunger games for beer. \n\nOne and done.\n\nThe #1 game on BGG? Someone euthanize me.',
#  'Tedious and boring VP pusher with instant railway transition. Not my cup of tea? No, I’d rather smear my genitalia with fish paste and dangle them in a pool of hungry piranha. \n\nDingo',
#  "The first game had been somewhat difficult. Partly because of the new rules and partly because, in the random distribution of initial markets, we ended up with one of them closed and that disrupted how the game unfolds (it doesn't break it, but it's not the easiest thing to deal with the first time). Initially, I was left with the feeling that the addition of options and depth did not compensate for the loss of the fluid pace of the original.\n\nIn the last one I participated in, the same thing happened with the initial markets and we said fuggit, and we shuffled them again. With the rules more polished and more markets open, the game flew with the fluidity that I remembered the original having, so I reconciled myself with this new version.\n\nBut you have to use the side of the board during the day, the side of the board at night, unless you use a miner's helmet with a light, you can't see a knob.\n\nI also don't know what the game will bring as money, because we always use poker chips.\n\nA classic that preserves the best of the Eurogames of that time: depth, options, decisions, interaction, fluidity, with an updated card.\n\nHighly recommended :star::star::star::star::nostar:",
#  'SpielboxRating 9-10, by. 9.20',
#  "Much more fun than the (old) original version. This took a few plays to grow on me. No in game text, has a central board and good balance between tactical and strategical play. Maybe a bit on the long side, but it's a really nail-biter till the end. I can see why this is rated so high as it is.",
#  "It's a great game, would struggle to get consistent plays.",
#  '+ 3D Printed insert\n+ Sleeves',
#  'I enjoy Lancashire and want to add this one to my collection at some point.',
#  'Very clean medium euro.',
#  'Great game!',
#  'Compared to dry games of the same weight, the rules are hard to memorize. The main mechanism is classically simple, like Catan, even for a 2018 game. Replayability is also questionable if played with the same members. Conclusion Fun is simple, understanding is difficult.',
#  'Great game\n-scratches the economic itch\n-tight gameplay, but does not feel too limiting\n-not too long after you learn\n-straightforward ways to score\n-has a semi cooperative element to the game which make other players turns more interesting  \n-can be a bit tough to learn/teach first time\n-rules can feel contradicting when learning',
#  'kickstarter',
#  '+ Engaging tactics and strategy\n+ Agonizing decisions and tradeoffs\n+ Tight economy\n+ Player interaction\n+ Climactic ending\n- AP prone\n- Finicky rules and fiddliness\n- Downtime',
#  "BRASS BIRMINGHAM (2-4 players)\n\nDeluxe player aids: https://boardgamegeek.com/filepage/179522/deluxe-player-aids-brass-birmingham\n\nFanmade solo variant: \n\nhttp://www.mautoma.com/mautomas/brass-birmingham \n\nOnline app for solo variant so you don't have to print the cards: \n\nhttps://boardgamegeek.com/filepage/168370/brass-birmingham-george-solo-competitive-mode\n\nBrass Birmingham is better than Brass Lancashire. The Mautoma Solo variant is quite good but I prefer to play Brass as a multiplayer game. The game is a dry euro but a VERY good dry euro.",
#  "Rules that are a bit obtuse, with exceptions and many details that make you have to constantly review them. The explanation must be prepared well, it is not easy to assimilate the concepts. \n\nI like that everyone participates on the central board and can take advantage of each other's routes and resources, there is a lot of interaction, without a doubt what I like most about the game. The editing is cool too. However, the game has too many unintuitive rules and too many details to keep an eye on (it can lead to long turns). Seeing that it is such a beloved game, I have given it several chances but it is definitely not my thing.",
#  'It’s Brass with a more-is-better approach: more buildings, more locations, more connections—and then beer. Less cutthroat and leaning toward a point-salad feel. The high rail scoring makes the rail era predictable, though some might see it as a more forgiving, flexible evolution of the original. Could rate higher, but I’d always pick Lancashire over this, which brings the rating down a bit.',
#  'Boardroom, PAX, 4 2-4, 2h',
#  "That's the most boring and ugly game I've ever played. Viscous snot is the most suitable description for it. 1000% overrated.",
#  'Loved playing and would recommend playing but did take us 4 and a half hours to learn and play as a 3. Worth it though',
#  'Sleeved with Shield Titan Super Sleeves (Clear)\nInsert included',
#  "Tentative rating.\n\nI understand how this game got its reputation. The puzzle involved is unique, which is such a rarity among the hundreds of Euros we see each year. It felt like the game is stimulating a whole new part of my brain's strategy center that I didn't know existed, and I love it.\n\nThe game is complex, the strategy is opaque, and it was a pain to teach with all of its minor titbits and exceptions. However, these won't matter after 20+ plays, and the game is solid enough to warrant that.",
#  '3.87',
#  'great euro styled game.\nflow of interaction is just a masterpiece.\nMartin is genious.',
#  'Less fluid than the black edition.',
#  "In my opinion, Lancashire is much better.\n\nLancashire is more straightforward and you focus on the strategy. You don't get tired of the multitude of tokens, in Lancashire there is only the essential ones. \n\nAfter playing Birmingham I always felt exhausted, but still liked the game. However, after playing Lancashire the time just flew and I would have wanted to play again right away.",
#  '2-4 [S]',
#  'Great game that somehow feels simple, yet every decision you make carries weight',
#  "If you can play this in 60 minutes you're playing too fast.  With my group a a game lasts about 45 minutes per player.\n\nKeep pushing up my rating..  This game continues to be my favorite and the favorite of our group.",
#  'Table top',
#  'I only played half a real game, but I was captivated throughout. Would play again.',
#  'SGI',
#  "The more I play, the more I realize it's more about playing the hand you're dealt, and less about strategy",
#  'Very good game. I might not say it is the best of all times, but it is definetely great. The mechanics are simple, but I consider that it takes a little time to adapt to them. You may need several playthroughs to achieve some sort of mastering. Revise every victory point possibility to plan your strategy, otherwise, it can be easy to fall pursuing things that are not profitable in the long term.',
#  "+ Artwork is great\n+ Great strategy game\n+ Lots of interaction\n+ Low luck factor\n+ Many paths to victory\n+ Brain burner \n- Quite long\n- Rules heavy \n- Theme is a bit boring\n\nDeep strategic economic game with many ways to win the game. It is surprisingly enough very interactive. I've only played it at 2 and 3 player count.",
#  'Not a Euro fan, it could be good, I wouldn’t mind playing it again if necessary, but I won’t suggest it myself. And yes, this is definitely not the first place on BGG.',
#  'Most of my plays have been at 2p, and I thoroughly enjoyed every single game. \nHowever, it feels like it ends very quickly at 4p (a feeling it seems others at my table tend to have as well).',
#  'Pt: 3',
#  'In: October 2025',
#  'IS',
#  'M.Heavy Euro - Wallace, Trains',
#  "Arguably the best strategic area control, resource management game.  Just make sure you use other peoples beer and don't let them use yours.",
#  'Epic',
#  "haven't played it enough to really understand it. Heavy and thinky. need to log more plays",
#  "Brass is a game that owes a lot of its success to its ability to offer little criticism (little chance, impeccable editing, mature theme, elitist game). It's an overrated game that rides on the flaws of the BGG ranking (the reissues have excessively high ratings, especially with a graphical overhaul and abundant hyper-quality material. These reissues preach convictions who overrate their favorite games through a new entry on BGG).",
#  'Your first game is likely going to be rough. However no doubt you will see the appeal of building up your own niche economy that ends up frustratingly reliant on and sometimes in favor the other players. At the end of each round you will be left going "oh I wish I did that," or "things could have gone well if you didn\'t do that", but still be left to admire how everything resulted in the end. After that rough first game, you are most likely going to arrange for another game, all to get better at this system.',
#  'B3u4, G2',
#  'Gift 14',
#  '£67.85 https://www.amazon.co.uk/Roxley-Games-ROX402-Brass-Birmingham/dp/1988884047?crid=2I7084BPZPFR5&dib=eyJ2IjoiMSJ9.AKBvx-qCEQ1s2PviGSbDhYyDSrcdKdGtfSi_ilfJCheyjNb5lf8iB5Kr8USCrowvqXNUC7k-hRITiyTddwAp1e-vXgssxL4xuGJa3X2ETt8Np9UmhR4kjr6WpnTMDMRj_VvxWnEgN6AY7c15BtQ-aWQy9Jis6jXCz3utNAtdZ5rT2epjPFsa2S4Te8RikY2S8yEHoXlcbHAEnprGxF1cy7ivg7o24JuypogPNga_UZOPS_Psun_ySg-365rKRCq8i06CmiXpEVyVf83N0o-ViZGc70ox5rE1PqNQ2yb6k4I.VZKtGk37XxVIkuMPPcDUbbo9eBxUHUpzCjO7chxTe9k&dib_tag=se&keywords=brass%2Bbirmingham%2Bboard%2Bgame&qid=1762604991&sprefix=brass%2B%2Caps%2C123&sr=8-4&th=1',
#  "Previously 9. The more you play this game the more it shines!\n\nIt has a relatively simple rule set with incredible depth. No need for expansions.... It's a modern classic.\n\nIf you like strategy without the need to attack your opponents to win, this is for you.\n\nThe interplay of you using up the other players resources benefitting both you and them is very satisfying and keeps everyone engaged.\n\nGreat family strategic game!",
#  'I loathe this as much as I loathed the original Brass. And now add in hunger games for beer. \n\nOne and done.\n\nThe #1 game on BGG? Someone euthanize me.',
#  'Tedious and boring VP pusher with instant railway transition. Not my cup of tea? No, I’d rather smear my genitalia with fish paste and dangle them in a pool of hungry piranha. \n\nDingo',
#  "The first game had been somewhat difficult. Partly because of the new rules and partly because, in the random distribution of initial markets, we ended up with one of them closed and that disrupted how the game unfolds (it doesn't break it, but it's not the easiest thing to deal with the first time). Initially, I was left with the feeling that the addition of options and depth did not compensate for the loss of the fluid pace of the original.\n\nIn the last one I participated in, the same thing happened with the initial markets and we said fuggit, and we shuffled them again. With the rules more polished and more markets open, the game flew with the fluidity that I remembered the original having, so I reconciled myself with this new version.\n\nBut you have to use the side of the board during the day, the side of the board at night, unless you use a miner's helmet with a light, you can't see a knob.\n\nI also don't know what the game will bring as money, because we always use poker chips.\n\nA classic that preserves the best of the Eurogames of that time: depth, options, decisions, interaction, fluidity, with an updated card.\n\nHighly recommended :star::star::star::star::nostar:",
#  'SpielboxRating 9-10, by. 9.20',
#  "Much more fun than the (old) original version. This took a few plays to grow on me. No in game text, has a central board and good balance between tactical and strategical play. Maybe a bit on the long side, but it's a really nail-biter till the end. I can see why this is rated so high as it is.",
#  "It's a great game, would struggle to get consistent plays.",
#  '+ 3D Printed insert\n+ Sleeves',
#  'I enjoy Lancashire and want to add this one to my collection at some point.',
#  'Very clean medium euro.',
#  'Great game!',
#  'Compared to dry games of the same weight, the rules are hard to memorize. The main mechanism is classically simple, like Catan, even for a 2018 game. Replayability is also questionable if played with the same members. Conclusion Fun is simple, understanding is difficult.',
#  'Great game\n-scratches the economic itch\n-tight gameplay, but does not feel too limiting\n-not too long after you learn\n-straightforward ways to score\n-has a semi cooperative element to the game which make other players turns more interesting  \n-can be a bit tough to learn/teach first time\n-rules can feel contradicting when learning',
#  'kickstarter',
#  '+ Engaging tactics and strategy\n+ Agonizing decisions and tradeoffs\n+ Tight economy\n+ Player interaction\n+ Climactic ending\n- AP prone\n- Finicky rules and fiddliness\n- Downtime',
#  "BRASS BIRMINGHAM (2-4 players)\n\nDeluxe player aids: https://boardgamegeek.com/filepage/179522/deluxe-player-aids-brass-birmingham\n\nFanmade solo variant: \n\nhttp://www.mautoma.com/mautomas/brass-birmingham \n\nOnline app for solo variant so you don't have to print the cards: \n\nhttps://boardgamegeek.com/filepage/168370/brass-birmingham-george-solo-competitive-mode\n\nBrass Birmingham is better than Brass Lancashire. The Mautoma Solo variant is quite good but I prefer to play Brass as a multiplayer game. The game is a dry euro but a VERY good dry euro.",
#  "Rules that are a bit obtuse, with exceptions and many details that make you have to constantly review them. The explanation must be prepared well, it is not easy to assimilate the concepts. \n\nI like that everyone participates on the central board and can take advantage of each other's routes and resources, there is a lot of interaction, without a doubt what I like most about the game. The editing is cool too. However, the game has too many unintuitive rules and too many details to keep an eye on (it can lead to long turns). Seeing that it is such a beloved game, I have given it several chances but it is definitely not my thing.",
#  'It’s Brass with a more-is-better approach: more buildings, more locations, more connections—and then beer. Less cutthroat and leaning toward a point-salad feel. The high rail scoring makes the rail era predictable, though some might see it as a more forgiving, flexible evolution of the original. Could rate higher, but I’d always pick Lancashire over this, which brings the rating down a bit.',
#  'Boardroom, PAX, 4 2-4, 2h',
#  "That's the most boring and ugly game I've ever played. Viscous snot is the most suitable description for it. 1000% overrated.",
#  'Loved playing and would recommend playing but did take us 4 and a half hours to learn and play as a 3. Worth it though',
#  'Sleeved with Shield Titan Super Sleeves (Clear)\nInsert included',
#  "Tentative rating.\n\nI understand how this game got its reputation. The puzzle involved is unique, which is such a rarity among the hundreds of Euros we see each year. It felt like the game is stimulating a whole new part of my brain's strategy center that I didn't know existed, and I love it.\n\nThe game is complex, the strategy is opaque, and it was a pain to teach with all of its minor titbits and exceptions. However, these won't matter after 20+ plays, and the game is solid enough to warrant that.",
#  '3.87',
#  'great euro styled game.\nflow of interaction is just a masterpiece.\nMartin is genious.',
#  'Less fluid than the black edition.',
#  "In my opinion, Lancashire is much better.\n\nLancashire is more straightforward and you focus on the strategy. You don't get tired of the multitude of tokens, in Lancashire there is only the essential ones. \n\nAfter playing Birmingham I always felt exhausted, but still liked the game. However, after playing Lancashire the time just flew and I would have wanted to play again right away.",
#  "Too many little nit-picky rules.  It's fine, but I always get frustrated when I play it.  Wish it was a little more intuitive and elegant in its design.  I can see why people like it - my group loves it - just not my favorite.",
#  '25\n50€',
#  "This game is not about deciding what to do. It's about figuring out what you can do by navigating the silly amount of clunky exceptions slowly but surely chipping away your decision space until only 1-2 options are remaining. Turns take a long time not because of strategy, but because of how fiddly everything is. The rules are nonsensical from a logic standpoint. Some resources follow networks, some teleport, some do both, sometimes, except x and y and z. And then, halfway through the game, the connections between the places you worked on for the last hour and a half have to be removed and redone from scratch in the second half. The graphic design is abysmal, symbols are lost in the unnecessary detail, everything becomes a blurry mess, while important information is hidden away in the corners. The player aids that come in the box are worthless, the game is genuinely unlearnable and unplayable without the user-made ones. Furthermore, the setup and the mid-game scoring/upkeep are tedious, fiddly and take way too long. This game does not deserve the praise it gets, at all.",
#  'Was my #1 game! (2022)\nI love the shared economy, board building, income, and theme of this game.',
#  'DIY',
#  "good game , \nbrass Birmingham = wildcatters ( underrated )\nhas the same feel: \n-pick an area through cards on a map\n- play your actions , build, develop, trains ... in that area\n- use each other's  network\n....",
#  'Loaned to Connor Smith on 11/3/2023, returned 1/22/2024\nLoaned to Cade Loving on 3/16/2024, returned',
#  'not fun no matter how hard i try',
#  '+Incredible depth of strategy. Brain burning turns trying to figure out what, where and in which order to build. \n+The player economy and heavy interaction is a joy. "Helping" other players out by flipping their tiles makes everyone feel good, but can quickly swing to tense denial as someone takes your last beer. Need to always be on your toes to see how changes in the board state benefits or harms you.\n+Lots of opportunities to feel clever in short-term tactics to take advantage of board/market state, and also longer-term planning for big sales. \n\n-Easily creates AP in players, making the game drag at 4p.\n-Takes a couple plays to really see the tactics and strategies. First play is mostly just figuring out WHAT you can do with your cards.  \n\n≈The cards act as a limit to what you\'re able to do, which is not my preference for a heavy strategy game. The "do the best with what you\'ve been given" feels more tactical. Contrast this with Terra Mystica where all the actions are available to you, but it is your resources that limit your choices. \n≈Strategizing and playing well is a massive brain burn. It\'s a lot of work just figuring out what the cards allow you to do, before you can even work out an optimal strategy from the available options.\n\n8 > 7.8 > 8',
#  "Doesn't sound that interesting, but the #1 game ever, so might as well try?",
#  'Partially Played at ProCon 2024. Was the last day, we were both exhausted so I will not rate just yet until there is another chance to play it.',
#  'Overall, it’s a solid game, but I expected more from something ranked #1. If it held a lower position, I’d likely view it more favorably. Also, the theme drags everything else down.',
#  'A bit too repetitive',
#  'A superb economic game',
#  'Played once and enjoyed it. It took several turns before it started to click, but not until end of the game that some of the scoring really started to make sense.',
#  '2-4',
#  'We played together with my wife. We love the game, the its number 1 place on the ranking list is well deserved. The learning curve took some time, we watched tutorials as some rules were not easily understandable in the hungarian rule book (at least for us).\n\nThe game with 2 players is fun and pretty fast, with little downtime. Both eras are fun and once you figure out certain rules it can be fun. There are more detailed reviews, but what I have to say is that this is a well designed game (a bit too dark for my taste and eyes) made for us, as we like euro games with less or zero luck.',
#  'The perfect german.',
#  'A heavy boardgame classic with a short rulebook presenting relatively few and absolutely clear rules, a simple and convincing iconography, a truely atomspheric artwork and an outstanding thematic embedding.\nTons of tactical options, dilemmas and decisions just wait to be explored, interaction galore. Gameplay is very demanding, entertainment guaranteed. Sheer enthusiasm if a plan works, pure frustration if it doesn´t, \nThe board game companion to "Hard times" by Charles Dickens or "North & South" by Elizabeth Gaskell.\nBest board game ever? I don´t know, but it´s extraordinary.\n(SPIEL25 Essen 25.10.25)',
#  'Skopje Insert 3d',
#  "Pros:\nGreat theme and artwork. It looks beautiful on the table.\nUsually finishes within reasonable time\nCons:\nSome of the mechanics in this game are unnecessarily complex for complexity sake. \nTransition from canal to rail era breaks the rhythm of the game . Scraping all those old tiles off the map is fiddly and annoying.\nSetup is a drag. Having to meticulously place all the tiles on player boards feels like a chore and is annoying due to the fact that most of them don't get used.",
#  '*',
#  'M: 2-4',
#  'Very clever positive-negative interaction.\nSmart management of the changing market and the order of play is great.\nThe theme is "meh", but at least it\'s nicely executed.\nThe mechanics of beer are not as interesting to me as those of ports.\nThere are a lot more options than in Lancashire, so it loses a bit of the tension.\nDeservedly BGG top 1.',
#  'It it great',
#  'Brass: Birmingham (2018) https://tarsasjatekok.com/tarsasjatek/brass-lancashire-2007/kiegeszito/brass-birmingham-2018 Gavan Brown, Matt Tolman, Martin Wallace Artist: Gavan Brown, Lina Cossette, David Forest, Gui Landgraf, Damien Mammoliti, Matt Tolman Rank: Overall 1 Strategy 1 Spiel des Jahres 2018 Év játéka jelölt TEMU',
#  'fun!',
#  'A crunchy and smooth euro. Certainly a bit heavy, but the game is a blast to play. I really need to play this one more. This game is another proof that hand-management is the best mechanism in gaming. The current king of BGG, it\'s definitely one of the best euros that I\'ve ever played. The set up is a bit long, but it\'s all worth it. All the mechanics of the game shines through, and it\'s very engaging and fun to construct new "buildings" and deliver goods. And the beautiful artwork is just the cherry on top.\n\nThat being said, it does still feel a bit dry and less exciting compared to lots of other heavy euro games that I love. I personally enjoy A Feast for Odin, Kanban EV, and Great Western Trail a lot more. Maybe because the currency and numbers in those games are smaller and less math-y.',
#  "Industrial Revolution England-Themed, Heavy Economic Euro-Game.\n2-4 Players. (Best With 3-4 Players).\n\n'Deluxe Edition Comes With Upgraded Player Mats, A Custom Insert, And Upgraded Money Chips'.\n\n“Sleeved”",
#  "This is a very interactive game: players must look for ways to interfere with their opponents’ plans by blocking access to markets and resources. While that’s going on, you must somehow implement a plan of your own while factoring in all the ways your opponents could mess it up. The result is a fascinating but often frustrating game.\n \nThe art and graphics are too dark, even on the “daylight” side of the double sided board. This is too bad because the art is excellent. The dark shading is meant to be thematic by portraying the dirty coal smoke pollution of the period. It’s as if a dark grey filter is overlaid on the board but it’s so dark it's difficult to discern the features necessary for play without bright room lighting.",
#  'Steam version but not good',
#  'Preferred player count: 4p\nInteraction: High, while still being a Euro.',
#  'Solo',
#  "It's.... fine. Would you have told me this is the number 1 rated board game on BGG after playing it I would have never believed you. \n\nMaybe I need to try it again?",
#  '2-4 B: 3-4\nIn: 3.87',
#  'The absolutely most overrated game ever. Boring and stale. Lacking a lot of variation and dynamic to be even near a good game for me.',
#  'Sleeved with:\nGGS10063ML Standard Card Game Matte (66 x 91)',
#  'Aesthetic: 1\nMechanism: 2\nInvolvement/length/fluid: 2\nReplayability: 2\nOther: 1',
#  '+ Iron Clay Upgrade\n+ Playmat',
#  'E. 60',
#  'H',
#  'To test',
#  'Played only once with friends and fell in love. Awesome game. Will try it again to get more of it.',
#  '1 play',
#  'Falling low',
#  'We played Brass as Kickstarter and Deluxe edition (which is the same quality and tokens) and as 4, 3 and 2 player games. Its incredibly flexible and game mechanics are challenging enough to keep you busy during downtime (which it has) but overall, player interaction is very good and we can truly recommend it because of its re-playability in all constellations.',
#  'Excellent. Deep strategy with clear rules that are not even that complex. The only downside is that you constantly have to do a LOT of coin exchange to have exact change.',
#  'Played (IRL & TTS)',
#  '3 4 players',
#  'Theme is so great. I was born in Dudley and am very proud of our industrial heritage. This game is the best attempt to place the player at the heart of the industrial revolution. \n\nAfter playing a few games I realised it requires a lot of time investment to play and improve but having spent that time I really appreciate the nuance of this tight design. Exclusively played at 2 players.',
#  "deep strategic possibilities, competition for space, sharing of other players' resources...\nHigh replay value in my opinion",
#  'Best at 2',
#  '2025',
#  'N/A Expansions\n\n(Folded Space Insert)',
#  'JJ2',
#  'Roxley Games',
#  'Gave it a shot to see what all the hype was about, and I was pleasantly surprised! The economic choices are varied. Stealing resources from others, or getting your resources stolen, does not feel too cutthroat since you get hefty benefits from depleting resources, no matter who was responsible for this. This makes these "take that" choices feel less malevolent and the less obvious choice to take, because you need to think about whether it helps them more than it helps you. It\'s also surprisingly not a super long game unless you have players with bad cases of AP. The setup is a bit tedious, but I always measure games by the setup/fun ratio, and the fun in this case is worth it.',
#  '2024:I\n2025:IIII',
#  'English retail edition. Includes https://boardgamegeek.com/boardgameaccessory/306354/brass-birmingham-lancashire-folded-space-insert\n\nBox has moderate shelf wear and whitening, seen here:\nhttps://boardgamegeek.com/image/9176195/lboucheron\nhttps://boardgamegeek.com/image/9176197/lboucheron\nhttps://boardgamegeek.com/image/9176194/lboucheron\n\nThe previous owner glued together the Folded Space insert. I believe they put away the game components before the glue was fully dry, which led to a few pieces sticking and tearing when removed. All the damaged pieces I could find are shown here:\n\nhttps://boardgamegeek.com/image/9176196/lboucheron\n\nAll other components are in excellent condition. Cards are sleeved in premium sleeves.',
#  'Such an excellent design and the reprint is out of this world!',
#  "Complex game with many strategies available. Great game of it's genre",
#  'Need to Review',
#  'Cake - Black Shelf',
#  "Find this one a little harder to get my head around than Lancashire, but probably just because I don't own it.",
#  'Kickstarter game forge with Iron clays',
#  '3D Printed Insert',
#  'I mean what can I even say that anybody else hasn’t already? It’s Brass Birmingham. That’s all you need to know, and while it isn’t one of my all time favorites it’s undeniably fantastic. Brass keeps you on your toes in way that rewards both long term planning and clever decisions on the fly, making you constantly adjust to the ever fluctuations of the market. Brass can feel very frustrating at times, sure. However anyone with a love of the hobby who is willing to give it a good amount of plays will see why this is the number one game of all time. At least until camel up inevitably overtakes it as it should.',
#  'Highest Rank: 1 in 2025',
#  "Puzzle-y and thinky game. Lots of strategies to explore. Good player interaction, in terms of racing for certain spots and resources, and using other player's connections and resources (coal, iron, & beer). Very crunchy.",
#  "For two players, it isn't our household first choice.  But it's a really fun game to have in the collection and play with 3 or 4.",
#  'See other copy.',
#  'One play: Nice game, random location of selling points made half the map unused.',
#  'Check',
#  '[u]Expansions & Upgrades:[/u]\n-Iron Clays',
#  'Had a lot of fun with this, great mechanics for the most part and lots of interesting interaction.  Really enjoy the markets, loans, network building etc..  So much interaction and so many great small quick decisions.',
#  '@TX',
#  'Sleeved / Inserted',
#  "I don't like bear.",
#  'Zmvo',
#  'played',
#  'Really enjoyed they game. It was challenging to set up your turns but it was fun. Played it with 2 others.',
#  'Keep',
#  'Best: 3-4\nOwner: Adam A',
#  '* Sleeved ✓\n* Custom Insert - I want one',
#  '30% luck, 70% strategy',
#  "Took another run at Birmingham after hitting 20+ plays of Lancashire. Confirmed that for our tastes, it's worse in every way. A frustrating, lengthy, overly procedural experience that offers less interaction than the original. Lowered rating to a 6. I'm surprised more gamers new to the system don't bounce off Birmingham. \n===================================================\nFinally got this to the table after almost a dozen plays of Lancashire.\n\nBirmingham is much fiddlier. Much more difficult to put together a sequence of useful actions. The addition of beer, and the wonky benefits of manufactured goods and pottery, make for a more uneven and frustrating experience all around. That’s not sour grapes - I won handily.\n\nPresumably, Birmingham is intended to refresh the challenge for people who have played out Lancashire. Fair enough. But I won’t be coming back to it any time soon - Lancashire isn’t a lifestyle game for me, so at 6-7 plays a year I expect I have years of play before it starts to get stale. I doubt Birmingham sees the table again in that time.",
#  'Premium\n(Deluxe Edition)',
#  "What a cool game. The aesthetic is great, the strategy runs deep, and I absolutely adore the interconnectedness of the economy. Seeing this level of interaction in a Euro is so refreshing. The players have immense agency over the state of the game, and the way it all comes together is magical.\n\nThat said, some of the rules are incredibly unintuitive, bordering on arcane (iron can teleport, coal cannot, beer can for you, etc). There's enough weirdness to make it genuinely difficult to explain with a straight face. It's not particularly complex in the traditional sense; there's not that many actions you can take, but these strange caveats combined with the obtuse nature of how to actually play the game well makes for a large barrier to entry. I also find the game can veer into being slightly dry after many plays.\n\nStill, this is an amazing design. My only real critiques are in regards to the teach, and once players learn it this is a masterpiece. The fact that this game allows for this level of enmeshment between the players is a breath of fresh air, and something I must find more of.",
#  'The plus version of Power Plant, but I always feel that it is not as simple as Power Plant. It will be easy to play at the beginning. After playing a few more times, you will understand its design intention.',
#  'aliexpress',
#  'D.S',
#  'PoS',
#  'Hard to teach but smooth as silk once everyone gets it. The game gives you that perfect desire a game should - to play it again because you think you know where you can do better next time.',
#  'Mary and I love this game.  Such a fun strategy game that does not get boring.',
#  '1/2 off @ Barnes and Noble 2025',
#  'This is the best economic game I have. I am really proud to have the Kickstarter edition. It is a number 1 more than deserved.',
#  "[b]Thoughts:[/b] Not sure this deserves #1 on BGG, but it's an amazing game without question. Doesn't get to the table as much as we'd like so it takes a minute to get back into the rules. When we do though, it's always a joy. Every decision matters and the economic engine is unlike anything else.\n\n[b]Tag(s):[/b] Economic, Heavy Euro, Network Building\n[b]Best Player Count:[/b] 2-4, {3-4}\n[b]Rating:[/b] 9, [color=red]-0.5[/color]\n[b]Own:[/b] Physical",
#  "This is a great game. I don't know whether I'm slightly biased being from the Midlands but this is surely better than the Lancashire one! ? The number of components can be a little daunting at first but once you see past the sheer number of little tokens stacked on your player boards, underneath is quite a simple game with a couple of key mechanisms to remember. Unfortunately, my wife's not there yet, so it doesn't hit the table enough but I would probably play this game most weeks if I could.",
#  'Premium Sleeved (Paladin - Percivals)\nPainted Barrels\nDeluxe Iron Clays\n3D Printed Player Trays\n3D Printed Insert\n\n09235/20000',
#  "It's a good game. Is it worthy of being #1? I don't think so but is definitely up there if euro is your thing. I enjoy playing but it would be rare for me to suggest out of my other games.",
#  "Played at Mini Wellycon 2024. Very smart highly interactive and interconnected economic Euro. A bit dry but really interesting. Only played once and clearly it's the sort of game you need to play a few times to really get to grips with it. I wouldn't put it #1 on my personal list, but I can see how it's such a BGG hit.",
#  "A solid game, I'm just not as excited about it as most other people seem to be. Bought at Essen Spiel '19.",
#  'novel and fun',
#  '9',
# ...
#  '(Sleeved; matte)\n\nPlaymat',
#  'Sleeved\nInsert',
#  'Just boring',
#  'game is so very elegant and dynamic every time',
#  "probably the best economic game I've ever played...",
#  'Quite simply a playful marvel! As good, although different, as its big brother. Enjoyable with 2 or 3 unlike Lancashire which can only be played with 4.',
#  'You can consider starting at €50\nFor just under 30 stonks',
#  'One of the best strategy game designs of all time.',
#  'theme: train, economic\nbest: 3-4\ntime: average (~2h)',
#  '1-4',
#  'WANT',
#  'Best with 4 player, as you get more interactions.',
#  '2-4 players\nHardcore\nPhilly',
#  'Printed organizer',
#  'Amazing game but takes 2 hours to play, not everyone is up to play it but I love it!',
#  'Explainer/Game Master: Thierry',
#  'Best economic game there is',
#  'Heavy-2',
#  'Sloyca Premium',
#  'Signed Copy',
#  '€80 + €56 insert + €8 scales + €39.50 token',
#  'Not sure if its the best boardgame ever, but definetly in the top 5',
#  "Played the new BRASS: BIRMINGHAM yesterday and completely blown away by it (even though I sucked at it). Strong core mechanics, very compelling and elegant gameplay and the most kick-ass production for a Euro I have ever seen (without being  over-produced like most KS games I see). This is Brass done right.  Can't wait to play again...& again!\n\nMy biggest critique of the game (if at all) is related to its major strength—aesthetics. While the art IS spectacular and looks just that on the computer screen where the light of a thousand suns from tiny pixels bring out all the details, I am afraid the printing process does not do justice to the darker palette. This severely impairs the playing of the game in sub-optimal lighting conditions (many cafes, pubs and non-game room areas in condo apartments have this problem). The location banners have similar tonal values and hence can be hard to identify (again, ONLY in sub-optimal lighting conditions) Having said that, it does look AWESOME in natural daylight and/well-lit rooms. I am only making this point because I am REALLY loving the game and wish it was as perfect as it could have been. \n\nAlso, because of the Kickstarter success, it would have been very practical and helpful if a stretch goal was player trays to go with the awesome player mats so all the tiles could be stored in the correct place and the game does not need the 5-6 min painful setup of sorting and placing tiles. Much like games such as Wasteland Express , Reckoners etc. Love the Iron Clays though...cant imagine playing without them!\n--------------------\n\nFavorite things...\n► Brass: Birmingham reinvents a classic, building upon what worked the most and improving things that did not. The depth the game offers relative to its complexity and ruleset is simply the best.\n► The player interaction is another highlight for me. The game works like a dynamic shared economy where every action affects others—networks, market prices, and resource access make Brass feel alive and competitive. This is my absolute favorite kind of player interaction.\n► There are multiple paths to victory, which serve a varied degree of challenges, allowing players to pick what seems most challenging and/or fun for them.\n\nMore, on this & other games in my ALL TIME - TOP 100  on my ⟣⧗First Pass⧗⟢ Blog:\nhttps://boardgamegeek.com/blog/9052/blogpost/172984/anim8rs-top-100-from-1000-2024-25-to-01",
#  'Very good game; one of my top euros. Very fiddly setup and some mechanics are clunky, but otherwise I love the way the game looks and plays. Slightly better than Lancashire, I think, and a major improvement over original Brass in terms of looks.\n\nKey downside in my opinion is that the card actions are hard to remember and manage, especially with new players. People need to be very diligent about spending cards for actions and drawing back up to 8 cards. Very, very common to get to the end of an era with one person having too many cards.',
#  "Matt's collection",
#  'Played once. Looong game. \nOnly for hardcore gamers',
#  'Received for my birthday from Leon and Jelena',
#  'Players C2-4 B3-4\n60-120min',
#  "2 - 4 players\nCan be a bit heavy and some players are susceptible to AP'ing a bit much.",
#  "Haven't tried but my immediate circle doesn't have it and it sticks out as the top boardgame on many lists that I haven't tried and am interested in.",
#  'Insert from PrintablesByCaren (Etsy $37)',
#  'Best game of all time.\n\nMid-heavy euro with a lot of player interaction and a lot of replayability.',
#  "After a while I sold this and I bought the original. If Lancashire didn't exist, this rating would higher. The problem is, they made a worse version of a good game.\n\nIt is more convoluted than Lancashire, with more little bits and adapted to modern eurogamers. The game is more forgiving. No matter how bad the situation is, you can always do something, it is not nearly as tight as the original. Second era is just everyone placing connections and beer. The variable setup is nice, but Lancashire is superior in every other aspect.",
#  'Yes',
#  'The depth/complexity is too small for my taste. Whenever I had my turn planned, I realized that I missed another special rule (because each resource is handled differently). I guess this becomes easier over time but it still requires a lot of mental resources to just get all of the constraints right.',
#  'A really interesting game with a lot of cool mechanics. It takes a while to play though you can set an ealier stopping point (the game has obvious eras) should you not want the game to take too long. It is a bit more complicated than some so it helps to have an experienced person at the table.',
#  'Very challenging and fin game',
#  'lang_eng cat_strategy',
#  'Dinged corner,',
#  '[76] 65x90 boardm sleeve',
#  "Great network building and resource management game. \n\nInterestingly, this game has many actions where the action you're taking benefits yourself, but also another player. For example, you can take other players' resources on building they've built, but they want their buildings to be emptied so that their building tiles can be flipped and score them points and income.\n\nThere is a soft reset of the board in the middle of the game as well, which is definitely something to consider. If you manage to get out one of your buildings that don't get removed by this soft reset after the first era, they will score twice.\n\nI have heard countless times that this game was very cutthroat, but honestly, I didn't find it so compared to other network building games. Yes, you can cut someone's network short with your own, but that means you're likely cutting your own network too. Other players can use each other's networks anyway in many cases. I guess you can steal other players' building spots, but that is not enough to call a game cutthroat for me. i don't generally like cutthroat games, but I did like this.",
#  "Friend's game",
#  '280',
#  'Challenging One.',
#  "A very, very good game. I'll come back with pleasure",
#  'Olga 3\nOmar 1',
#  'A truly remarkable game.',
#  'Easy to get into but really hard on the brain to progress. Always in debt too.\nPlays brilliantly',
#  'The game itself is very neat and fun, but when you start thinking about only earning points through the network, the illusion disappears a bit.',
#  "I think the more I play this the higher it will go. I played two-handed, but I can't stop thinking about it...",
#  'In UK',
#  'Awesome game! (Very hard to play after a longer break.) 2nd phase is more fun than 1st phase.\nBrain-burner. Feels really good to pull off a strategy.',
#  'Derrick, Jessica, Jack?',
#  '3-4 players',
#  'i had a lot of fun playing this game with friends',
#  'Amazing game at every player count.',
#  '#1 on BGG for a long time - would like to play!',
#  "The more I play the more I am converted. What I thought was a smart but hollow experience is now one of my most excited games to table. The balance of tactical plays, strategic planning, and player interaction, all wrapped in (what I think) is a beautiful package and theme, makes it clear why this is the King. It's not my favourite game, but damnit if it's not a brilliant one.",
#  'Original',
#  'Been in the cupboard for years.  Finally got to play with 2 great teachers and none of us are AP prone.\n\nBrilliant, loved every second.  I think it does depend on the people at the table like most games.  Any AP prone people at the table would kill this for me.\n\nWorthy of being top 10 game, not sure about number 1 though ;-)',
#  "One of the most responsive strategy games. And one of the best Euro's out there. More flexible than Brass: Lancashire. Very very good game. could be a bit stuffy.",
#  "Only one game at 4. If it wasn't 1st in the bgg rankings I wouldn't even consider playing it again.",
#  "- first couple of games you will simply try to understand the rules and flip a few tiles across a few industries, then you move on and start developing level I buildings and focus on two or three industries, maybe you even start messing around with the wild cards, at some point you then realize it is really important to flip tiles before the end of the first era and that you should to flip multiple tiles in one move, build multiple connections in one move, buy coal/iron when it's cheap and so on. It is all about the action efficiency, stupid! :)\n- you are working towards your own goals but along the way other players will most likely also benefit from your activities - and vice versa. Whether it is building a connection or supplying resources. Sometimes it makes me wonder: so this is how capitalism works - everyone works for their own advantage but it somehow all falls into place and everyone is better off?!? On average at least…\n- yet you can also hurt other players by occupying spaces they have had their eyes on or forcing them to connect your network to dealers \n- beautiful map and art although a bit too much the dark side",
#  'Just great!',
#  '+ insert reDrewno, iron clays 200',
#  'David S. holds it (March 2025)',
#  'Owner: Katie',
#  "Introduced this game by my mate and I can't stop thinking about it afterwards. Got myself a deluxe copy and played with my SO and she loves it too. My first 10 rating euro game in my collection, is almost flawless, would really like to try Lancashire next and hopefully more Brass games will come out in the future.",
#  "Beautiful in it's design, and elegant.\n\nI can't believe how much I enjoyed this game, and it's worth all of the praise it gets. It scales uniquely from 2-4 players, and even has a fairly accessible 'Short' version.\n\nA little finnicky, and hard to grapple with on the first go through, but you'll catch yourself wanting to push harder and harder for more efficiency on the next play.",
#  'No necessary in-game text',
#  '2-4p',
#  "Incredible game. The rules are surprisingly not intimidating, it's strange. There's really only a few actions you're taking and you're limited to the cards in your hand, but there's an astonishing amount to consider. The nature of the rules and actions also result in new players feeling completely lost for the first half of the game. Thankfully there is an option to just only play one half. You lose out on a lot of the meaty planning ahead strategy, but new players can't comprehend that anyway. Allows you to still play through a teaching game in a couple of hours. The only bummer for me is so far I have mostly only played teaching/half games. \n\nStill my favorite economic game out there, it's a lot to sit down, setup and teach, but it's worth it every time.",
#  'Not my cup of tea, but I can see why people love it.\nVery euro, but also very interactive. First plays can be very punishing for new players.\nIt is easy to teach, but there are many nuances difficult to remember and spot when playing. It can cause AP very easily. I would not seek it but I can play it again',
#  'Played at ampthill on board. Complex but worth a second play.',
#  'I like Lancashire a bit better but these games are good enough to warrant owning and playing two slightly different versions.',
#  '8.5',
#  "Step back in time - entrenched in the theme - working 29hours a day at mill… young folk just wouldn't believe you. Fantastic!",
#  "One of, if not, my favorite board games. Lots of different strategies but you can't stick to one thing and have to adapt to what other players are doing. \n\nLove its blend of pvp + pve. Love the quality, design, everything.",
#  'Best 3-4\n(Sleeved)\nKR+',
#  'Birthday present Sept. 2024',
#  'Description in English: Euro-rated "route/network construction" game based on the Industrial Revolution',
#  "Sleeved (FFG Grey)\nTinkertown 25 iron and 30 'coal' cubes",
#  'Bricks',
#  '2-4',
#  'The Master Work of Tito Wallace ❤️',
#  "I'm still a novice with less than 10 plays under my belt, but this could be a top 5 game for me. I find the interaction between the players as the resource network grows to be so fascinating and unique. I'll revisit my rating once I have more plays under my belt",
#  'The setup is fiddly and the rules are overly complex.\n* Sold by Timeless Board Games for me *',
#  "I have the kickstarter Deluxe edition. It looks sooooo pretty that I don't want to play it. There is no game in my possession with a better build quality",
#  "A good game. I personaly prefer Lancashire because it's a more streamlined version.In my opinion the game already was good enough. But this is still a good one.",
#  "Upgraded it to 9 and potentially to 10 moving forward. It does take a few plays to get around the ridiculous way goods transport around the map but once you accept that it's a great game.\n\nUpgraded to 6 after two plays. Still think it's fiddly as hell but it's definitely an interesting game.\n\nGiving it a reluctant 3 after one first play.\nSuper fiddly unintuitive rules:\n- Different ways the resources travel\n- The fact that lvl 1 buildings get cleared from the main board but not your personal board\n- 1 action for the 1st turn only for some reason\n- Can use bonus beer to ship goods but not to build tracks during phase 2\n\nReally hated the fact that you play canal part and then reset the game and count scores to play the rail phase with some useless buildings on the board you can't reuse. I took effort to develop and place lvl 2 buildings on the board and I can't reflip them for extra income, beer, etc? \n\nAlso the fact that you see the scores at the end of the canal phase, if you're quite far behind doesn't make you want to play the second phase anymore.\n\nEtc, etc.\n\nI basically liked nothing about the game after this first play.",
#  "In friends' collection: I usually wait until I played games a few times before I do a first rating, but this game is an exception. The first time I played this game was already amazing and I can't stop thinking about new strategies I want to try. I'm looking forward to my next play of the game. This is exactly the type of game I love. It does all the things I want in a game and it does them right.",
#  'Martin Wallace economic game masterpiece.',
#  'Critical Thinking\nEconomics\nManagement\nMath and Numeracy\nProblem Solving',
#  'Great game',
#  ...]

# %%
def extract_tokens(text: str) -> list[str]:
    """Firstly remove all non alphabetic characters, having in mind that
    there are Unicode characters. After tokenization we remove stopwords (ENG+PL)
    and  remove all 1-2 chars lenghts words.

    Finally lemmatize tokens.
    """
    clean = re.sub(r"[\W]+", " ", text.lower())
    clean = re.sub(r"[\d]+", " ", clean)
    words = nltk.word_tokenize(clean)
    words = [w for w in words if w not in (word_difficulty.STOPWORDS_PL | word_difficulty.STOPWORDS_EN) and len(w) > 2]
    doc = nlp(" ".join(words))
    return [token.lemma_.lower() for token in doc if token.is_alpha]

# %% [markdown]
# ### Sentiment analysis

# %%
analyzer = SentimentIntensityAnalyzer()

def get_sentiment(text):
    scores = analyzer.polarity_scores(text)
    if scores['compound'] >= 0.05:
        sentiment = 1
    elif scores['compound'] <= -0.05:
        sentiment = -1
    else:
        sentiment = 0
    return sentiment

# %%
sentiments = list(map(get_sentiment, translactions))
list(zip(sentiments, translactions))
# Out:
# [(0, '2-4 [S]'),
#  (1,
#   'Great game that somehow feels simple, yet every decision you make carries weight'),
#  (1,
#   "If you can play this in 60 minutes you're playing too fast.  With my group a a game lasts about 45 minutes per player.\n\nKeep pushing up my rating..  This game continues to be my favorite and the favorite of our group."),
#  (1, 'Table top'),
#  (1,
#   'I only played half a real game, but I was captivated throughout. Would play again.'),
#  (0, 'SGI'),
#  (1,
#   "The more I play, the more I realize it's more about playing the hand you're dealt, and less about strategy"),
#  (1,
#   'Very good game. I might not say it is the best of all times, but it is definetely great. The mechanics are simple, but I consider that it takes a little time to adapt to them. You may need several playthroughs to achieve some sort of mastering. Revise every victory point possibility to plan your strategy, otherwise, it can be easy to fall pursuing things that are not profitable in the long term.'),
#  (1,
#   "+ Artwork is great\n+ Great strategy game\n+ Lots of interaction\n+ Low luck factor\n+ Many paths to victory\n+ Brain burner \n- Quite long\n- Rules heavy \n- Theme is a bit boring\n\nDeep strategic economic game with many ways to win the game. It is surprisingly enough very interactive. I've only played it at 2 and 3 player count."),
#  (1,
#   'Not a Euro fan, it could be good, I wouldn’t mind playing it again if necessary, but I won’t suggest it myself. And yes, this is definitely not the first place on BGG.'),
#  (1,
#   'Most of my plays have been at 2p, and I thoroughly enjoyed every single game. \nHowever, it feels like it ends very quickly at 4p (a feeling it seems others at my table tend to have as well).'),
#  (0, 'Pt: 3'),
#  (0, 'In: October 2025'),
#  (0, 'IS'),
#  (0, 'M.Heavy Euro - Wallace, Trains'),
#  (1,
#   "Arguably the best strategic area control, resource management game.  Just make sure you use other peoples beer and don't let them use yours."),
#  (0, 'Epic'),
#  (1,
#   "haven't played it enough to really understand it. Heavy and thinky. need to log more plays"),
#  (1,
#   "Brass is a game that owes a lot of its success to its ability to offer little criticism (little chance, impeccable editing, mature theme, elitist game). It's an overrated game that rides on the flaws of the BGG ranking (the reissues have excessively high ratings, especially with a graphical overhaul and abundant hyper-quality material. These reissues preach convictions who overrate their favorite games through a new entry on BGG)."),
#  (1,
#   'Your first game is likely going to be rough. However no doubt you will see the appeal of building up your own niche economy that ends up frustratingly reliant on and sometimes in favor the other players. At the end of each round you will be left going "oh I wish I did that," or "things could have gone well if you didn\'t do that", but still be left to admire how everything resulted in the end. After that rough first game, you are most likely going to arrange for another game, all to get better at this system.'),
#  (0, 'B3u4, G2'),
#  (1, 'Gift 14'),
#  (0,
#   '£67.85 https://www.amazon.co.uk/Roxley-Games-ROX402-Brass-Birmingham/dp/1988884047?crid=2I7084BPZPFR5&dib=eyJ2IjoiMSJ9.AKBvx-qCEQ1s2PviGSbDhYyDSrcdKdGtfSi_ilfJCheyjNb5lf8iB5Kr8USCrowvqXNUC7k-hRITiyTddwAp1e-vXgssxL4xuGJa3X2ETt8Np9UmhR4kjr6WpnTMDMRj_VvxWnEgN6AY7c15BtQ-aWQy9Jis6jXCz3utNAtdZ5rT2epjPFsa2S4Te8RikY2S8yEHoXlcbHAEnprGxF1cy7ivg7o24JuypogPNga_UZOPS_Psun_ySg-365rKRCq8i06CmiXpEVyVf83N0o-ViZGc70ox5rE1PqNQ2yb6k4I.VZKtGk37XxVIkuMPPcDUbbo9eBxUHUpzCjO7chxTe9k&dib_tag=se&keywords=brass%2Bbirmingham%2Bboard%2Bgame&qid=1762604991&sprefix=brass%2B%2Caps%2C123&sr=8-4&th=1'),
#  (1,
#   "Previously 9. The more you play this game the more it shines!\n\nIt has a relatively simple rule set with incredible depth. No need for expansions.... It's a modern classic.\n\nIf you like strategy without the need to attack your opponents to win, this is for you.\n\nThe interplay of you using up the other players resources benefitting both you and them is very satisfying and keeps everyone engaged.\n\nGreat family strategic game!"),
#  (-1,
#   'I loathe this as much as I loathed the original Brass. And now add in hunger games for beer. \n\nOne and done.\n\nThe #1 game on BGG? Someone euthanize me.'),
#  (-1,
#   'Tedious and boring VP pusher with instant railway transition. Not my cup of tea? No, I’d rather smear my genitalia with fish paste and dangle them in a pool of hungry piranha. \n\nDingo'),
#  (1,
#   "The first game had been somewhat difficult. Partly because of the new rules and partly because, in the random distribution of initial markets, we ended up with one of them closed and that disrupted how the game unfolds (it doesn't break it, but it's not the easiest thing to deal with the first time). Initially, I was left with the feeling that the addition of options and depth did not compensate for the loss of the fluid pace of the original.\n\nIn the last one I participated in, the same thing happened with the initial markets and we said fuggit, and we shuffled them again. With the rules more polished and more markets open, the game flew with the fluidity that I remembered the original having, so I reconciled myself with this new version.\n\nBut you have to use the side of the board during the day, the side of the board at night, unless you use a miner's helmet with a light, you can't see a knob.\n\nI also don't know what the game will bring as money, because we always use poker chips.\n\nA classic that preserves the best of the Eurogames of that time: depth, options, decisions, interaction, fluidity, with an updated card.\n\nHighly recommended :star::star::star::star::nostar:"),
#  (0, 'SpielboxRating 9-10, by. 9.20'),
#  (1,
#   "Much more fun than the (old) original version. This took a few plays to grow on me. No in game text, has a central board and good balance between tactical and strategical play. Maybe a bit on the long side, but it's a really nail-biter till the end. I can see why this is rated so high as it is."),
#  (1, "It's a great game, would struggle to get consistent plays."),
#  (0, '+ 3D Printed insert\n+ Sleeves'),
#  (1,
#   'I enjoy Lancashire and want to add this one to my collection at some point.'),
#  (1, 'Very clean medium euro.'),
#  (1, 'Great game!'),
#  (1,
#   'Compared to dry games of the same weight, the rules are hard to memorize. The main mechanism is classically simple, like Catan, even for a 2018 game. Replayability is also questionable if played with the same members. Conclusion Fun is simple, understanding is difficult.'),
#  (1,
#   'Great game\n-scratches the economic itch\n-tight gameplay, but does not feel too limiting\n-not too long after you learn\n-straightforward ways to score\n-has a semi cooperative element to the game which make other players turns more interesting  \n-can be a bit tough to learn/teach first time\n-rules can feel contradicting when learning'),
#  (0, 'kickstarter'),
#  (-1,
#   '+ Engaging tactics and strategy\n+ Agonizing decisions and tradeoffs\n+ Tight economy\n+ Player interaction\n+ Climactic ending\n- AP prone\n- Finicky rules and fiddliness\n- Downtime'),
#  (1,
#   "BRASS BIRMINGHAM (2-4 players)\n\nDeluxe player aids: https://boardgamegeek.com/filepage/179522/deluxe-player-aids-brass-birmingham\n\nFanmade solo variant: \n\nhttp://www.mautoma.com/mautomas/brass-birmingham \n\nOnline app for solo variant so you don't have to print the cards: \n\nhttps://boardgamegeek.com/filepage/168370/brass-birmingham-george-solo-competitive-mode\n\nBrass Birmingham is better than Brass Lancashire. The Mautoma Solo variant is quite good but I prefer to play Brass as a multiplayer game. The game is a dry euro but a VERY good dry euro."),
#  (1,
#   "Rules that are a bit obtuse, with exceptions and many details that make you have to constantly review them. The explanation must be prepared well, it is not easy to assimilate the concepts. \n\nI like that everyone participates on the central board and can take advantage of each other's routes and resources, there is a lot of interaction, without a doubt what I like most about the game. The editing is cool too. However, the game has too many unintuitive rules and too many details to keep an eye on (it can lead to long turns). Seeing that it is such a beloved game, I have given it several chances but it is definitely not my thing."),
#  (1,
#   'It’s Brass with a more-is-better approach: more buildings, more locations, more connections—and then beer. Less cutthroat and leaning toward a point-salad feel. The high rail scoring makes the rail era predictable, though some might see it as a more forgiving, flexible evolution of the original. Could rate higher, but I’d always pick Lancashire over this, which brings the rating down a bit.'),
#  (0, 'Boardroom, PAX, 4 2-4, 2h'),
#  (-1,
#   "That's the most boring and ugly game I've ever played. Viscous snot is the most suitable description for it. 1000% overrated."),
#  (1,
#   'Loved playing and would recommend playing but did take us 4 and a half hours to learn and play as a 3. Worth it though'),
#  (1, 'Sleeved with Shield Titan Super Sleeves (Clear)\nInsert included'),
#  (1,
#   "Tentative rating.\n\nI understand how this game got its reputation. The puzzle involved is unique, which is such a rarity among the hundreds of Euros we see each year. It felt like the game is stimulating a whole new part of my brain's strategy center that I didn't know existed, and I love it.\n\nThe game is complex, the strategy is opaque, and it was a pain to teach with all of its minor titbits and exceptions. However, these won't matter after 20+ plays, and the game is solid enough to warrant that."),
#  (0, '3.87'),
#  (1,
#   'great euro styled game.\nflow of interaction is just a masterpiece.\nMartin is genious.'),
#  (0, 'Less fluid than the black edition.'),
#  (1,
#   "In my opinion, Lancashire is much better.\n\nLancashire is more straightforward and you focus on the strategy. You don't get tired of the multitude of tokens, in Lancashire there is only the essential ones. \n\nAfter playing Birmingham I always felt exhausted, but still liked the game. However, after playing Lancashire the time just flew and I would have wanted to play again right away."),
#  (0, '2-4 [S]'),
#  (1,
#   'Great game that somehow feels simple, yet every decision you make carries weight'),
#  (1,
#   "If you can play this in 60 minutes you're playing too fast.  With my group a a game lasts about 45 minutes per player.\n\nKeep pushing up my rating..  This game continues to be my favorite and the favorite of our group."),
#  (1, 'Table top'),
#  (1,
#   'I only played half a real game, but I was captivated throughout. Would play again.'),
#  (0, 'SGI'),
#  (1,
#   "The more I play, the more I realize it's more about playing the hand you're dealt, and less about strategy"),
#  (1,
#   'Very good game. I might not say it is the best of all times, but it is definetely great. The mechanics are simple, but I consider that it takes a little time to adapt to them. You may need several playthroughs to achieve some sort of mastering. Revise every victory point possibility to plan your strategy, otherwise, it can be easy to fall pursuing things that are not profitable in the long term.'),
#  (1,
#   "+ Artwork is great\n+ Great strategy game\n+ Lots of interaction\n+ Low luck factor\n+ Many paths to victory\n+ Brain burner \n- Quite long\n- Rules heavy \n- Theme is a bit boring\n\nDeep strategic economic game with many ways to win the game. It is surprisingly enough very interactive. I've only played it at 2 and 3 player count."),
#  (1,
#   'Not a Euro fan, it could be good, I wouldn’t mind playing it again if necessary, but I won’t suggest it myself. And yes, this is definitely not the first place on BGG.'),
#  (1,
#   'Most of my plays have been at 2p, and I thoroughly enjoyed every single game. \nHowever, it feels like it ends very quickly at 4p (a feeling it seems others at my table tend to have as well).'),
#  (0, 'Pt: 3'),
#  (0, 'In: October 2025'),
#  (0, 'IS'),
#  (0, 'M.Heavy Euro - Wallace, Trains'),
#  (1,
#   "Arguably the best strategic area control, resource management game.  Just make sure you use other peoples beer and don't let them use yours."),
#  (0, 'Epic'),
#  (1,
#   "haven't played it enough to really understand it. Heavy and thinky. need to log more plays"),
#  (1,
#   "Brass is a game that owes a lot of its success to its ability to offer little criticism (little chance, impeccable editing, mature theme, elitist game). It's an overrated game that rides on the flaws of the BGG ranking (the reissues have excessively high ratings, especially with a graphical overhaul and abundant hyper-quality material. These reissues preach convictions who overrate their favorite games through a new entry on BGG)."),
#  (1,
#   'Your first game is likely going to be rough. However no doubt you will see the appeal of building up your own niche economy that ends up frustratingly reliant on and sometimes in favor the other players. At the end of each round you will be left going "oh I wish I did that," or "things could have gone well if you didn\'t do that", but still be left to admire how everything resulted in the end. After that rough first game, you are most likely going to arrange for another game, all to get better at this system.'),
#  (0, 'B3u4, G2'),
#  (1, 'Gift 14'),
#  (0,
#   '£67.85 https://www.amazon.co.uk/Roxley-Games-ROX402-Brass-Birmingham/dp/1988884047?crid=2I7084BPZPFR5&dib=eyJ2IjoiMSJ9.AKBvx-qCEQ1s2PviGSbDhYyDSrcdKdGtfSi_ilfJCheyjNb5lf8iB5Kr8USCrowvqXNUC7k-hRITiyTddwAp1e-vXgssxL4xuGJa3X2ETt8Np9UmhR4kjr6WpnTMDMRj_VvxWnEgN6AY7c15BtQ-aWQy9Jis6jXCz3utNAtdZ5rT2epjPFsa2S4Te8RikY2S8yEHoXlcbHAEnprGxF1cy7ivg7o24JuypogPNga_UZOPS_Psun_ySg-365rKRCq8i06CmiXpEVyVf83N0o-ViZGc70ox5rE1PqNQ2yb6k4I.VZKtGk37XxVIkuMPPcDUbbo9eBxUHUpzCjO7chxTe9k&dib_tag=se&keywords=brass%2Bbirmingham%2Bboard%2Bgame&qid=1762604991&sprefix=brass%2B%2Caps%2C123&sr=8-4&th=1'),
#  (1,
#   "Previously 9. The more you play this game the more it shines!\n\nIt has a relatively simple rule set with incredible depth. No need for expansions.... It's a modern classic.\n\nIf you like strategy without the need to attack your opponents to win, this is for you.\n\nThe interplay of you using up the other players resources benefitting both you and them is very satisfying and keeps everyone engaged.\n\nGreat family strategic game!"),
#  (-1,
#   'I loathe this as much as I loathed the original Brass. And now add in hunger games for beer. \n\nOne and done.\n\nThe #1 game on BGG? Someone euthanize me.'),
#  (-1,
#   'Tedious and boring VP pusher with instant railway transition. Not my cup of tea? No, I’d rather smear my genitalia with fish paste and dangle them in a pool of hungry piranha. \n\nDingo'),
#  (1,
#   "The first game had been somewhat difficult. Partly because of the new rules and partly because, in the random distribution of initial markets, we ended up with one of them closed and that disrupted how the game unfolds (it doesn't break it, but it's not the easiest thing to deal with the first time). Initially, I was left with the feeling that the addition of options and depth did not compensate for the loss of the fluid pace of the original.\n\nIn the last one I participated in, the same thing happened with the initial markets and we said fuggit, and we shuffled them again. With the rules more polished and more markets open, the game flew with the fluidity that I remembered the original having, so I reconciled myself with this new version.\n\nBut you have to use the side of the board during the day, the side of the board at night, unless you use a miner's helmet with a light, you can't see a knob.\n\nI also don't know what the game will bring as money, because we always use poker chips.\n\nA classic that preserves the best of the Eurogames of that time: depth, options, decisions, interaction, fluidity, with an updated card.\n\nHighly recommended :star::star::star::star::nostar:"),
#  (0, 'SpielboxRating 9-10, by. 9.20'),
#  (1,
#   "Much more fun than the (old) original version. This took a few plays to grow on me. No in game text, has a central board and good balance between tactical and strategical play. Maybe a bit on the long side, but it's a really nail-biter till the end. I can see why this is rated so high as it is."),
#  (1, "It's a great game, would struggle to get consistent plays."),
#  (0, '+ 3D Printed insert\n+ Sleeves'),
#  (1,
#   'I enjoy Lancashire and want to add this one to my collection at some point.'),
#  (1, 'Very clean medium euro.'),
#  (1, 'Great game!'),
#  (1,
#   'Compared to dry games of the same weight, the rules are hard to memorize. The main mechanism is classically simple, like Catan, even for a 2018 game. Replayability is also questionable if played with the same members. Conclusion Fun is simple, understanding is difficult.'),
#  (1,
#   'Great game\n-scratches the economic itch\n-tight gameplay, but does not feel too limiting\n-not too long after you learn\n-straightforward ways to score\n-has a semi cooperative element to the game which make other players turns more interesting  \n-can be a bit tough to learn/teach first time\n-rules can feel contradicting when learning'),
#  (0, 'kickstarter'),
#  (-1,
#   '+ Engaging tactics and strategy\n+ Agonizing decisions and tradeoffs\n+ Tight economy\n+ Player interaction\n+ Climactic ending\n- AP prone\n- Finicky rules and fiddliness\n- Downtime'),
#  (1,
#   "BRASS BIRMINGHAM (2-4 players)\n\nDeluxe player aids: https://boardgamegeek.com/filepage/179522/deluxe-player-aids-brass-birmingham\n\nFanmade solo variant: \n\nhttp://www.mautoma.com/mautomas/brass-birmingham \n\nOnline app for solo variant so you don't have to print the cards: \n\nhttps://boardgamegeek.com/filepage/168370/brass-birmingham-george-solo-competitive-mode\n\nBrass Birmingham is better than Brass Lancashire. The Mautoma Solo variant is quite good but I prefer to play Brass as a multiplayer game. The game is a dry euro but a VERY good dry euro."),
#  (1,
#   "Rules that are a bit obtuse, with exceptions and many details that make you have to constantly review them. The explanation must be prepared well, it is not easy to assimilate the concepts. \n\nI like that everyone participates on the central board and can take advantage of each other's routes and resources, there is a lot of interaction, without a doubt what I like most about the game. The editing is cool too. However, the game has too many unintuitive rules and too many details to keep an eye on (it can lead to long turns). Seeing that it is such a beloved game, I have given it several chances but it is definitely not my thing."),
#  (1,
#   'It’s Brass with a more-is-better approach: more buildings, more locations, more connections—and then beer. Less cutthroat and leaning toward a point-salad feel. The high rail scoring makes the rail era predictable, though some might see it as a more forgiving, flexible evolution of the original. Could rate higher, but I’d always pick Lancashire over this, which brings the rating down a bit.'),
#  (0, 'Boardroom, PAX, 4 2-4, 2h'),
#  (-1,
#   "That's the most boring and ugly game I've ever played. Viscous snot is the most suitable description for it. 1000% overrated."),
#  (1,
#   'Loved playing and would recommend playing but did take us 4 and a half hours to learn and play as a 3. Worth it though'),
#  (1, 'Sleeved with Shield Titan Super Sleeves (Clear)\nInsert included'),
#  (1,
#   "Tentative rating.\n\nI understand how this game got its reputation. The puzzle involved is unique, which is such a rarity among the hundreds of Euros we see each year. It felt like the game is stimulating a whole new part of my brain's strategy center that I didn't know existed, and I love it.\n\nThe game is complex, the strategy is opaque, and it was a pain to teach with all of its minor titbits and exceptions. However, these won't matter after 20+ plays, and the game is solid enough to warrant that."),
#  (0, '3.87'),
#  (1,
#   'great euro styled game.\nflow of interaction is just a masterpiece.\nMartin is genious.'),
#  (0, 'Less fluid than the black edition.'),
#  (1,
#   "In my opinion, Lancashire is much better.\n\nLancashire is more straightforward and you focus on the strategy. You don't get tired of the multitude of tokens, in Lancashire there is only the essential ones. \n\nAfter playing Birmingham I always felt exhausted, but still liked the game. However, after playing Lancashire the time just flew and I would have wanted to play again right away."),
#  (0, '2-4 [S]'),
#  (1,
#   'Great game that somehow feels simple, yet every decision you make carries weight'),
#  (1,
#   "If you can play this in 60 minutes you're playing too fast.  With my group a a game lasts about 45 minutes per player.\n\nKeep pushing up my rating..  This game continues to be my favorite and the favorite of our group."),
#  (1, 'Table top'),
#  (1,
#   'I only played half a real game, but I was captivated throughout. Would play again.'),
#  (0, 'SGI'),
#  (1,
#   "The more I play, the more I realize it's more about playing the hand you're dealt, and less about strategy"),
#  (1,
#   'Very good game. I might not say it is the best of all times, but it is definetely great. The mechanics are simple, but I consider that it takes a little time to adapt to them. You may need several playthroughs to achieve some sort of mastering. Revise every victory point possibility to plan your strategy, otherwise, it can be easy to fall pursuing things that are not profitable in the long term.'),
#  (1,
#   "+ Artwork is great\n+ Great strategy game\n+ Lots of interaction\n+ Low luck factor\n+ Many paths to victory\n+ Brain burner \n- Quite long\n- Rules heavy \n- Theme is a bit boring\n\nDeep strategic economic game with many ways to win the game. It is surprisingly enough very interactive. I've only played it at 2 and 3 player count."),
#  (1,
#   'Not a Euro fan, it could be good, I wouldn’t mind playing it again if necessary, but I won’t suggest it myself. And yes, this is definitely not the first place on BGG.'),
#  (1,
#   'Most of my plays have been at 2p, and I thoroughly enjoyed every single game. \nHowever, it feels like it ends very quickly at 4p (a feeling it seems others at my table tend to have as well).'),
#  (0, 'Pt: 3'),
#  (0, 'In: October 2025'),
#  (0, 'IS'),
#  (0, 'M.Heavy Euro - Wallace, Trains'),
#  (1,
#   "Arguably the best strategic area control, resource management game.  Just make sure you use other peoples beer and don't let them use yours."),
#  (0, 'Epic'),
#  (1,
#   "haven't played it enough to really understand it. Heavy and thinky. need to log more plays"),
#  (1,
#   "Brass is a game that owes a lot of its success to its ability to offer little criticism (little chance, impeccable editing, mature theme, elitist game). It's an overrated game that rides on the flaws of the BGG ranking (the reissues have excessively high ratings, especially with a graphical overhaul and abundant hyper-quality material. These reissues preach convictions who overrate their favorite games through a new entry on BGG)."),
#  (1,
#   'Your first game is likely going to be rough. However no doubt you will see the appeal of building up your own niche economy that ends up frustratingly reliant on and sometimes in favor the other players. At the end of each round you will be left going "oh I wish I did that," or "things could have gone well if you didn\'t do that", but still be left to admire how everything resulted in the end. After that rough first game, you are most likely going to arrange for another game, all to get better at this system.'),
#  (0, 'B3u4, G2'),
#  (1, 'Gift 14'),
#  (0,
#   '£67.85 https://www.amazon.co.uk/Roxley-Games-ROX402-Brass-Birmingham/dp/1988884047?crid=2I7084BPZPFR5&dib=eyJ2IjoiMSJ9.AKBvx-qCEQ1s2PviGSbDhYyDSrcdKdGtfSi_ilfJCheyjNb5lf8iB5Kr8USCrowvqXNUC7k-hRITiyTddwAp1e-vXgssxL4xuGJa3X2ETt8Np9UmhR4kjr6WpnTMDMRj_VvxWnEgN6AY7c15BtQ-aWQy9Jis6jXCz3utNAtdZ5rT2epjPFsa2S4Te8RikY2S8yEHoXlcbHAEnprGxF1cy7ivg7o24JuypogPNga_UZOPS_Psun_ySg-365rKRCq8i06CmiXpEVyVf83N0o-ViZGc70ox5rE1PqNQ2yb6k4I.VZKtGk37XxVIkuMPPcDUbbo9eBxUHUpzCjO7chxTe9k&dib_tag=se&keywords=brass%2Bbirmingham%2Bboard%2Bgame&qid=1762604991&sprefix=brass%2B%2Caps%2C123&sr=8-4&th=1'),
#  (1,
#   "Previously 9. The more you play this game the more it shines!\n\nIt has a relatively simple rule set with incredible depth. No need for expansions.... It's a modern classic.\n\nIf you like strategy without the need to attack your opponents to win, this is for you.\n\nThe interplay of you using up the other players resources benefitting both you and them is very satisfying and keeps everyone engaged.\n\nGreat family strategic game!"),
#  (-1,
#   'I loathe this as much as I loathed the original Brass. And now add in hunger games for beer. \n\nOne and done.\n\nThe #1 game on BGG? Someone euthanize me.'),
#  (-1,
#   'Tedious and boring VP pusher with instant railway transition. Not my cup of tea? No, I’d rather smear my genitalia with fish paste and dangle them in a pool of hungry piranha. \n\nDingo'),
#  (1,
#   "The first game had been somewhat difficult. Partly because of the new rules and partly because, in the random distribution of initial markets, we ended up with one of them closed and that disrupted how the game unfolds (it doesn't break it, but it's not the easiest thing to deal with the first time). Initially, I was left with the feeling that the addition of options and depth did not compensate for the loss of the fluid pace of the original.\n\nIn the last one I participated in, the same thing happened with the initial markets and we said fuggit, and we shuffled them again. With the rules more polished and more markets open, the game flew with the fluidity that I remembered the original having, so I reconciled myself with this new version.\n\nBut you have to use the side of the board during the day, the side of the board at night, unless you use a miner's helmet with a light, you can't see a knob.\n\nI also don't know what the game will bring as money, because we always use poker chips.\n\nA classic that preserves the best of the Eurogames of that time: depth, options, decisions, interaction, fluidity, with an updated card.\n\nHighly recommended :star::star::star::star::nostar:"),
#  (0, 'SpielboxRating 9-10, by. 9.20'),
#  (1,
#   "Much more fun than the (old) original version. This took a few plays to grow on me. No in game text, has a central board and good balance between tactical and strategical play. Maybe a bit on the long side, but it's a really nail-biter till the end. I can see why this is rated so high as it is."),
#  (1, "It's a great game, would struggle to get consistent plays."),
#  (0, '+ 3D Printed insert\n+ Sleeves'),
#  (1,
#   'I enjoy Lancashire and want to add this one to my collection at some point.'),
#  (1, 'Very clean medium euro.'),
#  (1, 'Great game!'),
#  (1,
#   'Compared to dry games of the same weight, the rules are hard to memorize. The main mechanism is classically simple, like Catan, even for a 2018 game. Replayability is also questionable if played with the same members. Conclusion Fun is simple, understanding is difficult.'),
#  (1,
#   'Great game\n-scratches the economic itch\n-tight gameplay, but does not feel too limiting\n-not too long after you learn\n-straightforward ways to score\n-has a semi cooperative element to the game which make other players turns more interesting  \n-can be a bit tough to learn/teach first time\n-rules can feel contradicting when learning'),
#  (0, 'kickstarter'),
#  (-1,
#   '+ Engaging tactics and strategy\n+ Agonizing decisions and tradeoffs\n+ Tight economy\n+ Player interaction\n+ Climactic ending\n- AP prone\n- Finicky rules and fiddliness\n- Downtime'),
#  (1,
#   "BRASS BIRMINGHAM (2-4 players)\n\nDeluxe player aids: https://boardgamegeek.com/filepage/179522/deluxe-player-aids-brass-birmingham\n\nFanmade solo variant: \n\nhttp://www.mautoma.com/mautomas/brass-birmingham \n\nOnline app for solo variant so you don't have to print the cards: \n\nhttps://boardgamegeek.com/filepage/168370/brass-birmingham-george-solo-competitive-mode\n\nBrass Birmingham is better than Brass Lancashire. The Mautoma Solo variant is quite good but I prefer to play Brass as a multiplayer game. The game is a dry euro but a VERY good dry euro."),
#  (1,
#   "Rules that are a bit obtuse, with exceptions and many details that make you have to constantly review them. The explanation must be prepared well, it is not easy to assimilate the concepts. \n\nI like that everyone participates on the central board and can take advantage of each other's routes and resources, there is a lot of interaction, without a doubt what I like most about the game. The editing is cool too. However, the game has too many unintuitive rules and too many details to keep an eye on (it can lead to long turns). Seeing that it is such a beloved game, I have given it several chances but it is definitely not my thing."),
#  (1,
#   'It’s Brass with a more-is-better approach: more buildings, more locations, more connections—and then beer. Less cutthroat and leaning toward a point-salad feel. The high rail scoring makes the rail era predictable, though some might see it as a more forgiving, flexible evolution of the original. Could rate higher, but I’d always pick Lancashire over this, which brings the rating down a bit.'),
#  (0, 'Boardroom, PAX, 4 2-4, 2h'),
#  (-1,
#   "That's the most boring and ugly game I've ever played. Viscous snot is the most suitable description for it. 1000% overrated."),
#  (1,
#   'Loved playing and would recommend playing but did take us 4 and a half hours to learn and play as a 3. Worth it though'),
#  (1, 'Sleeved with Shield Titan Super Sleeves (Clear)\nInsert included'),
#  (1,
#   "Tentative rating.\n\nI understand how this game got its reputation. The puzzle involved is unique, which is such a rarity among the hundreds of Euros we see each year. It felt like the game is stimulating a whole new part of my brain's strategy center that I didn't know existed, and I love it.\n\nThe game is complex, the strategy is opaque, and it was a pain to teach with all of its minor titbits and exceptions. However, these won't matter after 20+ plays, and the game is solid enough to warrant that."),
#  (0, '3.87'),
#  (1,
#   'great euro styled game.\nflow of interaction is just a masterpiece.\nMartin is genious.'),
#  (0, 'Less fluid than the black edition.'),
#  (1,
#   "In my opinion, Lancashire is much better.\n\nLancashire is more straightforward and you focus on the strategy. You don't get tired of the multitude of tokens, in Lancashire there is only the essential ones. \n\nAfter playing Birmingham I always felt exhausted, but still liked the game. However, after playing Lancashire the time just flew and I would have wanted to play again right away."),
#  (1,
#   "Too many little nit-picky rules.  It's fine, but I always get frustrated when I play it.  Wish it was a little more intuitive and elegant in its design.  I can see why people like it - my group loves it - just not my favorite."),
#  (0, '25\n50€'),
#  (-1,
#   "This game is not about deciding what to do. It's about figuring out what you can do by navigating the silly amount of clunky exceptions slowly but surely chipping away your decision space until only 1-2 options are remaining. Turns take a long time not because of strategy, but because of how fiddly everything is. The rules are nonsensical from a logic standpoint. Some resources follow networks, some teleport, some do both, sometimes, except x and y and z. And then, halfway through the game, the connections between the places you worked on for the last hour and a half have to be removed and redone from scratch in the second half. The graphic design is abysmal, symbols are lost in the unnecessary detail, everything becomes a blurry mess, while important information is hidden away in the corners. The player aids that come in the box are worthless, the game is genuinely unlearnable and unplayable without the user-made ones. Furthermore, the setup and the mid-game scoring/upkeep are tedious, fiddly and take way too long. This game does not deserve the praise it gets, at all."),
#  (1,
#   'Was my #1 game! (2022)\nI love the shared economy, board building, income, and theme of this game.'),
#  (0, 'DIY'),
#  (1,
#   "good game , \nbrass Birmingham = wildcatters ( underrated )\nhas the same feel: \n-pick an area through cards on a map\n- play your actions , build, develop, trains ... in that area\n- use each other's  network\n...."),
#  (1,
#   'Loaned to Connor Smith on 11/3/2023, returned 1/22/2024\nLoaned to Cade Loving on 3/16/2024, returned'),
#  (-1, 'not fun no matter how hard i try'),
#  (1,
#   '+Incredible depth of strategy. Brain burning turns trying to figure out what, where and in which order to build. \n+The player economy and heavy interaction is a joy. "Helping" other players out by flipping their tiles makes everyone feel good, but can quickly swing to tense denial as someone takes your last beer. Need to always be on your toes to see how changes in the board state benefits or harms you.\n+Lots of opportunities to feel clever in short-term tactics to take advantage of board/market state, and also longer-term planning for big sales. \n\n-Easily creates AP in players, making the game drag at 4p.\n-Takes a couple plays to really see the tactics and strategies. First play is mostly just figuring out WHAT you can do with your cards.  \n\n≈The cards act as a limit to what you\'re able to do, which is not my preference for a heavy strategy game. The "do the best with what you\'ve been given" feels more tactical. Contrast this with Terra Mystica where all the actions are available to you, but it is your resources that limit your choices. \n≈Strategizing and playing well is a massive brain burn. It\'s a lot of work just figuring out what the cards allow you to do, before you can even work out an optimal strategy from the available options.\n\n8 > 7.8 > 8'),
#  (1,
#   "Doesn't sound that interesting, but the #1 game ever, so might as well try?"),
#  (1,
#   'Partially Played at ProCon 2024. Was the last day, we were both exhausted so I will not rate just yet until there is another chance to play it.'),
#  (1,
#   'Overall, it’s a solid game, but I expected more from something ranked #1. If it held a lower position, I’d likely view it more favorably. Also, the theme drags everything else down.'),
#  (-1, 'A bit too repetitive'),
#  (1, 'A superb economic game'),
#  (1,
#   'Played once and enjoyed it. It took several turns before it started to click, but not until end of the game that some of the scoring really started to make sense.'),
#  (0, '2-4'),
#  (1,
#   'We played together with my wife. We love the game, the its number 1 place on the ranking list is well deserved. The learning curve took some time, we watched tutorials as some rules were not easily understandable in the hungarian rule book (at least for us).\n\nThe game with 2 players is fun and pretty fast, with little downtime. Both eras are fun and once you figure out certain rules it can be fun. There are more detailed reviews, but what I have to say is that this is a well designed game (a bit too dark for my taste and eyes) made for us, as we like euro games with less or zero luck.'),
#  (1, 'The perfect german.'),
#  (1,
#   'A heavy boardgame classic with a short rulebook presenting relatively few and absolutely clear rules, a simple and convincing iconography, a truely atomspheric artwork and an outstanding thematic embedding.\nTons of tactical options, dilemmas and decisions just wait to be explored, interaction galore. Gameplay is very demanding, entertainment guaranteed. Sheer enthusiasm if a plan works, pure frustration if it doesn´t, \nThe board game companion to "Hard times" by Charles Dickens or "North & South" by Elizabeth Gaskell.\nBest board game ever? I don´t know, but it´s extraordinary.\n(SPIEL25 Essen 25.10.25)'),
#  (0, 'Skopje Insert 3d'),
#  (1,
#   "Pros:\nGreat theme and artwork. It looks beautiful on the table.\nUsually finishes within reasonable time\nCons:\nSome of the mechanics in this game are unnecessarily complex for complexity sake. \nTransition from canal to rail era breaks the rhythm of the game . Scraping all those old tiles off the map is fiddly and annoying.\nSetup is a drag. Having to meticulously place all the tiles on player boards feels like a chore and is annoying due to the fact that most of them don't get used."),
#  (0, '*'),
#  (0, 'M: 2-4'),
#  (1,
#   'Very clever positive-negative interaction.\nSmart management of the changing market and the order of play is great.\nThe theme is "meh", but at least it\'s nicely executed.\nThe mechanics of beer are not as interesting to me as those of ports.\nThere are a lot more options than in Lancashire, so it loses a bit of the tension.\nDeservedly BGG top 1.'),
#  (1, 'It it great'),
#  (0,
#   'Brass: Birmingham (2018) https://tarsasjatekok.com/tarsasjatek/brass-lancashire-2007/kiegeszito/brass-birmingham-2018 Gavan Brown, Matt Tolman, Martin Wallace Artist: Gavan Brown, Lina Cossette, David Forest, Gui Landgraf, Damien Mammoliti, Matt Tolman Rank: Overall 1 Strategy 1 Spiel des Jahres 2018 Év játéka jelölt TEMU'),
#  (1, 'fun!'),
#  (1,
#   'A crunchy and smooth euro. Certainly a bit heavy, but the game is a blast to play. I really need to play this one more. This game is another proof that hand-management is the best mechanism in gaming. The current king of BGG, it\'s definitely one of the best euros that I\'ve ever played. The set up is a bit long, but it\'s all worth it. All the mechanics of the game shines through, and it\'s very engaging and fun to construct new "buildings" and deliver goods. And the beautiful artwork is just the cherry on top.\n\nThat being said, it does still feel a bit dry and less exciting compared to lots of other heavy euro games that I love. I personally enjoy A Feast for Odin, Kanban EV, and Great Western Trail a lot more. Maybe because the currency and numbers in those games are smaller and less math-y.'),
#  (0,
#   "Industrial Revolution England-Themed, Heavy Economic Euro-Game.\n2-4 Players. (Best With 3-4 Players).\n\n'Deluxe Edition Comes With Upgraded Player Mats, A Custom Insert, And Upgraded Money Chips'.\n\n“Sleeved”"),
#  (-1,
#   "This is a very interactive game: players must look for ways to interfere with their opponents’ plans by blocking access to markets and resources. While that’s going on, you must somehow implement a plan of your own while factoring in all the ways your opponents could mess it up. The result is a fascinating but often frustrating game.\n \nThe art and graphics are too dark, even on the “daylight” side of the double sided board. This is too bad because the art is excellent. The dark shading is meant to be thematic by portraying the dirty coal smoke pollution of the period. It’s as if a dark grey filter is overlaid on the board but it’s so dark it's difficult to discern the features necessary for play without bright room lighting."),
#  (-1, 'Steam version but not good'),
#  (0,
#   'Preferred player count: 4p\nInteraction: High, while still being a Euro.'),
#  (0, 'Solo'),
#  (1,
#   "It's.... fine. Would you have told me this is the number 1 rated board game on BGG after playing it I would have never believed you. \n\nMaybe I need to try it again?"),
#  (0, '2-4 B: 3-4\nIn: 3.87'),
#  (1,
#   'The absolutely most overrated game ever. Boring and stale. Lacking a lot of variation and dynamic to be even near a good game for me.'),
#  (0, 'Sleeved with:\nGGS10063ML Standard Card Game Matte (66 x 91)'),
#  (0,
#   'Aesthetic: 1\nMechanism: 2\nInvolvement/length/fluid: 2\nReplayability: 2\nOther: 1'),
#  (0, '+ Iron Clay Upgrade\n+ Playmat'),
#  (0, 'E. 60'),
#  (0, 'H'),
#  (0, 'To test'),
#  (1,
#   'Played only once with friends and fell in love. Awesome game. Will try it again to get more of it.'),
#  (1, '1 play'),
#  (-1, 'Falling low'),
#  (1,
#   'We played Brass as Kickstarter and Deluxe edition (which is the same quality and tokens) and as 4, 3 and 2 player games. Its incredibly flexible and game mechanics are challenging enough to keep you busy during downtime (which it has) but overall, player interaction is very good and we can truly recommend it because of its re-playability in all constellations.'),
#  (1,
#   'Excellent. Deep strategy with clear rules that are not even that complex. The only downside is that you constantly have to do a LOT of coin exchange to have exact change.'),
#  (1, 'Played (IRL & TTS)'),
#  (0, '3 4 players'),
#  (1,
#   'Theme is so great. I was born in Dudley and am very proud of our industrial heritage. This game is the best attempt to place the player at the heart of the industrial revolution. \n\nAfter playing a few games I realised it requires a lot of time investment to play and improve but having spent that time I really appreciate the nuance of this tight design. Exclusively played at 2 players.'),
#  (1,
#   "deep strategic possibilities, competition for space, sharing of other players' resources...\nHigh replay value in my opinion"),
#  (1, 'Best at 2'),
#  (0, '2025'),
#  (0, 'N/A Expansions\n\n(Folded Space Insert)'),
#  (0, 'JJ2'),
#  (0, 'Roxley Games'),
#  (1,
#   'Gave it a shot to see what all the hype was about, and I was pleasantly surprised! The economic choices are varied. Stealing resources from others, or getting your resources stolen, does not feel too cutthroat since you get hefty benefits from depleting resources, no matter who was responsible for this. This makes these "take that" choices feel less malevolent and the less obvious choice to take, because you need to think about whether it helps them more than it helps you. It\'s also surprisingly not a super long game unless you have players with bad cases of AP. The setup is a bit tedious, but I always measure games by the setup/fun ratio, and the fun in this case is worth it.'),
#  (0, '2024:I\n2025:IIII'),
#  (1,
#   'English retail edition. Includes https://boardgamegeek.com/boardgameaccessory/306354/brass-birmingham-lancashire-folded-space-insert\n\nBox has moderate shelf wear and whitening, seen here:\nhttps://boardgamegeek.com/image/9176195/lboucheron\nhttps://boardgamegeek.com/image/9176197/lboucheron\nhttps://boardgamegeek.com/image/9176194/lboucheron\n\nThe previous owner glued together the Folded Space insert. I believe they put away the game components before the glue was fully dry, which led to a few pieces sticking and tearing when removed. All the damaged pieces I could find are shown here:\n\nhttps://boardgamegeek.com/image/9176196/lboucheron\n\nAll other components are in excellent condition. Cards are sleeved in premium sleeves.'),
#  (1, 'Such an excellent design and the reprint is out of this world!'),
#  (1, "Complex game with many strategies available. Great game of it's genre"),
#  (0, 'Need to Review'),
#  (0, 'Cake - Black Shelf'),
#  (0,
#   "Find this one a little harder to get my head around than Lancashire, but probably just because I don't own it."),
#  (0, 'Kickstarter game forge with Iron clays'),
#  (0, '3D Printed Insert'),
#  (1,
#   'I mean what can I even say that anybody else hasn’t already? It’s Brass Birmingham. That’s all you need to know, and while it isn’t one of my all time favorites it’s undeniably fantastic. Brass keeps you on your toes in way that rewards both long term planning and clever decisions on the fly, making you constantly adjust to the ever fluctuations of the market. Brass can feel very frustrating at times, sure. However anyone with a love of the hobby who is willing to give it a good amount of plays will see why this is the number one game of all time. At least until camel up inevitably overtakes it as it should.'),
#  (0, 'Highest Rank: 1 in 2025'),
#  (1,
#   "Puzzle-y and thinky game. Lots of strategies to explore. Good player interaction, in terms of racing for certain spots and resources, and using other player's connections and resources (coal, iron, & beer). Very crunchy."),
#  (1,
#   "For two players, it isn't our household first choice.  But it's a really fun game to have in the collection and play with 3 or 4."),
#  (0, 'See other copy.'),
#  (1,
#   'One play: Nice game, random location of selling points made half the map unused.'),
#  (0, 'Check'),
#  (0, '[u]Expansions & Upgrades:[/u]\n-Iron Clays'),
#  (1,
#   'Had a lot of fun with this, great mechanics for the most part and lots of interesting interaction.  Really enjoy the markets, loans, network building etc..  So much interaction and so many great small quick decisions.'),
#  (0, '@TX'),
#  (0, 'Sleeved / Inserted'),
#  (-1, "I don't like bear."),
#  (0, 'Zmvo'),
#  (1, 'played'),
#  (1,
#   'Really enjoyed they game. It was challenging to set up your turns but it was fun. Played it with 2 others.'),
#  (0, 'Keep'),
#  (1, 'Best: 3-4\nOwner: Adam A'),
#  (1, '* Sleeved ✓\n* Custom Insert - I want one'),
#  (1, '30% luck, 70% strategy'),
#  (1,
#   "Took another run at Birmingham after hitting 20+ plays of Lancashire. Confirmed that for our tastes, it's worse in every way. A frustrating, lengthy, overly procedural experience that offers less interaction than the original. Lowered rating to a 6. I'm surprised more gamers new to the system don't bounce off Birmingham. \n===================================================\nFinally got this to the table after almost a dozen plays of Lancashire.\n\nBirmingham is much fiddlier. Much more difficult to put together a sequence of useful actions. The addition of beer, and the wonky benefits of manufactured goods and pottery, make for a more uneven and frustrating experience all around. That’s not sour grapes - I won handily.\n\nPresumably, Birmingham is intended to refresh the challenge for people who have played out Lancashire. Fair enough. But I won’t be coming back to it any time soon - Lancashire isn’t a lifestyle game for me, so at 6-7 plays a year I expect I have years of play before it starts to get stale. I doubt Birmingham sees the table again in that time."),
#  (0, 'Premium\n(Deluxe Edition)'),
#  (1,
#   "What a cool game. The aesthetic is great, the strategy runs deep, and I absolutely adore the interconnectedness of the economy. Seeing this level of interaction in a Euro is so refreshing. The players have immense agency over the state of the game, and the way it all comes together is magical.\n\nThat said, some of the rules are incredibly unintuitive, bordering on arcane (iron can teleport, coal cannot, beer can for you, etc). There's enough weirdness to make it genuinely difficult to explain with a straight face. It's not particularly complex in the traditional sense; there's not that many actions you can take, but these strange caveats combined with the obtuse nature of how to actually play the game well makes for a large barrier to entry. I also find the game can veer into being slightly dry after many plays.\n\nStill, this is an amazing design. My only real critiques are in regards to the teach, and once players learn it this is a masterpiece. The fact that this game allows for this level of enmeshment between the players is a breath of fresh air, and something I must find more of."),
#  (1,
#   'The plus version of Power Plant, but I always feel that it is not as simple as Power Plant. It will be easy to play at the beginning. After playing a few more times, you will understand its design intention.'),
#  (0, 'aliexpress'),
#  (0, 'D.S'),
#  (0, 'PoS'),
#  (1,
#   'Hard to teach but smooth as silk once everyone gets it. The game gives you that perfect desire a game should - to play it again because you think you know where you can do better next time.'),
#  (1,
#   'Mary and I love this game.  Such a fun strategy game that does not get boring.'),
#  (1, '1/2 off @ Barnes and Noble 2025'),
#  (1,
#   'This is the best economic game I have. I am really proud to have the Kickstarter edition. It is a number 1 more than deserved.'),
#  (1,
# ...
#  (0, '(Sleeved; matte)\n\nPlaymat'),
#  (0, 'Sleeved\nInsert'),
#  (-1, 'Just boring'),
#  (1, 'game is so very elegant and dynamic every time'),
#  (1, "probably the best economic game I've ever played..."),
#  (1,
#   'Quite simply a playful marvel! As good, although different, as its big brother. Enjoyable with 2 or 3 unlike Lancashire which can only be played with 4.'),
#  (0, 'You can consider starting at €50\nFor just under 30 stonks'),
#  (1, 'One of the best strategy game designs of all time.'),
#  (1, 'theme: train, economic\nbest: 3-4\ntime: average (~2h)'),
#  (0, '1-4'),
#  (1, 'WANT'),
#  (1, 'Best with 4 player, as you get more interactions.'),
#  (0, '2-4 players\nHardcore\nPhilly'),
#  (0, 'Printed organizer'),
#  (1,
#   'Amazing game but takes 2 hours to play, not everyone is up to play it but I love it!'),
#  (0, 'Explainer/Game Master: Thierry'),
#  (1, 'Best economic game there is'),
#  (0, 'Heavy-2'),
#  (0, 'Sloyca Premium'),
#  (0, 'Signed Copy'),
#  (0, '€80 + €56 insert + €8 scales + €39.50 token'),
#  (1, 'Not sure if its the best boardgame ever, but definetly in the top 5'),
#  (1,
#   "Played the new BRASS: BIRMINGHAM yesterday and completely blown away by it (even though I sucked at it). Strong core mechanics, very compelling and elegant gameplay and the most kick-ass production for a Euro I have ever seen (without being  over-produced like most KS games I see). This is Brass done right.  Can't wait to play again...& again!\n\nMy biggest critique of the game (if at all) is related to its major strength—aesthetics. While the art IS spectacular and looks just that on the computer screen where the light of a thousand suns from tiny pixels bring out all the details, I am afraid the printing process does not do justice to the darker palette. This severely impairs the playing of the game in sub-optimal lighting conditions (many cafes, pubs and non-game room areas in condo apartments have this problem). The location banners have similar tonal values and hence can be hard to identify (again, ONLY in sub-optimal lighting conditions) Having said that, it does look AWESOME in natural daylight and/well-lit rooms. I am only making this point because I am REALLY loving the game and wish it was as perfect as it could have been. \n\nAlso, because of the Kickstarter success, it would have been very practical and helpful if a stretch goal was player trays to go with the awesome player mats so all the tiles could be stored in the correct place and the game does not need the 5-6 min painful setup of sorting and placing tiles. Much like games such as Wasteland Express , Reckoners etc. Love the Iron Clays though...cant imagine playing without them!\n--------------------\n\nFavorite things...\n► Brass: Birmingham reinvents a classic, building upon what worked the most and improving things that did not. The depth the game offers relative to its complexity and ruleset is simply the best.\n► The player interaction is another highlight for me. The game works like a dynamic shared economy where every action affects others—networks, market prices, and resource access make Brass feel alive and competitive. This is my absolute favorite kind of player interaction.\n► There are multiple paths to victory, which serve a varied degree of challenges, allowing players to pick what seems most challenging and/or fun for them.\n\nMore, on this & other games in my ALL TIME - TOP 100  on my ⟣⧗First Pass⧗⟢ Blog:\nhttps://boardgamegeek.com/blog/9052/blogpost/172984/anim8rs-top-100-from-1000-2024-25-to-01"),
#  (1,
#   'Very good game; one of my top euros. Very fiddly setup and some mechanics are clunky, but otherwise I love the way the game looks and plays. Slightly better than Lancashire, I think, and a major improvement over original Brass in terms of looks.\n\nKey downside in my opinion is that the card actions are hard to remember and manage, especially with new players. People need to be very diligent about spending cards for actions and drawing back up to 8 cards. Very, very common to get to the end of an era with one person having too many cards.'),
#  (0, "Matt's collection"),
#  (1, 'Played once. Looong game. \nOnly for hardcore gamers'),
#  (0, 'Received for my birthday from Leon and Jelena'),
#  (0, 'Players C2-4 B3-4\n60-120min'),
#  (0,
#   "2 - 4 players\nCan be a bit heavy and some players are susceptible to AP'ing a bit much."),
#  (1,
#   "Haven't tried but my immediate circle doesn't have it and it sticks out as the top boardgame on many lists that I haven't tried and am interested in."),
#  (0, 'Insert from PrintablesByCaren (Etsy $37)'),
#  (1,
#   'Best game of all time.\n\nMid-heavy euro with a lot of player interaction and a lot of replayability.'),
#  (1,
#   "After a while I sold this and I bought the original. If Lancashire didn't exist, this rating would higher. The problem is, they made a worse version of a good game.\n\nIt is more convoluted than Lancashire, with more little bits and adapted to modern eurogamers. The game is more forgiving. No matter how bad the situation is, you can always do something, it is not nearly as tight as the original. Second era is just everyone placing connections and beer. The variable setup is nice, but Lancashire is superior in every other aspect."),
#  (1, 'Yes'),
#  (1,
#   'The depth/complexity is too small for my taste. Whenever I had my turn planned, I realized that I missed another special rule (because each resource is handled differently). I guess this becomes easier over time but it still requires a lot of mental resources to just get all of the constraints right.'),
#  (1,
#   'A really interesting game with a lot of cool mechanics. It takes a while to play though you can set an ealier stopping point (the game has obvious eras) should you not want the game to take too long. It is a bit more complicated than some so it helps to have an experienced person at the table.'),
#  (1, 'Very challenging and fin game'),
#  (0, 'lang_eng cat_strategy'),
#  (0, 'Dinged corner,'),
#  (0, '[76] 65x90 boardm sleeve'),
#  (1,
#   "Great network building and resource management game. \n\nInterestingly, this game has many actions where the action you're taking benefits yourself, but also another player. For example, you can take other players' resources on building they've built, but they want their buildings to be emptied so that their building tiles can be flipped and score them points and income.\n\nThere is a soft reset of the board in the middle of the game as well, which is definitely something to consider. If you manage to get out one of your buildings that don't get removed by this soft reset after the first era, they will score twice.\n\nI have heard countless times that this game was very cutthroat, but honestly, I didn't find it so compared to other network building games. Yes, you can cut someone's network short with your own, but that means you're likely cutting your own network too. Other players can use each other's networks anyway in many cases. I guess you can steal other players' building spots, but that is not enough to call a game cutthroat for me. i don't generally like cutthroat games, but I did like this."),
#  (0, "Friend's game"),
#  (0, '280'),
#  (1, 'Challenging One.'),
#  (1, "A very, very good game. I'll come back with pleasure"),
#  (0, 'Olga 3\nOmar 1'),
#  (1, 'A truly remarkable game.'),
#  (1,
#   'Easy to get into but really hard on the brain to progress. Always in debt too.\nPlays brilliantly'),
#  (1,
#   'The game itself is very neat and fun, but when you start thinking about only earning points through the network, the illusion disappears a bit.'),
#  (1,
#   "I think the more I play this the higher it will go. I played two-handed, but I can't stop thinking about it..."),
#  (0, 'In UK'),
#  (1,
#   'Awesome game! (Very hard to play after a longer break.) 2nd phase is more fun than 1st phase.\nBrain-burner. Feels really good to pull off a strategy.'),
#  (0, 'Derrick, Jessica, Jack?'),
#  (0, '3-4 players'),
#  (1, 'i had a lot of fun playing this game with friends'),
#  (1, 'Amazing game at every player count.'),
#  (1, '#1 on BGG for a long time - would like to play!'),
#  (1,
#   "The more I play the more I am converted. What I thought was a smart but hollow experience is now one of my most excited games to table. The balance of tactical plays, strategic planning, and player interaction, all wrapped in (what I think) is a beautiful package and theme, makes it clear why this is the King. It's not my favourite game, but damnit if it's not a brilliant one."),
#  (1, 'Original'),
#  (1,
#   'Been in the cupboard for years.  Finally got to play with 2 great teachers and none of us are AP prone.\n\nBrilliant, loved every second.  I think it does depend on the people at the table like most games.  Any AP prone people at the table would kill this for me.\n\nWorthy of being top 10 game, not sure about number 1 though ;-)'),
#  (1,
#   "One of the most responsive strategy games. And one of the best Euro's out there. More flexible than Brass: Lancashire. Very very good game. could be a bit stuffy."),
#  (-1,
#   "Only one game at 4. If it wasn't 1st in the bgg rankings I wouldn't even consider playing it again."),
#  (1,
#   "- first couple of games you will simply try to understand the rules and flip a few tiles across a few industries, then you move on and start developing level I buildings and focus on two or three industries, maybe you even start messing around with the wild cards, at some point you then realize it is really important to flip tiles before the end of the first era and that you should to flip multiple tiles in one move, build multiple connections in one move, buy coal/iron when it's cheap and so on. It is all about the action efficiency, stupid! :)\n- you are working towards your own goals but along the way other players will most likely also benefit from your activities - and vice versa. Whether it is building a connection or supplying resources. Sometimes it makes me wonder: so this is how capitalism works - everyone works for their own advantage but it somehow all falls into place and everyone is better off?!? On average at least…\n- yet you can also hurt other players by occupying spaces they have had their eyes on or forcing them to connect your network to dealers \n- beautiful map and art although a bit too much the dark side"),
#  (1, 'Just great!'),
#  (0, '+ insert reDrewno, iron clays 200'),
#  (0, 'David S. holds it (March 2025)'),
#  (0, 'Owner: Katie'),
#  (1,
#   "Introduced this game by my mate and I can't stop thinking about it afterwards. Got myself a deluxe copy and played with my SO and she loves it too. My first 10 rating euro game in my collection, is almost flawless, would really like to try Lancashire next and hopefully more Brass games will come out in the future."),
#  (1,
#   "Beautiful in it's design, and elegant.\n\nI can't believe how much I enjoyed this game, and it's worth all of the praise it gets. It scales uniquely from 2-4 players, and even has a fairly accessible 'Short' version.\n\nA little finnicky, and hard to grapple with on the first go through, but you'll catch yourself wanting to push harder and harder for more efficiency on the next play."),
#  (-1, 'No necessary in-game text'),
#  (0, '2-4p'),
#  (1,
#   "Incredible game. The rules are surprisingly not intimidating, it's strange. There's really only a few actions you're taking and you're limited to the cards in your hand, but there's an astonishing amount to consider. The nature of the rules and actions also result in new players feeling completely lost for the first half of the game. Thankfully there is an option to just only play one half. You lose out on a lot of the meaty planning ahead strategy, but new players can't comprehend that anyway. Allows you to still play through a teaching game in a couple of hours. The only bummer for me is so far I have mostly only played teaching/half games. \n\nStill my favorite economic game out there, it's a lot to sit down, setup and teach, but it's worth it every time."),
#  (1,
#   'Not my cup of tea, but I can see why people love it.\nVery euro, but also very interactive. First plays can be very punishing for new players.\nIt is easy to teach, but there are many nuances difficult to remember and spot when playing. It can cause AP very easily. I would not seek it but I can play it again'),
#  (1, 'Played at ampthill on board. Complex but worth a second play.'),
#  (1,
#   'I like Lancashire a bit better but these games are good enough to warrant owning and playing two slightly different versions.'),
#  (0, '8.5'),
#  (-1,
#   "Step back in time - entrenched in the theme - working 29hours a day at mill… young folk just wouldn't believe you. Fantastic!"),
#  (1,
#   "One of, if not, my favorite board games. Lots of different strategies but you can't stick to one thing and have to adapt to what other players are doing. \n\nLove its blend of pvp + pve. Love the quality, design, everything."),
#  (1, 'Best 3-4\n(Sleeved)\nKR+'),
#  (0, 'Birthday present Sept. 2024'),
#  (0,
#   'Description in English: Euro-rated "route/network construction" game based on the Industrial Revolution'),
#  (0, "Sleeved (FFG Grey)\nTinkertown 25 iron and 30 'coal' cubes"),
#  (0, 'Bricks'),
#  (0, '2-4'),
#  (0, 'The Master Work of Tito Wallace ❤️'),
#  (1,
#   "I'm still a novice with less than 10 plays under my belt, but this could be a top 5 game for me. I find the interaction between the players as the resource network grows to be so fascinating and unique. I'll revisit my rating once I have more plays under my belt"),
#  (0,
#   'The setup is fiddly and the rules are overly complex.\n* Sold by Timeless Board Games for me *'),
#  (1,
#   "I have the kickstarter Deluxe edition. It looks sooooo pretty that I don't want to play it. There is no game in my possession with a better build quality"),
#  (1,
#   "A good game. I personaly prefer Lancashire because it's a more streamlined version.In my opinion the game already was good enough. But this is still a good one."),
#  (1,
#   "Upgraded it to 9 and potentially to 10 moving forward. It does take a few plays to get around the ridiculous way goods transport around the map but once you accept that it's a great game.\n\nUpgraded to 6 after two plays. Still think it's fiddly as hell but it's definitely an interesting game.\n\nGiving it a reluctant 3 after one first play.\nSuper fiddly unintuitive rules:\n- Different ways the resources travel\n- The fact that lvl 1 buildings get cleared from the main board but not your personal board\n- 1 action for the 1st turn only for some reason\n- Can use bonus beer to ship goods but not to build tracks during phase 2\n\nReally hated the fact that you play canal part and then reset the game and count scores to play the rail phase with some useless buildings on the board you can't reuse. I took effort to develop and place lvl 2 buildings on the board and I can't reflip them for extra income, beer, etc? \n\nAlso the fact that you see the scores at the end of the canal phase, if you're quite far behind doesn't make you want to play the second phase anymore.\n\nEtc, etc.\n\nI basically liked nothing about the game after this first play."),
#  (1,
#   "In friends' collection: I usually wait until I played games a few times before I do a first rating, but this game is an exception. The first time I played this game was already amazing and I can't stop thinking about new strategies I want to try. I'm looking forward to my next play of the game. This is exactly the type of game I love. It does all the things I want in a game and it does them right."),
#  (1, 'Martin Wallace economic game masterpiece.'),
#  (-1,
#   'Critical Thinking\nEconomics\nManagement\nMath and Numeracy\nProblem Solving'),
#  (1, 'Great game'),
#  ...]

# %% [markdown]
# # Unsupervised Text Classification

# %%
import polars as pl
from sklearn.datasets import fetch_20newsgroups

# load data
train = fetch_20newsgroups(subset='train', shuffle=False)
test = fetch_20newsgroups(subset='test', shuffle=False)

# parse data to pandas DataFrames
newsgroup_test = pd.DataFrame({'article':test.data, 'class_index':test.target})
newsgroup_train = pd.DataFrame({'article':train.data, 'class_index':train.target})

# load labels with keywords
labels = pd.read_csv('20newsgroups_keywords.csv',sep=';')
# Out:
# /home/ziverael/Documents/BGG/analysis/.venv/lib/python3.12/site-packages/sklearn/datasets/_base.py:1519: UserWarning: Retry downloading from url: https://ndownloader.figshare.com/files/5975967
#   warnings.warn(f"Retry downloading from url: {remote.url}")
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[15], line 5
#       2 from sklearn.datasets import fetch_20newsgroups
#       4 # load data
# ----> 5 train = fetch_20newsgroups(subset='train', shuffle=False)
#       6 test = fetch_20newsgroups(subset='test', shuffle=False)
#       8 # parse data to pandas DataFrames
#
# File ~/Documents/BGG/analysis/.venv/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~/Documents/BGG/analysis/.venv/lib/python3.12/site-packages/sklearn/datasets/_twenty_newsgroups.py:320, in fetch_20newsgroups(data_home, subset, categories, shuffle, random_state, remove, download_if_missing, return_X_y, n_retries, delay)
#     318 if download_if_missing:
#     319     logger.info("Downloading 20news dataset. This may take a few minutes.")
# --> 320     cache = _download_20newsgroups(
#     321         target_dir=twenty_home,
#     322         cache_path=cache_path,
#     323         n_retries=n_retries,
#     324         delay=delay,
#     325     )
#     326 else:
#     327     raise OSError("20Newsgroups dataset not found")
#
# File ~/Documents/BGG/analysis/.venv/lib/python3.12/site-packages/sklearn/datasets/_twenty_newsgroups.py:79, in _download_20newsgroups(target_dir, cache_path, n_retries, delay)
#      76 os.makedirs(target_dir, exist_ok=True)
#      78 logger.info("Downloading dataset from %s (14 MB)", ARCHIVE.url)
# ---> 79 archive_path = _fetch_remote(
#      80     ARCHIVE, dirname=target_dir, n_retries=n_retries, delay=delay
#      81 )
#      83 logger.debug("Decompressing %s", archive_path)
#      84 with tarfile.open(archive_path, "r:gz") as fp:
#
# File ~/Documents/BGG/analysis/.venv/lib/python3.12/site-packages/sklearn/datasets/_base.py:1513, in _fetch_remote(remote, dirname, n_retries, delay)
#    1511 while True:
#    1512     try:
# -> 1513         urlretrieve(remote.url, temp_file_path)
#    1514         break
#    1515     except (URLError, TimeoutError):
#
# File /usr/lib/python3.12/urllib/request.py:240, in urlretrieve(url, filename, reporthook, data)
#     223 """
#     224 Retrieve a URL into a temporary location on disk.
#     225
#    (...)    236 data file as well as the resulting HTTPMessage object.
#     237 """
#     238 url_type, path = _splittype(url)
# --> 240 with contextlib.closing(urlopen(url, data)) as fp:
#     241     headers = fp.info()
#     243     # Just return the local path and the "headers" for file://
#     244     # URLs. No sense in performing a copy unless requested.
#
# File /usr/lib/python3.12/urllib/request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File /usr/lib/python3.12/urllib/request.py:521, in OpenerDirector.open(self, fullurl, data, timeout)
#     519 for processor in self.process_response.get(protocol, []):
#     520     meth = getattr(processor, meth_name)
# --> 521     response = meth(req, response)
#     523 return response
#
# File /usr/lib/python3.12/urllib/request.py:630, in HTTPErrorProcessor.http_response(self, request, response)
#     627 # According to RFC 2616, "2xx" code indicates that the client's
#     628 # request was successfully received, understood, and accepted.
#     629 if not (200 <= code < 300):
# --> 630     response = self.parent.error(
#     631         'http', request, response, code, msg, hdrs)
#     633 return response
#
# File /usr/lib/python3.12/urllib/request.py:559, in OpenerDirector.error(self, proto, *args)
#     557 if http_err:
#     558     args = (dict, 'default', 'http_error_default') + orig_args
# --> 559     return self._call_chain(*args)
#
# File /usr/lib/python3.12/urllib/request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File /usr/lib/python3.12/urllib/request.py:639, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     638 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 639     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 403: Forbidden
